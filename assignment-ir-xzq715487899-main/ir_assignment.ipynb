# %% [markdown]
# # Assignment: Information Retrieval (IR)

# %% [markdown]
# ## Preparations
# * Put all your imports, and path constants in the next cells

# %%
# !pip install whoosh
# !pip install pytrec_eval
# !pip install wget
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: whoosh in /usr/local/lib/python3.8/dist-packages (2.7.4)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: pytrec_eval in /usr/local/lib/python3.8/dist-packages (0.5)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: wget in /usr/local/lib/python3.8/dist-packages (3.2)

# %%
import wget
wget.download("https://github.com/MIE1513HS-2022/course-datasets/raw/main/government.zip", "government.zip")
# Out:
# 'government (1).zip'

# %%
# !unzip government.zip
# Out:
# Archive:  government.zip
# replace government/topics-with-full-descriptions.txt? [y]es, [n]o, [A]ll, [N]one, [r]ename: N

# %%
# imports
# Put all your imports here
from whoosh import index, writing, qparser,scoring
from whoosh.fields import Schema, TEXT, KEYWORD, ID, STORED
from whoosh.analysis import *
from whoosh.qparser import QueryParser
import os.path
from pathlib import Path
import tempfile
import subprocess
import pytrec_eval
import wget
import abc
import nltk
from abc import abstractmethod
from whoosh.analysis import Filter
from nltk.stem import *

# %%
class IRSystem(metaclass=abc.ABCMeta):
    """
    Abstract class which is inherited by other IR system
    """

    def __init__(self, data_dir):
        # DON'T change the following names,topic_file, qrels_file, document_dir, file_list
        self.topic_file = os.path.join(data_dir, "gov.topics")
        self.qrels_file = os.path.join(data_dir, "gov.qrels")
        self.document_dir = os.path.join(data_dir, "documents") 
        self.file_list = [str(filePath) for filePath in Path(self.document_dir).glob("**/*") if filePath.is_file()]

        self.create_index()
        self.add_files()
        self.create_parser_searcher()

    @abstractmethod
    def create_index(self):
        pass

    @abstractmethod
    def add_files(self):
        pass

    @abstractmethod
    def create_parser_searcher(self):
        pass

    @abstractmethod
    def perform_search(self, topic_phrase):
        pass

    @staticmethod
    def post_process_score(score):
        return score

    @staticmethod
    def print_trec_eval_result(results):
        if not results:
            print('empty results')
            return

        def print_line(name, scope, num):
            print('{:25s}{:8s}{:.4f}'.format(name, scope, num))

        for query_id, query_measures in results.items():
            for measure, value in query_measures.items():
                if measure == "runid":
                    continue
                print_line(measure, query_id, value)

        for measure in query_measures.keys():
            if measure == "runid":
                continue
            print_line(
                measure,
                'all',
                pytrec_eval.compute_aggregated_measure(
                    measure,
                    [query_measures[measure]
                     for query_measures in results.values()]))
            
    def print_rel_name(self, q_id):
        with open(self.topic_file, "r") as tf:
            topics = tf.read().splitlines()
        for topic in topics:
            topic_id, topic_phrase = tuple(topic.split(" ", 1))
            if topic_id == q_id:
                print("---------------------------Topic_id and Topic_phrase----------------------------------")
                print(topic_id, topic_phrase)
                 # get search result
                topic_results = self.perform_search(topic_phrase)
                print("---------------------------Return documents----------------------------------")
                for (docnum, result) in enumerate(topic_results):
                    score = topic_results.score(docnum)
                    score = self.post_process_score(score)
                    print("%s Q0 %s %d %lf test" % (topic_id, os.path.basename(result["file_path"]), docnum, score))
                print("---------------------------Relevant documents----------------------------------")
                with open(self.qrels_file, 'r') as f_qrel:
                    qrels = f_qrel.readlines()
                    for i in qrels:
                        qid, _, doc, rel = i.rstrip().split(" ")
                        if qid == q_id and rel == "1":
                            print(i.rstrip())

    def py_trec_eval(self):
        # Load topic file - a list of topics(search phrases) used for evalutation
        with open(self.topic_file, "r") as tf:
            topics = tf.read().splitlines()

            # create an output file to which we'll write our results
        temp_output_file = tempfile.mkstemp()[1]
        with open(temp_output_file, "w") as outputTRECFile:
            # for each evaluated topic:
            # build a query and record the results in the file in TREC_EVAL format
            for topic in topics:
                topic_id, topic_phrase = tuple(topic.split(" ", 1))
                # get search result
                topic_results = self.perform_search(topic_phrase)
                # format the result
                for (docnum, result) in enumerate(topic_results):
                    score = topic_results.score(docnum)
                    outputTRECFile.write(
                        "%s Q0 %s %d %lf test\n" % (topic_id, os.path.basename(result["file_path"]), docnum, score))

        with open(self.qrels_file, 'r') as f_qrel:
            qrel = pytrec_eval.parse_qrel(f_qrel)

        with open(temp_output_file, 'r') as f_run:
            run = pytrec_eval.parse_run(f_run)

        evaluator = pytrec_eval.RelevanceEvaluator(
            qrel, pytrec_eval.supported_measures)

        results = evaluator.evaluate(run)

        self.print_trec_eval_result(results)

# %%
# Dont change this! Use it as-is in your code
# This filter will run for both the index and the query
class CustomFilter(Filter):
    is_morph = True
    def __init__(self, filterFunc, *args, **kwargs):
        self.customFilter = filterFunc
        self.args = args
        self.kwargs = kwargs
    def __eq__(self):
        return (other
                and self.__class__ is other.__class__)
    def __call__(self, tokens):
        for t in tokens:
            if t.mode == 'query': # if called by query parser
                t.text = self.customFilter(t.text, *self.args, **self.kwargs)
                yield t
            else: # == 'index' if called by indexer
                t.text = self.customFilter(t.text, *self.args, **self.kwargs)
                yield t

# %% [markdown]
# ## Question 1
# Provide your text answers in the following two markdown cells

# %% [markdown]
# ### Q1 (a): Provide answer to Q1 (a) here [markdown cell]

# %% [markdown]
# Mean average precision (map)

# %% [markdown]
# ### Q1 (b): Provide answer to Q1 (b) here [markdown cell]

# %% [markdown]
# The MAP is a suitable measure to evaluate the performance of search engines for government websides. It gives equal weight to all queries, allowing for the assessment of both the relevance of the information retrieved and the ranked results. In my opinion, the MAP method is appropriate for measuring the performance of government website search systems and individual topics.

# %% [markdown]
# ## Question 2

# %% [markdown]
# ### Q2 (a): Write your code below

# %% [markdown]
# **1. The auto-grader will extract and use the following variables, DON'T change the their names:**
#
#       self.topic_file
#       self.qrels_file
#       self.document_dir
#       self.file_list
#       self.index_sys
#       self.query_parser
#       self.searcher
#
#
#
# **2. DON'T change the names of the already defined funtions**
# **3. DON'T change the py_trec_eval function**
# **4. DON'T change the class names including CustomFilter, IRSystem, IRQ2, IRQ3, IRQ4**
# **5. DON'T change the CustomFilter class and DON'T create any new custom filter class that is used to define Whoosh schema**

# %%
class IRQ2(IRSystem):
    def create_index(self):
        """
        INPUT:
            None
        OUTPUT:
            None
        
        NOTE: Please update self.index_sys which should have type whoosh.index.FileIndex
        """        
        # DON't change the name of 'index_sys'
        
        mySchema = Schema(file_path = ID(stored=True),
                          file_content = TEXT(analyzer = RegexTokenizer()))

         # Generate a temporary directory for the index
        indexDir = tempfile.mkdtemp()

        # create and return the index
        self.index_sys = index.create_in(indexDir, mySchema)


    def add_files(self):
        """
        INPUT:
            None
        OUTPUT:
            None
        
        NOTE: Add buffer to self.index_sys
        """
        # Build a list of files to index
        filesToIndex = [str(filePath) for filePath in Path(self.document_dir).glob("**/*") if filePath.is_file()]
        # open writer
        writer = writing.BufferedWriter(self.index_sys, period=None, limit=1000)
        try:
          # write each file to index
          for docNum, filePath in enumerate(filesToIndex):
              with open(filePath, "r", encoding="utf-8") as f:
                  fileContent = f.read()
                  writer.add_document(file_path = filePath,
                                      file_content = fileContent)

                  # print status every 1000 documents
                  if (docNum+1) % 1000 == 0:
                      print("already indexed:", docNum+1)
          print("done indexing.")

        finally:
            # close the index
            writer.close()

    def create_parser_searcher(self):
        """
        INPUT:
            None
        OUTPUT:
            None
        
        NOTE: Please update self.query_parser and self.searcher which should have type whoosh.qparser.default.QueryParser and whoosh.searching.Searcher respectively 
        """
        # define a query parser for the field "file_content" in the index
         # DON't change the names of 'query_parser' and 'searcher'
        self.query_parser = QueryParser("file_content", schema=self.index_sys.schema)
        self.searcher = self.index_sys.searcher()

    def perform_search(self, topic_phrase):
        """
        INPUT:
            topic_phrase: string
        OUTPUT:
            topic_results: whoosh.searching.Results
        
        NOTE: Utilize self.query_parser and self.searcher to calculate the result for topic_phrase
        """
        sampleQuery = self.query_parser.parse(topic_phrase)
        topic_results = self.searcher.search(sampleQuery, limit=None)
        return topic_results

# %%
q2 = IRQ2("government")
# Out:
# already indexed: 1000
# already indexed: 2000
# already indexed: 3000
# already indexed: 4000
# done indexing.

# %%
q2.py_trec_eval()
# Out:
# num_q                    1       1.0000
# num_ret                  1       1.0000
# num_rel                  1       5.0000
# num_rel_ret              1       0.0000
# map                      1       0.0000
# gm_map                   1       -11.5129
# Rprec                    1       0.0000
# bpref                    1       0.0000
# recip_rank               1       0.0000
# iprec_at_recall_0.00     1       0.0000
# iprec_at_recall_0.10     1       0.0000
# iprec_at_recall_0.20     1       0.0000
# iprec_at_recall_0.30     1       0.0000
# iprec_at_recall_0.40     1       0.0000
# iprec_at_recall_0.50     1       0.0000
# iprec_at_recall_0.60     1       0.0000
# iprec_at_recall_0.70     1       0.0000
# iprec_at_recall_0.80     1       0.0000
# iprec_at_recall_0.90     1       0.0000
# iprec_at_recall_1.00     1       0.0000
# P_5                      1       0.0000
# P_10                     1       0.0000
# P_15                     1       0.0000
# P_20                     1       0.0000
# P_30                     1       0.0000
# P_100                    1       0.0000
# P_200                    1       0.0000
# P_500                    1       0.0000
# P_1000                   1       0.0000
# relstring                1       0.0000
# recall_5                 1       0.0000
# recall_10                1       0.0000
# recall_15                1       0.0000
# recall_20                1       0.0000
# recall_30                1       0.0000
# recall_100               1       0.0000
# recall_200               1       0.0000
# recall_500               1       0.0000
# recall_1000              1       0.0000
# infAP                    1       0.0000
# gm_bpref                 1       -11.5129
# Rprec_mult_0.20          1       0.0000
# Rprec_mult_0.40          1       0.0000
# Rprec_mult_0.60          1       0.0000
# Rprec_mult_0.80          1       0.0000
# Rprec_mult_1.00          1       0.0000
# Rprec_mult_1.20          1       0.0000
# Rprec_mult_1.40          1       0.0000
# Rprec_mult_1.60          1       0.0000
# Rprec_mult_1.80          1       0.0000
# Rprec_mult_2.00          1       0.0000
# utility                  1       -1.0000
# 11pt_avg                 1       0.0000
# binG                     1       0.0000
# G                        1       0.0000
# ndcg                     1       0.0000
# ndcg_rel                 1       0.0000
# Rndcg                    1       0.0000
# ndcg_cut_5               1       0.0000
# ndcg_cut_10              1       0.0000
# ndcg_cut_15              1       0.0000
# ndcg_cut_20              1       0.0000
# ndcg_cut_30              1       0.0000
# ndcg_cut_100             1       0.0000
# ndcg_cut_200             1       0.0000
# ndcg_cut_500             1       0.0000
# ndcg_cut_1000            1       0.0000
# map_cut_5                1       0.0000
# map_cut_10               1       0.0000
# map_cut_15               1       0.0000
# map_cut_20               1       0.0000
# map_cut_30               1       0.0000
# map_cut_100              1       0.0000
# map_cut_200              1       0.0000
# map_cut_500              1       0.0000
# map_cut_1000             1       0.0000
# relative_P_5             1       0.0000
# relative_P_10            1       0.0000
# relative_P_15            1       0.0000
# relative_P_20            1       0.0000
# relative_P_30            1       0.0000
# relative_P_100           1       0.0000
# relative_P_200           1       0.0000
# relative_P_500           1       0.0000
# relative_P_1000          1       0.0000
# success_1                1       0.0000
# success_5                1       0.0000
# success_10               1       0.0000
# set_P                    1       0.0000
# set_relative_P           1       0.0000
# set_recall               1       0.0000
# set_map                  1       0.0000
# set_F                    1       0.0000
# num_nonrel_judged_ret    1       1.0000
# num_q                    2       1.0000
# num_ret                  2       6.0000
# num_rel                  2       2.0000
# num_rel_ret              2       0.0000
# map                      2       0.0000
# gm_map                   2       -11.5129
# Rprec                    2       0.0000
# bpref                    2       0.0000
# recip_rank               2       0.0000
# iprec_at_recall_0.00     2       0.0000
# iprec_at_recall_0.10     2       0.0000
# iprec_at_recall_0.20     2       0.0000
# iprec_at_recall_0.30     2       0.0000
# iprec_at_recall_0.40     2       0.0000
# iprec_at_recall_0.50     2       0.0000
# iprec_at_recall_0.60     2       0.0000
# iprec_at_recall_0.70     2       0.0000
# iprec_at_recall_0.80     2       0.0000
# iprec_at_recall_0.90     2       0.0000
# iprec_at_recall_1.00     2       0.0000
# P_5                      2       0.0000
# P_10                     2       0.0000
# P_15                     2       0.0000
# P_20                     2       0.0000
# P_30                     2       0.0000
# P_100                    2       0.0000
# P_200                    2       0.0000
# P_500                    2       0.0000
# P_1000                   2       0.0000
# relstring                2       0.0000
# recall_5                 2       0.0000
# recall_10                2       0.0000
# recall_15                2       0.0000
# recall_20                2       0.0000
# recall_30                2       0.0000
# recall_100               2       0.0000
# recall_200               2       0.0000
# recall_500               2       0.0000
# recall_1000              2       0.0000
# infAP                    2       0.0000
# gm_bpref                 2       -11.5129
# Rprec_mult_0.20          2       0.0000
# Rprec_mult_0.40          2       0.0000
# Rprec_mult_0.60          2       0.0000
# Rprec_mult_0.80          2       0.0000
# Rprec_mult_1.00          2       0.0000
# Rprec_mult_1.20          2       0.0000
# Rprec_mult_1.40          2       0.0000
# Rprec_mult_1.60          2       0.0000
# Rprec_mult_1.80          2       0.0000
# Rprec_mult_2.00          2       0.0000
# utility                  2       -6.0000
# 11pt_avg                 2       0.0000
# binG                     2       0.0000
# G                        2       0.0000
# ndcg                     2       0.0000
# ndcg_rel                 2       0.0000
# Rndcg                    2       0.0000
# ndcg_cut_5               2       0.0000
# ndcg_cut_10              2       0.0000
# ndcg_cut_15              2       0.0000
# ndcg_cut_20              2       0.0000
# ndcg_cut_30              2       0.0000
# ndcg_cut_100             2       0.0000
# ndcg_cut_200             2       0.0000
# ndcg_cut_500             2       0.0000
# ndcg_cut_1000            2       0.0000
# map_cut_5                2       0.0000
# map_cut_10               2       0.0000
# map_cut_15               2       0.0000
# map_cut_20               2       0.0000
# map_cut_30               2       0.0000
# map_cut_100              2       0.0000
# map_cut_200              2       0.0000
# map_cut_500              2       0.0000
# map_cut_1000             2       0.0000
# relative_P_5             2       0.0000
# relative_P_10            2       0.0000
# relative_P_15            2       0.0000
# relative_P_20            2       0.0000
# relative_P_30            2       0.0000
# relative_P_100           2       0.0000
# relative_P_200           2       0.0000
# relative_P_500           2       0.0000
# relative_P_1000          2       0.0000
# success_1                2       0.0000
# success_5                2       0.0000
# success_10               2       0.0000
# set_P                    2       0.0000
# set_relative_P           2       0.0000
# set_recall               2       0.0000
# set_map                  2       0.0000
# set_F                    2       0.0000
# num_nonrel_judged_ret    2       4.0000
# num_q                    4       1.0000
# num_ret                  4       12.0000
# num_rel                  4       4.0000
# num_rel_ret              4       1.0000
# map                      4       0.0312
# gm_map                   4       -3.4657
# Rprec                    4       0.0000
# bpref                    4       0.0000
# recip_rank               4       0.1250
# iprec_at_recall_0.00     4       0.1250
# iprec_at_recall_0.10     4       0.1250
# iprec_at_recall_0.20     4       0.1250
# iprec_at_recall_0.30     4       0.0000
# iprec_at_recall_0.40     4       0.0000
# iprec_at_recall_0.50     4       0.0000
# iprec_at_recall_0.60     4       0.0000
# iprec_at_recall_0.70     4       0.0000
# iprec_at_recall_0.80     4       0.0000
# iprec_at_recall_0.90     4       0.0000
# iprec_at_recall_1.00     4       0.0000
# P_5                      4       0.0000
# P_10                     4       0.1000
# P_15                     4       0.0667
# P_20                     4       0.0500
# P_30                     4       0.0333
# P_100                    4       0.0100
# P_200                    4       0.0050
# P_500                    4       0.0020
# P_1000                   4       0.0010
# relstring                4       0.0000
# recall_5                 4       0.0000
# recall_10                4       0.2500
# recall_15                4       0.2500
# recall_20                4       0.2500
# recall_30                4       0.2500
# recall_100               4       0.2500
# recall_200               4       0.2500
# recall_500               4       0.2500
# recall_1000              4       0.2500
# infAP                    4       0.0313
# gm_bpref                 4       -11.5129
# Rprec_mult_0.20          4       0.0000
# Rprec_mult_0.40          4       0.0000
# Rprec_mult_0.60          4       0.0000
# Rprec_mult_0.80          4       0.0000
# Rprec_mult_1.00          4       0.0000
# Rprec_mult_1.20          4       0.0000
# Rprec_mult_1.40          4       0.0000
# Rprec_mult_1.60          4       0.0000
# Rprec_mult_1.80          4       0.1250
# Rprec_mult_2.00          4       0.1250
# utility                  4       -10.0000
# 11pt_avg                 4       0.0341
# binG                     4       0.0789
# G                        4       0.0789
# ndcg                     4       0.1232
# ndcg_rel                 4       0.1232
# Rndcg                    4       0.0616
# ndcg_cut_5               4       0.0000
# ndcg_cut_10              4       0.1232
# ndcg_cut_15              4       0.1232
# ndcg_cut_20              4       0.1232
# ndcg_cut_30              4       0.1232
# ndcg_cut_100             4       0.1232
# ndcg_cut_200             4       0.1232
# ndcg_cut_500             4       0.1232
# ndcg_cut_1000            4       0.1232
# map_cut_5                4       0.0000
# map_cut_10               4       0.0312
# map_cut_15               4       0.0312
# map_cut_20               4       0.0312
# map_cut_30               4       0.0312
# map_cut_100              4       0.0312
# map_cut_200              4       0.0312
# map_cut_500              4       0.0312
# map_cut_1000             4       0.0312
# relative_P_5             4       0.0000
# relative_P_10            4       0.2500
# relative_P_15            4       0.2500
# relative_P_20            4       0.2500
# relative_P_30            4       0.2500
# relative_P_100           4       0.2500
# relative_P_200           4       0.2500
# relative_P_500           4       0.2500
# relative_P_1000          4       0.2500
# success_1                4       0.0000
# success_5                4       0.0000
# success_10               4       1.0000
# set_P                    4       0.0833
# set_relative_P           4       0.2500
# set_recall               4       0.2500
# set_map                  4       0.0208
# set_F                    4       0.1250
# num_nonrel_judged_ret    4       9.0000
# num_q                    6       1.0000
# num_ret                  6       5.0000
# num_rel                  6       1.0000
# num_rel_ret              6       0.0000
# map                      6       0.0000
# gm_map                   6       -11.5129
# Rprec                    6       0.0000
# bpref                    6       0.0000
# recip_rank               6       0.0000
# iprec_at_recall_0.00     6       0.0000
# iprec_at_recall_0.10     6       0.0000
# iprec_at_recall_0.20     6       0.0000
# iprec_at_recall_0.30     6       0.0000
# iprec_at_recall_0.40     6       0.0000
# iprec_at_recall_0.50     6       0.0000
# iprec_at_recall_0.60     6       0.0000
# iprec_at_recall_0.70     6       0.0000
# iprec_at_recall_0.80     6       0.0000
# iprec_at_recall_0.90     6       0.0000
# iprec_at_recall_1.00     6       0.0000
# P_5                      6       0.0000
# P_10                     6       0.0000
# P_15                     6       0.0000
# P_20                     6       0.0000
# P_30                     6       0.0000
# P_100                    6       0.0000
# P_200                    6       0.0000
# P_500                    6       0.0000
# P_1000                   6       0.0000
# relstring                6       0.0000
# recall_5                 6       0.0000
# recall_10                6       0.0000
# recall_15                6       0.0000
# recall_20                6       0.0000
# recall_30                6       0.0000
# recall_100               6       0.0000
# recall_200               6       0.0000
# recall_500               6       0.0000
# recall_1000              6       0.0000
# infAP                    6       0.0000
# gm_bpref                 6       -11.5129
# Rprec_mult_0.20          6       0.0000
# Rprec_mult_0.40          6       0.0000
# Rprec_mult_0.60          6       0.0000
# Rprec_mult_0.80          6       0.0000
# Rprec_mult_1.00          6       0.0000
# Rprec_mult_1.20          6       0.0000
# Rprec_mult_1.40          6       0.0000
# Rprec_mult_1.60          6       0.0000
# Rprec_mult_1.80          6       0.0000
# Rprec_mult_2.00          6       0.0000
# utility                  6       -5.0000
# 11pt_avg                 6       0.0000
# binG                     6       0.0000
# G                        6       0.0000
# ndcg                     6       0.0000
# ndcg_rel                 6       0.0000
# Rndcg                    6       0.0000
# ndcg_cut_5               6       0.0000
# ndcg_cut_10              6       0.0000
# ndcg_cut_15              6       0.0000
# ndcg_cut_20              6       0.0000
# ndcg_cut_30              6       0.0000
# ndcg_cut_100             6       0.0000
# ndcg_cut_200             6       0.0000
# ndcg_cut_500             6       0.0000
# ndcg_cut_1000            6       0.0000
# map_cut_5                6       0.0000
# map_cut_10               6       0.0000
# map_cut_15               6       0.0000
# map_cut_20               6       0.0000
# map_cut_30               6       0.0000
# map_cut_100              6       0.0000
# map_cut_200              6       0.0000
# map_cut_500              6       0.0000
# map_cut_1000             6       0.0000
# relative_P_5             6       0.0000
# relative_P_10            6       0.0000
# relative_P_15            6       0.0000
# relative_P_20            6       0.0000
# relative_P_30            6       0.0000
# relative_P_100           6       0.0000
# relative_P_200           6       0.0000
# relative_P_500           6       0.0000
# relative_P_1000          6       0.0000
# success_1                6       0.0000
# success_5                6       0.0000
# success_10               6       0.0000
# set_P                    6       0.0000
# set_relative_P           6       0.0000
# set_recall               6       0.0000
# set_map                  6       0.0000
# set_F                    6       0.0000
# num_nonrel_judged_ret    6       4.0000
# num_q                    7       1.0000
# num_ret                  7       7.0000
# num_rel                  7       3.0000
# num_rel_ret              7       0.0000
# map                      7       0.0000
# gm_map                   7       -11.5129
# Rprec                    7       0.0000
# bpref                    7       0.0000
# recip_rank               7       0.0000
# iprec_at_recall_0.00     7       0.0000
# iprec_at_recall_0.10     7       0.0000
# iprec_at_recall_0.20     7       0.0000
# iprec_at_recall_0.30     7       0.0000
# iprec_at_recall_0.40     7       0.0000
# iprec_at_recall_0.50     7       0.0000
# iprec_at_recall_0.60     7       0.0000
# iprec_at_recall_0.70     7       0.0000
# iprec_at_recall_0.80     7       0.0000
# iprec_at_recall_0.90     7       0.0000
# iprec_at_recall_1.00     7       0.0000
# P_5                      7       0.0000
# P_10                     7       0.0000
# P_15                     7       0.0000
# P_20                     7       0.0000
# P_30                     7       0.0000
# P_100                    7       0.0000
# P_200                    7       0.0000
# P_500                    7       0.0000
# P_1000                   7       0.0000
# relstring                7       0.0000
# recall_5                 7       0.0000
# recall_10                7       0.0000
# recall_15                7       0.0000
# recall_20                7       0.0000
# recall_30                7       0.0000
# recall_100               7       0.0000
# recall_200               7       0.0000
# recall_500               7       0.0000
# recall_1000              7       0.0000
# infAP                    7       0.0000
# gm_bpref                 7       -11.5129
# Rprec_mult_0.20          7       0.0000
# Rprec_mult_0.40          7       0.0000
# Rprec_mult_0.60          7       0.0000
# Rprec_mult_0.80          7       0.0000
# Rprec_mult_1.00          7       0.0000
# Rprec_mult_1.20          7       0.0000
# Rprec_mult_1.40          7       0.0000
# Rprec_mult_1.60          7       0.0000
# Rprec_mult_1.80          7       0.0000
# Rprec_mult_2.00          7       0.0000
# utility                  7       -7.0000
# 11pt_avg                 7       0.0000
# binG                     7       0.0000
# G                        7       0.0000
# ndcg                     7       0.0000
# ndcg_rel                 7       0.0000
# Rndcg                    7       0.0000
# ndcg_cut_5               7       0.0000
# ndcg_cut_10              7       0.0000
# ndcg_cut_15              7       0.0000
# ndcg_cut_20              7       0.0000
# ndcg_cut_30              7       0.0000
# ndcg_cut_100             7       0.0000
# ndcg_cut_200             7       0.0000
# ndcg_cut_500             7       0.0000
# ndcg_cut_1000            7       0.0000
# map_cut_5                7       0.0000
# map_cut_10               7       0.0000
# map_cut_15               7       0.0000
# map_cut_20               7       0.0000
# map_cut_30               7       0.0000
# map_cut_100              7       0.0000
# map_cut_200              7       0.0000
# map_cut_500              7       0.0000
# map_cut_1000             7       0.0000
# relative_P_5             7       0.0000
# relative_P_10            7       0.0000
# relative_P_15            7       0.0000
# relative_P_20            7       0.0000
# relative_P_30            7       0.0000
# relative_P_100           7       0.0000
# relative_P_200           7       0.0000
# relative_P_500           7       0.0000
# relative_P_1000          7       0.0000
# success_1                7       0.0000
# success_5                7       0.0000
# success_10               7       0.0000
# set_P                    7       0.0000
# set_relative_P           7       0.0000
# set_recall               7       0.0000
# set_map                  7       0.0000
# set_F                    7       0.0000
# num_nonrel_judged_ret    7       5.0000
# num_q                    9       1.0000
# num_ret                  9       2.0000
# num_rel                  9       1.0000
# num_rel_ret              9       0.0000
# map                      9       0.0000
# gm_map                   9       -11.5129
# Rprec                    9       0.0000
# bpref                    9       0.0000
# recip_rank               9       0.0000
# iprec_at_recall_0.00     9       0.0000
# iprec_at_recall_0.10     9       0.0000
# iprec_at_recall_0.20     9       0.0000
# iprec_at_recall_0.30     9       0.0000
# iprec_at_recall_0.40     9       0.0000
# iprec_at_recall_0.50     9       0.0000
# iprec_at_recall_0.60     9       0.0000
# iprec_at_recall_0.70     9       0.0000
# iprec_at_recall_0.80     9       0.0000
# iprec_at_recall_0.90     9       0.0000
# iprec_at_recall_1.00     9       0.0000
# P_5                      9       0.0000
# P_10                     9       0.0000
# P_15                     9       0.0000
# P_20                     9       0.0000
# P_30                     9       0.0000
# P_100                    9       0.0000
# P_200                    9       0.0000
# P_500                    9       0.0000
# P_1000                   9       0.0000
# relstring                9       0.0000
# recall_5                 9       0.0000
# recall_10                9       0.0000
# recall_15                9       0.0000
# recall_20                9       0.0000
# recall_30                9       0.0000
# recall_100               9       0.0000
# recall_200               9       0.0000
# recall_500               9       0.0000
# recall_1000              9       0.0000
# infAP                    9       0.0000
# gm_bpref                 9       -11.5129
# Rprec_mult_0.20          9       0.0000
# Rprec_mult_0.40          9       0.0000
# Rprec_mult_0.60          9       0.0000
# Rprec_mult_0.80          9       0.0000
# Rprec_mult_1.00          9       0.0000
# Rprec_mult_1.20          9       0.0000
# Rprec_mult_1.40          9       0.0000
# Rprec_mult_1.60          9       0.0000
# Rprec_mult_1.80          9       0.0000
# Rprec_mult_2.00          9       0.0000
# utility                  9       -2.0000
# 11pt_avg                 9       0.0000
# binG                     9       0.0000
# G                        9       0.0000
# ndcg                     9       0.0000
# ndcg_rel                 9       0.0000
# Rndcg                    9       0.0000
# ndcg_cut_5               9       0.0000
# ndcg_cut_10              9       0.0000
# ndcg_cut_15              9       0.0000
# ndcg_cut_20              9       0.0000
# ndcg_cut_30              9       0.0000
# ndcg_cut_100             9       0.0000
# ndcg_cut_200             9       0.0000
# ndcg_cut_500             9       0.0000
# ndcg_cut_1000            9       0.0000
# map_cut_5                9       0.0000
# map_cut_10               9       0.0000
# map_cut_15               9       0.0000
# map_cut_20               9       0.0000
# map_cut_30               9       0.0000
# map_cut_100              9       0.0000
# map_cut_200              9       0.0000
# map_cut_500              9       0.0000
# map_cut_1000             9       0.0000
# relative_P_5             9       0.0000
# relative_P_10            9       0.0000
# relative_P_15            9       0.0000
# relative_P_20            9       0.0000
# relative_P_30            9       0.0000
# relative_P_100           9       0.0000
# relative_P_200           9       0.0000
# relative_P_500           9       0.0000
# relative_P_1000          9       0.0000
# success_1                9       0.0000
# success_5                9       0.0000
# success_10               9       0.0000
# set_P                    9       0.0000
# set_relative_P           9       0.0000
# set_recall               9       0.0000
# set_map                  9       0.0000
# set_F                    9       0.0000
# num_nonrel_judged_ret    9       2.0000
# num_q                    10      1.0000
# num_ret                  10      16.0000
# num_rel                  10      1.0000
# num_rel_ret              10      1.0000
# map                      10      0.1667
# gm_map                   10      -1.7918
# Rprec                    10      0.0000
# bpref                    10      0.0000
# recip_rank               10      0.1667
# iprec_at_recall_0.00     10      0.1667
# iprec_at_recall_0.10     10      0.1667
# iprec_at_recall_0.20     10      0.1667
# iprec_at_recall_0.30     10      0.1667
# iprec_at_recall_0.40     10      0.1667
# iprec_at_recall_0.50     10      0.1667
# iprec_at_recall_0.60     10      0.1667
# iprec_at_recall_0.70     10      0.1667
# iprec_at_recall_0.80     10      0.1667
# iprec_at_recall_0.90     10      0.1667
# iprec_at_recall_1.00     10      0.1667
# P_5                      10      0.0000
# P_10                     10      0.1000
# P_15                     10      0.0667
# P_20                     10      0.0500
# P_30                     10      0.0333
# P_100                    10      0.0100
# P_200                    10      0.0050
# P_500                    10      0.0020
# P_1000                   10      0.0010
# relstring                10      0.0000
# recall_5                 10      0.0000
# recall_10                10      1.0000
# recall_15                10      1.0000
# recall_20                10      1.0000
# recall_30                10      1.0000
# recall_100               10      1.0000
# recall_200               10      1.0000
# recall_500               10      1.0000
# recall_1000              10      1.0000
# infAP                    10      0.1667
# gm_bpref                 10      -11.5129
# Rprec_mult_0.20          10      0.0000
# Rprec_mult_0.40          10      0.0000
# Rprec_mult_0.60          10      0.0000
# Rprec_mult_0.80          10      0.0000
# Rprec_mult_1.00          10      0.0000
# Rprec_mult_1.20          10      0.0000
# Rprec_mult_1.40          10      0.0000
# Rprec_mult_1.60          10      0.0000
# Rprec_mult_1.80          10      0.0000
# Rprec_mult_2.00          10      0.0000
# utility                  10      -14.0000
# 11pt_avg                 10      0.1667
# binG                     10      0.3562
# G                        10      0.3562
# ndcg                     10      0.3562
# ndcg_rel                 10      0.3562
# Rndcg                    10      0.1781
# ndcg_cut_5               10      0.0000
# ndcg_cut_10              10      0.3562
# ndcg_cut_15              10      0.3562
# ndcg_cut_20              10      0.3562
# ndcg_cut_30              10      0.3562
# ndcg_cut_100             10      0.3562
# ndcg_cut_200             10      0.3562
# ndcg_cut_500             10      0.3562
# ndcg_cut_1000            10      0.3562
# map_cut_5                10      0.0000
# map_cut_10               10      0.1667
# map_cut_15               10      0.1667
# map_cut_20               10      0.1667
# map_cut_30               10      0.1667
# map_cut_100              10      0.1667
# map_cut_200              10      0.1667
# map_cut_500              10      0.1667
# map_cut_1000             10      0.1667
# relative_P_5             10      0.0000
# relative_P_10            10      1.0000
# relative_P_15            10      1.0000
# relative_P_20            10      1.0000
# relative_P_30            10      1.0000
# relative_P_100           10      1.0000
# relative_P_200           10      1.0000
# relative_P_500           10      1.0000
# relative_P_1000          10      1.0000
# success_1                10      0.0000
# success_5                10      0.0000
# success_10               10      1.0000
# set_P                    10      0.0625
# set_relative_P           10      1.0000
# set_recall               10      1.0000
# set_map                  10      0.0625
# set_F                    10      0.1176
# num_nonrel_judged_ret    10      10.0000
# num_q                    14      1.0000
# num_ret                  14      7.0000
# num_rel                  14      1.0000
# num_rel_ret              14      1.0000
# map                      14      0.2500
# gm_map                   14      -1.3863
# Rprec                    14      0.0000
# bpref                    14      0.0000
# recip_rank               14      0.2500
# iprec_at_recall_0.00     14      0.2500
# iprec_at_recall_0.10     14      0.2500
# iprec_at_recall_0.20     14      0.2500
# iprec_at_recall_0.30     14      0.2500
# iprec_at_recall_0.40     14      0.2500
# iprec_at_recall_0.50     14      0.2500
# iprec_at_recall_0.60     14      0.2500
# iprec_at_recall_0.70     14      0.2500
# iprec_at_recall_0.80     14      0.2500
# iprec_at_recall_0.90     14      0.2500
# iprec_at_recall_1.00     14      0.2500
# P_5                      14      0.2000
# P_10                     14      0.1000
# P_15                     14      0.0667
# P_20                     14      0.0500
# P_30                     14      0.0333
# P_100                    14      0.0100
# P_200                    14      0.0050
# P_500                    14      0.0020
# P_1000                   14      0.0010
# relstring                14      0.0000
# recall_5                 14      1.0000
# recall_10                14      1.0000
# recall_15                14      1.0000
# recall_20                14      1.0000
# recall_30                14      1.0000
# recall_100               14      1.0000
# recall_200               14      1.0000
# recall_500               14      1.0000
# recall_1000              14      1.0000
# infAP                    14      0.2500
# gm_bpref                 14      -11.5129
# Rprec_mult_0.20          14      0.0000
# Rprec_mult_0.40          14      0.0000
# Rprec_mult_0.60          14      0.0000
# Rprec_mult_0.80          14      0.0000
# Rprec_mult_1.00          14      0.0000
# Rprec_mult_1.20          14      0.0000
# Rprec_mult_1.40          14      0.0000
# Rprec_mult_1.60          14      0.0000
# Rprec_mult_1.80          14      0.0000
# Rprec_mult_2.00          14      0.0000
# utility                  14      -5.0000
# 11pt_avg                 14      0.2500
# binG                     14      0.4307
# G                        14      0.4307
# ndcg                     14      0.4307
# ndcg_rel                 14      0.4307
# Rndcg                    14      0.2153
# ndcg_cut_5               14      0.4307
# ndcg_cut_10              14      0.4307
# ndcg_cut_15              14      0.4307
# ndcg_cut_20              14      0.4307
# ndcg_cut_30              14      0.4307
# ndcg_cut_100             14      0.4307
# ndcg_cut_200             14      0.4307
# ndcg_cut_500             14      0.4307
# ndcg_cut_1000            14      0.4307
# map_cut_5                14      0.2500
# map_cut_10               14      0.2500
# map_cut_15               14      0.2500
# map_cut_20               14      0.2500
# map_cut_30               14      0.2500
# map_cut_100              14      0.2500
# map_cut_200              14      0.2500
# map_cut_500              14      0.2500
# map_cut_1000             14      0.2500
# relative_P_5             14      1.0000
# relative_P_10            14      1.0000
# relative_P_15            14      1.0000
# relative_P_20            14      1.0000
# relative_P_30            14      1.0000
# relative_P_100           14      1.0000
# relative_P_200           14      1.0000
# relative_P_500           14      1.0000
# relative_P_1000          14      1.0000
# success_1                14      0.0000
# success_5                14      1.0000
# success_10               14      1.0000
# set_P                    14      0.1429
# set_relative_P           14      1.0000
# set_recall               14      1.0000
# set_map                  14      0.1429
# set_F                    14      0.2500
# num_nonrel_judged_ret    14      5.0000
# num_q                    16      1.0000
# num_ret                  16      7.0000
# num_rel                  16      7.0000
# num_rel_ret              16      0.0000
# map                      16      0.0000
# gm_map                   16      -11.5129
# Rprec                    16      0.0000
# bpref                    16      0.0000
# recip_rank               16      0.0000
# iprec_at_recall_0.00     16      0.0000
# iprec_at_recall_0.10     16      0.0000
# iprec_at_recall_0.20     16      0.0000
# iprec_at_recall_0.30     16      0.0000
# iprec_at_recall_0.40     16      0.0000
# iprec_at_recall_0.50     16      0.0000
# iprec_at_recall_0.60     16      0.0000
# iprec_at_recall_0.70     16      0.0000
# iprec_at_recall_0.80     16      0.0000
# iprec_at_recall_0.90     16      0.0000
# iprec_at_recall_1.00     16      0.0000
# P_5                      16      0.0000
# P_10                     16      0.0000
# P_15                     16      0.0000
# P_20                     16      0.0000
# P_30                     16      0.0000
# P_100                    16      0.0000
# P_200                    16      0.0000
# P_500                    16      0.0000
# P_1000                   16      0.0000
# relstring                16      0.0000
# recall_5                 16      0.0000
# recall_10                16      0.0000
# recall_15                16      0.0000
# recall_20                16      0.0000
# recall_30                16      0.0000
# recall_100               16      0.0000
# recall_200               16      0.0000
# recall_500               16      0.0000
# recall_1000              16      0.0000
# infAP                    16      0.0000
# gm_bpref                 16      -11.5129
# Rprec_mult_0.20          16      0.0000
# Rprec_mult_0.40          16      0.0000
# Rprec_mult_0.60          16      0.0000
# Rprec_mult_0.80          16      0.0000
# Rprec_mult_1.00          16      0.0000
# Rprec_mult_1.20          16      0.0000
# Rprec_mult_1.40          16      0.0000
# Rprec_mult_1.60          16      0.0000
# Rprec_mult_1.80          16      0.0000
# Rprec_mult_2.00          16      0.0000
# utility                  16      -7.0000
# 11pt_avg                 16      0.0000
# binG                     16      0.0000
# G                        16      0.0000
# ndcg                     16      0.0000
# ndcg_rel                 16      0.0000
# Rndcg                    16      0.0000
# ndcg_cut_5               16      0.0000
# ndcg_cut_10              16      0.0000
# ndcg_cut_15              16      0.0000
# ndcg_cut_20              16      0.0000
# ndcg_cut_30              16      0.0000
# ndcg_cut_100             16      0.0000
# ndcg_cut_200             16      0.0000
# ndcg_cut_500             16      0.0000
# ndcg_cut_1000            16      0.0000
# map_cut_5                16      0.0000
# map_cut_10               16      0.0000
# map_cut_15               16      0.0000
# map_cut_20               16      0.0000
# map_cut_30               16      0.0000
# map_cut_100              16      0.0000
# map_cut_200              16      0.0000
# map_cut_500              16      0.0000
# map_cut_1000             16      0.0000
# relative_P_5             16      0.0000
# relative_P_10            16      0.0000
# relative_P_15            16      0.0000
# relative_P_20            16      0.0000
# relative_P_30            16      0.0000
# relative_P_100           16      0.0000
# relative_P_200           16      0.0000
# relative_P_500           16      0.0000
# relative_P_1000          16      0.0000
# success_1                16      0.0000
# success_5                16      0.0000
# success_10               16      0.0000
# set_P                    16      0.0000
# set_relative_P           16      0.0000
# set_recall               16      0.0000
# set_map                  16      0.0000
# set_F                    16      0.0000
# num_nonrel_judged_ret    16      6.0000
# num_q                    18      1.0000
# num_ret                  18      17.0000
# num_rel                  18      1.0000
# num_rel_ret              18      1.0000
# map                      18      1.0000
# gm_map                   18      0.0000
# Rprec                    18      1.0000
# bpref                    18      1.0000
# recip_rank               18      1.0000
# iprec_at_recall_0.00     18      1.0000
# iprec_at_recall_0.10     18      1.0000
# iprec_at_recall_0.20     18      1.0000
# iprec_at_recall_0.30     18      1.0000
# iprec_at_recall_0.40     18      1.0000
# iprec_at_recall_0.50     18      1.0000
# iprec_at_recall_0.60     18      1.0000
# iprec_at_recall_0.70     18      1.0000
# iprec_at_recall_0.80     18      1.0000
# iprec_at_recall_0.90     18      1.0000
# iprec_at_recall_1.00     18      1.0000
# P_5                      18      0.2000
# P_10                     18      0.1000
# P_15                     18      0.0667
# P_20                     18      0.0500
# P_30                     18      0.0333
# P_100                    18      0.0100
# P_200                    18      0.0050
# P_500                    18      0.0020
# P_1000                   18      0.0010
# relstring                18      0.0000
# recall_5                 18      1.0000
# recall_10                18      1.0000
# recall_15                18      1.0000
# recall_20                18      1.0000
# recall_30                18      1.0000
# recall_100               18      1.0000
# recall_200               18      1.0000
# recall_500               18      1.0000
# recall_1000              18      1.0000
# infAP                    18      1.0000
# gm_bpref                 18      0.0000
# Rprec_mult_0.20          18      1.0000
# Rprec_mult_0.40          18      1.0000
# Rprec_mult_0.60          18      1.0000
# Rprec_mult_0.80          18      1.0000
# Rprec_mult_1.00          18      1.0000
# Rprec_mult_1.20          18      0.5000
# Rprec_mult_1.40          18      0.5000
# Rprec_mult_1.60          18      0.5000
# Rprec_mult_1.80          18      0.5000
# Rprec_mult_2.00          18      0.5000
# utility                  18      -15.0000
# 11pt_avg                 18      1.0000
# binG                     18      1.0000
# G                        18      1.0000
# ndcg                     18      1.0000
# ndcg_rel                 18      1.0000
# Rndcg                    18      1.0000
# ndcg_cut_5               18      1.0000
# ndcg_cut_10              18      1.0000
# ndcg_cut_15              18      1.0000
# ndcg_cut_20              18      1.0000
# ndcg_cut_30              18      1.0000
# ndcg_cut_100             18      1.0000
# ndcg_cut_200             18      1.0000
# ndcg_cut_500             18      1.0000
# ndcg_cut_1000            18      1.0000
# map_cut_5                18      1.0000
# map_cut_10               18      1.0000
# map_cut_15               18      1.0000
# map_cut_20               18      1.0000
# map_cut_30               18      1.0000
# map_cut_100              18      1.0000
# map_cut_200              18      1.0000
# map_cut_500              18      1.0000
# map_cut_1000             18      1.0000
# relative_P_5             18      1.0000
# relative_P_10            18      1.0000
# relative_P_15            18      1.0000
# relative_P_20            18      1.0000
# relative_P_30            18      1.0000
# relative_P_100           18      1.0000
# relative_P_200           18      1.0000
# relative_P_500           18      1.0000
# relative_P_1000          18      1.0000
# success_1                18      1.0000
# success_5                18      1.0000
# success_10               18      1.0000
# set_P                    18      0.0588
# set_relative_P           18      1.0000
# set_recall               18      1.0000
# set_map                  18      0.0588
# set_F                    18      0.1111
# num_nonrel_judged_ret    18      16.0000
# num_q                    22      1.0000
# num_ret                  22      17.0000
# num_rel                  22      1.0000
# num_rel_ret              22      1.0000
# map                      22      0.2000
# gm_map                   22      -1.6094
# Rprec                    22      0.0000
# bpref                    22      0.0000
# recip_rank               22      0.2000
# iprec_at_recall_0.00     22      0.2000
# iprec_at_recall_0.10     22      0.2000
# iprec_at_recall_0.20     22      0.2000
# iprec_at_recall_0.30     22      0.2000
# iprec_at_recall_0.40     22      0.2000
# iprec_at_recall_0.50     22      0.2000
# iprec_at_recall_0.60     22      0.2000
# iprec_at_recall_0.70     22      0.2000
# iprec_at_recall_0.80     22      0.2000
# iprec_at_recall_0.90     22      0.2000
# iprec_at_recall_1.00     22      0.2000
# P_5                      22      0.2000
# P_10                     22      0.1000
# P_15                     22      0.0667
# P_20                     22      0.0500
# P_30                     22      0.0333
# P_100                    22      0.0100
# P_200                    22      0.0050
# P_500                    22      0.0020
# P_1000                   22      0.0010
# relstring                22      0.0000
# recall_5                 22      1.0000
# recall_10                22      1.0000
# recall_15                22      1.0000
# recall_20                22      1.0000
# recall_30                22      1.0000
# recall_100               22      1.0000
# recall_200               22      1.0000
# recall_500               22      1.0000
# recall_1000              22      1.0000
# infAP                    22      0.2000
# gm_bpref                 22      -11.5129
# Rprec_mult_0.20          22      0.0000
# Rprec_mult_0.40          22      0.0000
# Rprec_mult_0.60          22      0.0000
# Rprec_mult_0.80          22      0.0000
# Rprec_mult_1.00          22      0.0000
# Rprec_mult_1.20          22      0.0000
# Rprec_mult_1.40          22      0.0000
# Rprec_mult_1.60          22      0.0000
# Rprec_mult_1.80          22      0.0000
# Rprec_mult_2.00          22      0.0000
# utility                  22      -15.0000
# 11pt_avg                 22      0.2000
# binG                     22      0.3869
# G                        22      0.3869
# ndcg                     22      0.3869
# ndcg_rel                 22      0.3869
# Rndcg                    22      0.1934
# ndcg_cut_5               22      0.3869
# ndcg_cut_10              22      0.3869
# ndcg_cut_15              22      0.3869
# ndcg_cut_20              22      0.3869
# ndcg_cut_30              22      0.3869
# ndcg_cut_100             22      0.3869
# ndcg_cut_200             22      0.3869
# ndcg_cut_500             22      0.3869
# ndcg_cut_1000            22      0.3869
# map_cut_5                22      0.2000
# map_cut_10               22      0.2000
# map_cut_15               22      0.2000
# map_cut_20               22      0.2000
# map_cut_30               22      0.2000
# map_cut_100              22      0.2000
# map_cut_200              22      0.2000
# map_cut_500              22      0.2000
# map_cut_1000             22      0.2000
# relative_P_5             22      1.0000
# relative_P_10            22      1.0000
# relative_P_15            22      1.0000
# relative_P_20            22      1.0000
# relative_P_30            22      1.0000
# relative_P_100           22      1.0000
# relative_P_200           22      1.0000
# relative_P_500           22      1.0000
# relative_P_1000          22      1.0000
# success_1                22      0.0000
# success_5                22      1.0000
# success_10               22      1.0000
# set_P                    22      0.0588
# set_relative_P           22      1.0000
# set_recall               22      1.0000
# set_map                  22      0.0588
# set_F                    22      0.1111
# num_nonrel_judged_ret    22      15.0000
# num_q                    24      1.0000
# num_ret                  24      7.0000
# num_rel                  24      1.0000
# num_rel_ret              24      1.0000
# map                      24      1.0000
# gm_map                   24      0.0000
# Rprec                    24      1.0000
# bpref                    24      1.0000
# recip_rank               24      1.0000
# iprec_at_recall_0.00     24      1.0000
# iprec_at_recall_0.10     24      1.0000
# iprec_at_recall_0.20     24      1.0000
# iprec_at_recall_0.30     24      1.0000
# iprec_at_recall_0.40     24      1.0000
# iprec_at_recall_0.50     24      1.0000
# iprec_at_recall_0.60     24      1.0000
# iprec_at_recall_0.70     24      1.0000
# iprec_at_recall_0.80     24      1.0000
# iprec_at_recall_0.90     24      1.0000
# iprec_at_recall_1.00     24      1.0000
# P_5                      24      0.2000
# P_10                     24      0.1000
# P_15                     24      0.0667
# P_20                     24      0.0500
# P_30                     24      0.0333
# P_100                    24      0.0100
# P_200                    24      0.0050
# P_500                    24      0.0020
# P_1000                   24      0.0010
# relstring                24      0.0000
# recall_5                 24      1.0000
# recall_10                24      1.0000
# recall_15                24      1.0000
# recall_20                24      1.0000
# recall_30                24      1.0000
# recall_100               24      1.0000
# recall_200               24      1.0000
# recall_500               24      1.0000
# recall_1000              24      1.0000
# infAP                    24      1.0000
# gm_bpref                 24      0.0000
# Rprec_mult_0.20          24      1.0000
# Rprec_mult_0.40          24      1.0000
# Rprec_mult_0.60          24      1.0000
# Rprec_mult_0.80          24      1.0000
# Rprec_mult_1.00          24      1.0000
# Rprec_mult_1.20          24      0.5000
# Rprec_mult_1.40          24      0.5000
# Rprec_mult_1.60          24      0.5000
# Rprec_mult_1.80          24      0.5000
# Rprec_mult_2.00          24      0.5000
# utility                  24      -5.0000
# 11pt_avg                 24      1.0000
# binG                     24      1.0000
# G                        24      1.0000
# ndcg                     24      1.0000
# ndcg_rel                 24      1.0000
# Rndcg                    24      1.0000
# ndcg_cut_5               24      1.0000
# ndcg_cut_10              24      1.0000
# ndcg_cut_15              24      1.0000
# ndcg_cut_20              24      1.0000
# ndcg_cut_30              24      1.0000
# ndcg_cut_100             24      1.0000
# ndcg_cut_200             24      1.0000
# ndcg_cut_500             24      1.0000
# ndcg_cut_1000            24      1.0000
# map_cut_5                24      1.0000
# map_cut_10               24      1.0000
# map_cut_15               24      1.0000
# map_cut_20               24      1.0000
# map_cut_30               24      1.0000
# map_cut_100              24      1.0000
# map_cut_200              24      1.0000
# map_cut_500              24      1.0000
# map_cut_1000             24      1.0000
# relative_P_5             24      1.0000
# relative_P_10            24      1.0000
# relative_P_15            24      1.0000
# relative_P_20            24      1.0000
# relative_P_30            24      1.0000
# relative_P_100           24      1.0000
# relative_P_200           24      1.0000
# relative_P_500           24      1.0000
# relative_P_1000          24      1.0000
# success_1                24      1.0000
# success_5                24      1.0000
# success_10               24      1.0000
# set_P                    24      0.1429
# set_relative_P           24      1.0000
# set_recall               24      1.0000
# set_map                  24      0.1429
# set_F                    24      0.2500
# num_nonrel_judged_ret    24      6.0000
# num_q                    26      1.0000
# num_ret                  26      25.0000
# num_rel                  26      3.0000
# num_rel_ret              26      1.0000
# map                      26      0.1111
# gm_map                   26      -2.1972
# Rprec                    26      0.3333
# bpref                    26      0.1111
# recip_rank               26      0.3333
# iprec_at_recall_0.00     26      0.3333
# iprec_at_recall_0.10     26      0.3333
# iprec_at_recall_0.20     26      0.3333
# iprec_at_recall_0.30     26      0.3333
# iprec_at_recall_0.40     26      0.0000
# iprec_at_recall_0.50     26      0.0000
# iprec_at_recall_0.60     26      0.0000
# iprec_at_recall_0.70     26      0.0000
# iprec_at_recall_0.80     26      0.0000
# iprec_at_recall_0.90     26      0.0000
# iprec_at_recall_1.00     26      0.0000
# P_5                      26      0.2000
# P_10                     26      0.1000
# P_15                     26      0.0667
# P_20                     26      0.0500
# P_30                     26      0.0333
# P_100                    26      0.0100
# P_200                    26      0.0050
# P_500                    26      0.0020
# P_1000                   26      0.0010
# relstring                26      0.0000
# recall_5                 26      0.3333
# recall_10                26      0.3333
# recall_15                26      0.3333
# recall_20                26      0.3333
# recall_30                26      0.3333
# recall_100               26      0.3333
# recall_200               26      0.3333
# recall_500               26      0.3333
# recall_1000              26      0.3333
# infAP                    26      0.1111
# gm_bpref                 26      -2.1972
# Rprec_mult_0.20          26      0.0000
# Rprec_mult_0.40          26      0.0000
# Rprec_mult_0.60          26      0.0000
# Rprec_mult_0.80          26      0.3333
# Rprec_mult_1.00          26      0.3333
# Rprec_mult_1.20          26      0.2500
# Rprec_mult_1.40          26      0.2000
# Rprec_mult_1.60          26      0.2000
# Rprec_mult_1.80          26      0.1667
# Rprec_mult_2.00          26      0.1667
# utility                  26      -23.0000
# 11pt_avg                 26      0.1212
# binG                     26      0.1667
# G                        26      0.1667
# ndcg                     26      0.2346
# ndcg_rel                 26      0.2346
# Rndcg                    26      0.2346
# ndcg_cut_5               26      0.2346
# ndcg_cut_10              26      0.2346
# ndcg_cut_15              26      0.2346
# ndcg_cut_20              26      0.2346
# ndcg_cut_30              26      0.2346
# ndcg_cut_100             26      0.2346
# ndcg_cut_200             26      0.2346
# ndcg_cut_500             26      0.2346
# ndcg_cut_1000            26      0.2346
# map_cut_5                26      0.1111
# map_cut_10               26      0.1111
# map_cut_15               26      0.1111
# map_cut_20               26      0.1111
# map_cut_30               26      0.1111
# map_cut_100              26      0.1111
# map_cut_200              26      0.1111
# map_cut_500              26      0.1111
# map_cut_1000             26      0.1111
# relative_P_5             26      0.3333
# relative_P_10            26      0.3333
# relative_P_15            26      0.3333
# relative_P_20            26      0.3333
# relative_P_30            26      0.3333
# relative_P_100           26      0.3333
# relative_P_200           26      0.3333
# relative_P_500           26      0.3333
# relative_P_1000          26      0.3333
# success_1                26      0.0000
# success_5                26      1.0000
# success_10               26      1.0000
# set_P                    26      0.0400
# set_relative_P           26      0.3333
# set_recall               26      0.3333
# set_map                  26      0.0133
# set_F                    26      0.0714
# num_nonrel_judged_ret    26      22.0000
# num_q                    28      1.0000
# num_ret                  28      22.0000
# num_rel                  28      2.0000
# num_rel_ret              28      0.0000
# map                      28      0.0000
# gm_map                   28      -11.5129
# Rprec                    28      0.0000
# bpref                    28      0.0000
# recip_rank               28      0.0000
# iprec_at_recall_0.00     28      0.0000
# iprec_at_recall_0.10     28      0.0000
# iprec_at_recall_0.20     28      0.0000
# iprec_at_recall_0.30     28      0.0000
# iprec_at_recall_0.40     28      0.0000
# iprec_at_recall_0.50     28      0.0000
# iprec_at_recall_0.60     28      0.0000
# iprec_at_recall_0.70     28      0.0000
# iprec_at_recall_0.80     28      0.0000
# iprec_at_recall_0.90     28      0.0000
# iprec_at_recall_1.00     28      0.0000
# P_5                      28      0.0000
# P_10                     28      0.0000
# P_15                     28      0.0000
# P_20                     28      0.0000
# P_30                     28      0.0000
# P_100                    28      0.0000
# P_200                    28      0.0000
# P_500                    28      0.0000
# P_1000                   28      0.0000
# relstring                28      0.0000
# recall_5                 28      0.0000
# recall_10                28      0.0000
# recall_15                28      0.0000
# recall_20                28      0.0000
# recall_30                28      0.0000
# recall_100               28      0.0000
# recall_200               28      0.0000
# recall_500               28      0.0000
# recall_1000              28      0.0000
# infAP                    28      0.0000
# gm_bpref                 28      -11.5129
# Rprec_mult_0.20          28      0.0000
# Rprec_mult_0.40          28      0.0000
# Rprec_mult_0.60          28      0.0000
# Rprec_mult_0.80          28      0.0000
# Rprec_mult_1.00          28      0.0000
# Rprec_mult_1.20          28      0.0000
# Rprec_mult_1.40          28      0.0000
# Rprec_mult_1.60          28      0.0000
# Rprec_mult_1.80          28      0.0000
# Rprec_mult_2.00          28      0.0000
# utility                  28      -22.0000
# 11pt_avg                 28      0.0000
# binG                     28      0.0000
# G                        28      0.0000
# ndcg                     28      0.0000
# ndcg_rel                 28      0.0000
# Rndcg                    28      0.0000
# ndcg_cut_5               28      0.0000
# ndcg_cut_10              28      0.0000
# ndcg_cut_15              28      0.0000
# ndcg_cut_20              28      0.0000
# ndcg_cut_30              28      0.0000
# ndcg_cut_100             28      0.0000
# ndcg_cut_200             28      0.0000
# ndcg_cut_500             28      0.0000
# ndcg_cut_1000            28      0.0000
# map_cut_5                28      0.0000
# map_cut_10               28      0.0000
# map_cut_15               28      0.0000
# map_cut_20               28      0.0000
# map_cut_30               28      0.0000
# map_cut_100              28      0.0000
# map_cut_200              28      0.0000
# map_cut_500              28      0.0000
# map_cut_1000             28      0.0000
# relative_P_5             28      0.0000
# relative_P_10            28      0.0000
# relative_P_15            28      0.0000
# relative_P_20            28      0.0000
# relative_P_30            28      0.0000
# relative_P_100           28      0.0000
# relative_P_200           28      0.0000
# relative_P_500           28      0.0000
# relative_P_1000          28      0.0000
# success_1                28      0.0000
# success_5                28      0.0000
# success_10               28      0.0000
# set_P                    28      0.0000
# set_relative_P           28      0.0000
# set_recall               28      0.0000
# set_map                  28      0.0000
# set_F                    28      0.0000
# num_nonrel_judged_ret    28      21.0000
# num_q                    all     14.0000
# num_ret                  all     151.0000
# num_rel                  all     33.0000
# num_rel_ret              all     7.0000
# map                      all     0.1971
# gm_map                   all     0.0015
# Rprec                    all     0.1667
# bpref                    all     0.1508
# recip_rank               all     0.2196
# iprec_at_recall_0.00     all     0.2196
# iprec_at_recall_0.10     all     0.2196
# iprec_at_recall_0.20     all     0.2196
# iprec_at_recall_0.30     all     0.2107
# iprec_at_recall_0.40     all     0.1869
# iprec_at_recall_0.50     all     0.1869
# iprec_at_recall_0.60     all     0.1869
# iprec_at_recall_0.70     all     0.1869
# iprec_at_recall_0.80     all     0.1869
# iprec_at_recall_0.90     all     0.1869
# iprec_at_recall_1.00     all     0.1869
# P_5                      all     0.0714
# P_10                     all     0.0500
# P_15                     all     0.0333
# P_20                     all     0.0250
# P_30                     all     0.0167
# P_100                    all     0.0050
# P_200                    all     0.0025
# P_500                    all     0.0010
# P_1000                   all     0.0005
# relstring                all     0.0000
# recall_5                 all     0.3095
# recall_10                all     0.3988
# recall_15                all     0.3988
# recall_20                all     0.3988
# recall_30                all     0.3988
# recall_100               all     0.3988
# recall_200               all     0.3988
# recall_500               all     0.3988
# recall_1000              all     0.3988
# infAP                    all     0.1971
# gm_bpref                 all     0.0001
# Rprec_mult_0.20          all     0.1429
# Rprec_mult_0.40          all     0.1429
# Rprec_mult_0.60          all     0.1429
# Rprec_mult_0.80          all     0.1667
# Rprec_mult_1.00          all     0.1667
# Rprec_mult_1.20          all     0.0893
# Rprec_mult_1.40          all     0.0857
# Rprec_mult_1.60          all     0.0857
# Rprec_mult_1.80          all     0.0923
# Rprec_mult_2.00          all     0.0923
# utility                  all     -9.7857
# 11pt_avg                 all     0.1980
# binG                     all     0.2442
# G                        all     0.2442
# ndcg                     all     0.2523
# ndcg_rel                 all     0.2523
# Rndcg                    all     0.2059
# ndcg_cut_5               all     0.2180
# ndcg_cut_10              all     0.2523
# ndcg_cut_15              all     0.2523
# ndcg_cut_20              all     0.2523
# ndcg_cut_30              all     0.2523
# ndcg_cut_100             all     0.2523
# ndcg_cut_200             all     0.2523
# ndcg_cut_500             all     0.2523
# ndcg_cut_1000            all     0.2523
# map_cut_5                all     0.1829
# map_cut_10               all     0.1971
# map_cut_15               all     0.1971
# map_cut_20               all     0.1971
# map_cut_30               all     0.1971
# map_cut_100              all     0.1971
# map_cut_200              all     0.1971
# map_cut_500              all     0.1971
# map_cut_1000             all     0.1971
# relative_P_5             all     0.3095
# relative_P_10            all     0.3988
# relative_P_15            all     0.3988
# relative_P_20            all     0.3988
# relative_P_30            all     0.3988
# relative_P_100           all     0.3988
# relative_P_200           all     0.3988
# relative_P_500           all     0.3988
# relative_P_1000          all     0.3988
# success_1                all     0.1429
# success_5                all     0.3571
# success_10               all     0.5000
# set_P                    all     0.0421
# set_relative_P           all     0.3988
# set_recall               all     0.3988
# set_map                  all     0.0357
# set_F                    all     0.0740
# num_nonrel_judged_ret    all     126.0000

# %%
q2.print_rel_name('1')
# Out:
# ---------------------------Topic_id and Topic_phrase----------------------------------
# 1 mining gold silver coal
# ---------------------------Return documents----------------------------------
# 1 Q0 G00-90-0342721 0 26.645398 test
# ---------------------------Relevant documents----------------------------------
# 1 0 G00-00-1006224 1
# 1 0 G00-02-0901987 1
# 1 0 G00-03-1898526 1
# 1 0 G00-10-3730888 1
# 1 0 G00-10-3849661 1

# %% [markdown]
# ### Q2 (b): Provide answer to Q2 (b) here [markdown cell]

# %% [markdown]
# The MAP and set_recall results of the Whoosh system are both very low, with an MAP of 0.1971 and set_recall of 0.3988 as shown in the output data.

# %% [markdown]
# ### Q2 (c): Provide answer to Q2(c) here [markdown cell]

# %% [markdown]
# Topics 18 and 24 performed exceptionally well, as all relevant information was retrieved and their MAP scores were 1. The number of relevant documents matches the number of relevant documents retrieved. However, for topics 1, 2, 6, 7, 9, 16, and 28, the MAP scores are all zero, indicating that no or very few relevant documents were retrieved. In some cases, a score was not returned, indicating poor performance.

# %% [markdown]
# ## Question 3

# %%
q2.print_rel_name('9')
# Out:
# ---------------------------Topic_id and Topic_phrase----------------------------------
# 9 genealogy searches
# ---------------------------Return documents----------------------------------
# 9 Q0 G00-26-1048210 0 12.268873 test
# 9 Q0 G00-59-3622783 1 5.132722 test
# ---------------------------Relevant documents----------------------------------
# 9 0 G00-91-3181951 1

# %% [markdown]
# ### Q3 (a): Provide answer to Q3 (a) here [markdown cell]

# %% [markdown]
# The Whoosh system needs to update its analyzer in order to improve its performance. The current analyzer has limitations, such as not being able to comprehend words in various forms (such as prefixes) and not effectively removing stop words and punctuation.
#
# Using query 9, "genealogy searches", as an example, there are two results listed in the sample output: G00-26-1048210 and G00-59-3622783. However, upon further investigation, these two results are false positives as they are not present in the qrels file. The document "G00-26-1048210" contains information on the FAQ for the public, but does not provide much useful information for "genealogy searches". It appears in the results due to the word "Genealogical Research".
#
# On the other hand, the document "G00-91-3181951" is relevant according to the qrels file, but does not appear in the sample result list, making it a false negative. This document is actually about "genealogy" topics, but was not extracted properly, possibly due to its key words being in different forms or variations.
#
# The results indicate that there are several factors that can impact Whoosh's performance, such as the presence of stop words, differences in upper/lower case, and different forms of words with the same root (such as "genealogical" and "genealogy"). Improving the performance of Whoosh may involve adjusting the words in the queries before the search, and using tools such as stemmers and lemmatizers from NLTK, such as the LancasterStemmer, LowercaseFilter, and StopFilter.

# %% [markdown]
# ### Q3 (b): Write your code below

# %% [markdown]
# **1. The auto-grader will extract and use the following variables, DON'T change the their names:**
#
#       self.topic_file
#       self.qrels_file
#       self.document_dir
#       self.file_list
#       self.index_sys
#       self.query_parser
#       self.searcher
#
#
#
# **2. DON'T change the names of the already defined funtions**
# **3. DON'T change the py_trec_eval function**
# **4. DON'T change the class names including CustomFilter, IRSystem, IRQ2, IRQ3, IRQ4**
# **5. DON'T change the CustomFilter class and DON'T create any new custom filter class that is used to define Whoosh schema**

# %%
# download required resources
nltk.download("wordnet")
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
class IRQ3(IRSystem):
    def create_index(self):
        """
        INPUT:
            None
        OUTPUT:
            None
        
        NOTE: Please update self.index_sys which should have type whoosh.index.FileIndex
        """        
        # DON't change the name of 'index_sys'
        myFilter = RegexTokenizer() | LowercaseFilter() | IntraWordFilter() | StopFilter() | CustomFilter(LancasterStemmer().stem)
        mySchema = Schema(file_path = ID(stored=True),
                          file_content = TEXT(analyzer = myFilter))

         # Generate a temporary directory for the index
        indexDir = tempfile.mkdtemp()

        # create and return the index
        self.index_sys = index.create_in(indexDir, mySchema)


    def add_files(self):
        """
        INPUT:
            None
        OUTPUT:
            None
        
        NOTE: Add buffer to self.index_sys
        """
        # Build a list of files to index
        filesToIndex = [str(filePath) for filePath in Path(self.document_dir).glob("**/*") if filePath.is_file()]
        # open writer
        writer = writing.BufferedWriter(self.index_sys, period=None, limit=1000)
        try:
          # write each file to index
          for docNum, filePath in enumerate(filesToIndex):
              with open(filePath, "r", encoding="utf-8") as f:
                  fileContent = f.read()
                  writer.add_document(file_path = filePath,
                                      file_content = fileContent)

                  # print status every 1000 documents
                  if (docNum+1) % 1000 == 0:
                      print("already indexed:", docNum+1)
          print("done indexing.")

        finally:
            # close the index
            writer.close()

    def create_parser_searcher(self):
        """
        INPUT:
            None
        OUTPUT:
            None
        
        NOTE: Please update self.query_parser and self.searcher which should have type whoosh.qparser.default.QueryParser and whoosh.searching.Searcher respectively 
        """
        # define a query parser for the field "file_content" in the index
         # DON't change the names of 'query_parser' and 'searcher'
        self.query_parser = QueryParser("file_content", schema=self.index_sys.schema)
        self.searcher = self.index_sys.searcher()

    def perform_search(self, topic_phrase):
        """
        INPUT:
            topic_phrase: string
        OUTPUT:
            topic_results: whoosh.searching.Results
        
        NOTE: Utilize self.query_parser and self.searcher to calculate the result for topic_phrase
        """
        sampleQuery = self.query_parser.parse(topic_phrase)
        topic_results = self.searcher.search(sampleQuery, limit=None)
        return topic_results

# %%
q3 = IRQ3("government")
# Out:
# already indexed: 1000
# already indexed: 2000
# already indexed: 3000
# already indexed: 4000
# done indexing.

# %%
q3.py_trec_eval()
# Out:
# num_q                    1       1.0000
# num_ret                  1       3.0000
# num_rel                  1       5.0000
# num_rel_ret              1       0.0000
# map                      1       0.0000
# gm_map                   1       -11.5129
# Rprec                    1       0.0000
# bpref                    1       0.0000
# recip_rank               1       0.0000
# iprec_at_recall_0.00     1       0.0000
# iprec_at_recall_0.10     1       0.0000
# iprec_at_recall_0.20     1       0.0000
# iprec_at_recall_0.30     1       0.0000
# iprec_at_recall_0.40     1       0.0000
# iprec_at_recall_0.50     1       0.0000
# iprec_at_recall_0.60     1       0.0000
# iprec_at_recall_0.70     1       0.0000
# iprec_at_recall_0.80     1       0.0000
# iprec_at_recall_0.90     1       0.0000
# iprec_at_recall_1.00     1       0.0000
# P_5                      1       0.0000
# P_10                     1       0.0000
# P_15                     1       0.0000
# P_20                     1       0.0000
# P_30                     1       0.0000
# P_100                    1       0.0000
# P_200                    1       0.0000
# P_500                    1       0.0000
# P_1000                   1       0.0000
# relstring                1       0.0000
# recall_5                 1       0.0000
# recall_10                1       0.0000
# recall_15                1       0.0000
# recall_20                1       0.0000
# recall_30                1       0.0000
# recall_100               1       0.0000
# recall_200               1       0.0000
# recall_500               1       0.0000
# recall_1000              1       0.0000
# infAP                    1       0.0000
# gm_bpref                 1       -11.5129
# Rprec_mult_0.20          1       0.0000
# Rprec_mult_0.40          1       0.0000
# Rprec_mult_0.60          1       0.0000
# Rprec_mult_0.80          1       0.0000
# Rprec_mult_1.00          1       0.0000
# Rprec_mult_1.20          1       0.0000
# Rprec_mult_1.40          1       0.0000
# Rprec_mult_1.60          1       0.0000
# Rprec_mult_1.80          1       0.0000
# Rprec_mult_2.00          1       0.0000
# utility                  1       -3.0000
# 11pt_avg                 1       0.0000
# binG                     1       0.0000
# G                        1       0.0000
# ndcg                     1       0.0000
# ndcg_rel                 1       0.0000
# Rndcg                    1       0.0000
# ndcg_cut_5               1       0.0000
# ndcg_cut_10              1       0.0000
# ndcg_cut_15              1       0.0000
# ndcg_cut_20              1       0.0000
# ndcg_cut_30              1       0.0000
# ndcg_cut_100             1       0.0000
# ndcg_cut_200             1       0.0000
# ndcg_cut_500             1       0.0000
# ndcg_cut_1000            1       0.0000
# map_cut_5                1       0.0000
# map_cut_10               1       0.0000
# map_cut_15               1       0.0000
# map_cut_20               1       0.0000
# map_cut_30               1       0.0000
# map_cut_100              1       0.0000
# map_cut_200              1       0.0000
# map_cut_500              1       0.0000
# map_cut_1000             1       0.0000
# relative_P_5             1       0.0000
# relative_P_10            1       0.0000
# relative_P_15            1       0.0000
# relative_P_20            1       0.0000
# relative_P_30            1       0.0000
# relative_P_100           1       0.0000
# relative_P_200           1       0.0000
# relative_P_500           1       0.0000
# relative_P_1000          1       0.0000
# success_1                1       0.0000
# success_5                1       0.0000
# success_10               1       0.0000
# set_P                    1       0.0000
# set_relative_P           1       0.0000
# set_recall               1       0.0000
# set_map                  1       0.0000
# set_F                    1       0.0000
# num_nonrel_judged_ret    1       3.0000
# num_q                    2       1.0000
# num_ret                  2       13.0000
# num_rel                  2       2.0000
# num_rel_ret              2       1.0000
# map                      2       0.5000
# gm_map                   2       -0.6931
# Rprec                    2       0.5000
# bpref                    2       0.5000
# recip_rank               2       1.0000
# iprec_at_recall_0.00     2       1.0000
# iprec_at_recall_0.10     2       1.0000
# iprec_at_recall_0.20     2       1.0000
# iprec_at_recall_0.30     2       1.0000
# iprec_at_recall_0.40     2       1.0000
# iprec_at_recall_0.50     2       1.0000
# iprec_at_recall_0.60     2       0.0000
# iprec_at_recall_0.70     2       0.0000
# iprec_at_recall_0.80     2       0.0000
# iprec_at_recall_0.90     2       0.0000
# iprec_at_recall_1.00     2       0.0000
# P_5                      2       0.2000
# P_10                     2       0.1000
# P_15                     2       0.0667
# P_20                     2       0.0500
# P_30                     2       0.0333
# P_100                    2       0.0100
# P_200                    2       0.0050
# P_500                    2       0.0020
# P_1000                   2       0.0010
# relstring                2       0.0000
# recall_5                 2       0.5000
# recall_10                2       0.5000
# recall_15                2       0.5000
# recall_20                2       0.5000
# recall_30                2       0.5000
# recall_100               2       0.5000
# recall_200               2       0.5000
# recall_500               2       0.5000
# recall_1000              2       0.5000
# infAP                    2       0.5000
# gm_bpref                 2       -0.6931
# Rprec_mult_0.20          2       1.0000
# Rprec_mult_0.40          2       1.0000
# Rprec_mult_0.60          2       0.5000
# Rprec_mult_0.80          2       0.5000
# Rprec_mult_1.00          2       0.5000
# Rprec_mult_1.20          2       0.3333
# Rprec_mult_1.40          2       0.3333
# Rprec_mult_1.60          2       0.2500
# Rprec_mult_1.80          2       0.2500
# Rprec_mult_2.00          2       0.2500
# utility                  2       -11.0000
# 11pt_avg                 2       0.5455
# binG                     2       0.5000
# G                        2       0.5000
# ndcg                     2       0.6131
# ndcg_rel                 2       0.8066
# Rndcg                    2       0.6131
# ndcg_cut_5               2       0.6131
# ndcg_cut_10              2       0.6131
# ndcg_cut_15              2       0.6131
# ndcg_cut_20              2       0.6131
# ndcg_cut_30              2       0.6131
# ndcg_cut_100             2       0.6131
# ndcg_cut_200             2       0.6131
# ndcg_cut_500             2       0.6131
# ndcg_cut_1000            2       0.6131
# map_cut_5                2       0.5000
# map_cut_10               2       0.5000
# map_cut_15               2       0.5000
# map_cut_20               2       0.5000
# map_cut_30               2       0.5000
# map_cut_100              2       0.5000
# map_cut_200              2       0.5000
# map_cut_500              2       0.5000
# map_cut_1000             2       0.5000
# relative_P_5             2       0.5000
# relative_P_10            2       0.5000
# relative_P_15            2       0.5000
# relative_P_20            2       0.5000
# relative_P_30            2       0.5000
# relative_P_100           2       0.5000
# relative_P_200           2       0.5000
# relative_P_500           2       0.5000
# relative_P_1000          2       0.5000
# success_1                2       1.0000
# success_5                2       1.0000
# success_10               2       1.0000
# set_P                    2       0.0769
# set_relative_P           2       0.5000
# set_recall               2       0.5000
# set_map                  2       0.0385
# set_F                    2       0.1333
# num_nonrel_judged_ret    2       9.0000
# num_q                    4       1.0000
# num_ret                  4       41.0000
# num_rel                  4       4.0000
# num_rel_ret              4       3.0000
# map                      4       0.5357
# gm_map                   4       -0.6242
# Rprec                    4       0.5000
# bpref                    4       0.5000
# recip_rank               4       1.0000
# iprec_at_recall_0.00     4       1.0000
# iprec_at_recall_0.10     4       1.0000
# iprec_at_recall_0.20     4       1.0000
# iprec_at_recall_0.30     4       1.0000
# iprec_at_recall_0.40     4       1.0000
# iprec_at_recall_0.50     4       1.0000
# iprec_at_recall_0.60     4       0.1429
# iprec_at_recall_0.70     4       0.1429
# iprec_at_recall_0.80     4       0.0000
# iprec_at_recall_0.90     4       0.0000
# iprec_at_recall_1.00     4       0.0000
# P_5                      4       0.4000
# P_10                     4       0.2000
# P_15                     4       0.1333
# P_20                     4       0.1000
# P_30                     4       0.1000
# P_100                    4       0.0300
# P_200                    4       0.0150
# P_500                    4       0.0060
# P_1000                   4       0.0030
# relstring                4       0.0000
# recall_5                 4       0.5000
# recall_10                4       0.5000
# recall_15                4       0.5000
# recall_20                4       0.5000
# recall_30                4       0.7500
# recall_100               4       0.7500
# recall_200               4       0.7500
# recall_500               4       0.7500
# recall_1000              4       0.7500
# infAP                    4       0.5357
# gm_bpref                 4       -0.6931
# Rprec_mult_0.20          4       1.0000
# Rprec_mult_0.40          4       1.0000
# Rprec_mult_0.60          4       0.6667
# Rprec_mult_0.80          4       0.5000
# Rprec_mult_1.00          4       0.5000
# Rprec_mult_1.20          4       0.4000
# Rprec_mult_1.40          4       0.3333
# Rprec_mult_1.60          4       0.2857
# Rprec_mult_1.80          4       0.2500
# Rprec_mult_2.00          4       0.2500
# utility                  4       -35.0000
# 11pt_avg                 4       0.5714
# binG                     4       0.5578
# G                        4       0.5578
# ndcg                     4       0.7242
# ndcg_rel                 4       0.8621
# Rndcg                    4       0.6805
# ndcg_cut_5               4       0.6367
# ndcg_cut_10              4       0.6367
# ndcg_cut_15              4       0.6367
# ndcg_cut_20              4       0.6367
# ndcg_cut_30              4       0.7242
# ndcg_cut_100             4       0.7242
# ndcg_cut_200             4       0.7242
# ndcg_cut_500             4       0.7242
# ndcg_cut_1000            4       0.7242
# map_cut_5                4       0.5000
# map_cut_10               4       0.5000
# map_cut_15               4       0.5000
# map_cut_20               4       0.5000
# map_cut_30               4       0.5357
# map_cut_100              4       0.5357
# map_cut_200              4       0.5357
# map_cut_500              4       0.5357
# map_cut_1000             4       0.5357
# relative_P_5             4       0.5000
# relative_P_10            4       0.5000
# relative_P_15            4       0.5000
# relative_P_20            4       0.5000
# relative_P_30            4       0.7500
# relative_P_100           4       0.7500
# relative_P_200           4       0.7500
# relative_P_500           4       0.7500
# relative_P_1000          4       0.7500
# success_1                4       1.0000
# success_5                4       1.0000
# success_10               4       1.0000
# set_P                    4       0.0732
# set_relative_P           4       0.7500
# set_recall               4       0.7500
# set_map                  4       0.0549
# set_F                    4       0.1333
# num_nonrel_judged_ret    4       26.0000
# num_q                    6       1.0000
# num_ret                  6       15.0000
# num_rel                  6       1.0000
# num_rel_ret              6       0.0000
# map                      6       0.0000
# gm_map                   6       -11.5129
# Rprec                    6       0.0000
# bpref                    6       0.0000
# recip_rank               6       0.0000
# iprec_at_recall_0.00     6       0.0000
# iprec_at_recall_0.10     6       0.0000
# iprec_at_recall_0.20     6       0.0000
# iprec_at_recall_0.30     6       0.0000
# iprec_at_recall_0.40     6       0.0000
# iprec_at_recall_0.50     6       0.0000
# iprec_at_recall_0.60     6       0.0000
# iprec_at_recall_0.70     6       0.0000
# iprec_at_recall_0.80     6       0.0000
# iprec_at_recall_0.90     6       0.0000
# iprec_at_recall_1.00     6       0.0000
# P_5                      6       0.0000
# P_10                     6       0.0000
# P_15                     6       0.0000
# P_20                     6       0.0000
# P_30                     6       0.0000
# P_100                    6       0.0000
# P_200                    6       0.0000
# P_500                    6       0.0000
# P_1000                   6       0.0000
# relstring                6       0.0000
# recall_5                 6       0.0000
# recall_10                6       0.0000
# recall_15                6       0.0000
# recall_20                6       0.0000
# recall_30                6       0.0000
# recall_100               6       0.0000
# recall_200               6       0.0000
# recall_500               6       0.0000
# recall_1000              6       0.0000
# infAP                    6       0.0000
# gm_bpref                 6       -11.5129
# Rprec_mult_0.20          6       0.0000
# Rprec_mult_0.40          6       0.0000
# Rprec_mult_0.60          6       0.0000
# Rprec_mult_0.80          6       0.0000
# Rprec_mult_1.00          6       0.0000
# Rprec_mult_1.20          6       0.0000
# Rprec_mult_1.40          6       0.0000
# Rprec_mult_1.60          6       0.0000
# Rprec_mult_1.80          6       0.0000
# Rprec_mult_2.00          6       0.0000
# utility                  6       -15.0000
# 11pt_avg                 6       0.0000
# binG                     6       0.0000
# G                        6       0.0000
# ndcg                     6       0.0000
# ndcg_rel                 6       0.0000
# Rndcg                    6       0.0000
# ndcg_cut_5               6       0.0000
# ndcg_cut_10              6       0.0000
# ndcg_cut_15              6       0.0000
# ndcg_cut_20              6       0.0000
# ndcg_cut_30              6       0.0000
# ndcg_cut_100             6       0.0000
# ndcg_cut_200             6       0.0000
# ndcg_cut_500             6       0.0000
# ndcg_cut_1000            6       0.0000
# map_cut_5                6       0.0000
# map_cut_10               6       0.0000
# map_cut_15               6       0.0000
# map_cut_20               6       0.0000
# map_cut_30               6       0.0000
# map_cut_100              6       0.0000
# map_cut_200              6       0.0000
# map_cut_500              6       0.0000
# map_cut_1000             6       0.0000
# relative_P_5             6       0.0000
# relative_P_10            6       0.0000
# relative_P_15            6       0.0000
# relative_P_20            6       0.0000
# relative_P_30            6       0.0000
# relative_P_100           6       0.0000
# relative_P_200           6       0.0000
# relative_P_500           6       0.0000
# relative_P_1000          6       0.0000
# success_1                6       0.0000
# success_5                6       0.0000
# success_10               6       0.0000
# set_P                    6       0.0000
# set_relative_P           6       0.0000
# set_recall               6       0.0000
# set_map                  6       0.0000
# set_F                    6       0.0000
# num_nonrel_judged_ret    6       14.0000
# num_q                    7       1.0000
# num_ret                  7       14.0000
# num_rel                  7       3.0000
# num_rel_ret              7       0.0000
# map                      7       0.0000
# gm_map                   7       -11.5129
# Rprec                    7       0.0000
# bpref                    7       0.0000
# recip_rank               7       0.0000
# iprec_at_recall_0.00     7       0.0000
# iprec_at_recall_0.10     7       0.0000
# iprec_at_recall_0.20     7       0.0000
# iprec_at_recall_0.30     7       0.0000
# iprec_at_recall_0.40     7       0.0000
# iprec_at_recall_0.50     7       0.0000
# iprec_at_recall_0.60     7       0.0000
# iprec_at_recall_0.70     7       0.0000
# iprec_at_recall_0.80     7       0.0000
# iprec_at_recall_0.90     7       0.0000
# iprec_at_recall_1.00     7       0.0000
# P_5                      7       0.0000
# P_10                     7       0.0000
# P_15                     7       0.0000
# P_20                     7       0.0000
# P_30                     7       0.0000
# P_100                    7       0.0000
# P_200                    7       0.0000
# P_500                    7       0.0000
# P_1000                   7       0.0000
# relstring                7       0.0000
# recall_5                 7       0.0000
# recall_10                7       0.0000
# recall_15                7       0.0000
# recall_20                7       0.0000
# recall_30                7       0.0000
# recall_100               7       0.0000
# recall_200               7       0.0000
# recall_500               7       0.0000
# recall_1000              7       0.0000
# infAP                    7       0.0000
# gm_bpref                 7       -11.5129
# Rprec_mult_0.20          7       0.0000
# Rprec_mult_0.40          7       0.0000
# Rprec_mult_0.60          7       0.0000
# Rprec_mult_0.80          7       0.0000
# Rprec_mult_1.00          7       0.0000
# Rprec_mult_1.20          7       0.0000
# Rprec_mult_1.40          7       0.0000
# Rprec_mult_1.60          7       0.0000
# Rprec_mult_1.80          7       0.0000
# Rprec_mult_2.00          7       0.0000
# utility                  7       -14.0000
# 11pt_avg                 7       0.0000
# binG                     7       0.0000
# G                        7       0.0000
# ndcg                     7       0.0000
# ndcg_rel                 7       0.0000
# Rndcg                    7       0.0000
# ndcg_cut_5               7       0.0000
# ndcg_cut_10              7       0.0000
# ndcg_cut_15              7       0.0000
# ndcg_cut_20              7       0.0000
# ndcg_cut_30              7       0.0000
# ndcg_cut_100             7       0.0000
# ndcg_cut_200             7       0.0000
# ndcg_cut_500             7       0.0000
# ndcg_cut_1000            7       0.0000
# map_cut_5                7       0.0000
# map_cut_10               7       0.0000
# map_cut_15               7       0.0000
# map_cut_20               7       0.0000
# map_cut_30               7       0.0000
# map_cut_100              7       0.0000
# map_cut_200              7       0.0000
# map_cut_500              7       0.0000
# map_cut_1000             7       0.0000
# relative_P_5             7       0.0000
# relative_P_10            7       0.0000
# relative_P_15            7       0.0000
# relative_P_20            7       0.0000
# relative_P_30            7       0.0000
# relative_P_100           7       0.0000
# relative_P_200           7       0.0000
# relative_P_500           7       0.0000
# relative_P_1000          7       0.0000
# success_1                7       0.0000
# success_5                7       0.0000
# success_10               7       0.0000
# set_P                    7       0.0000
# set_relative_P           7       0.0000
# set_recall               7       0.0000
# set_map                  7       0.0000
# set_F                    7       0.0000
# num_nonrel_judged_ret    7       11.0000
# num_q                    9       1.0000
# num_ret                  9       27.0000
# num_rel                  9       1.0000
# num_rel_ret              9       1.0000
# map                      9       0.0588
# gm_map                   9       -2.8332
# Rprec                    9       0.0000
# bpref                    9       0.0000
# recip_rank               9       0.0588
# iprec_at_recall_0.00     9       0.0588
# iprec_at_recall_0.10     9       0.0588
# iprec_at_recall_0.20     9       0.0588
# iprec_at_recall_0.30     9       0.0588
# iprec_at_recall_0.40     9       0.0588
# iprec_at_recall_0.50     9       0.0588
# iprec_at_recall_0.60     9       0.0588
# iprec_at_recall_0.70     9       0.0588
# iprec_at_recall_0.80     9       0.0588
# iprec_at_recall_0.90     9       0.0588
# iprec_at_recall_1.00     9       0.0588
# P_5                      9       0.0000
# P_10                     9       0.0000
# P_15                     9       0.0000
# P_20                     9       0.0500
# P_30                     9       0.0333
# P_100                    9       0.0100
# P_200                    9       0.0050
# P_500                    9       0.0020
# P_1000                   9       0.0010
# relstring                9       0.0000
# recall_5                 9       0.0000
# recall_10                9       0.0000
# recall_15                9       0.0000
# recall_20                9       1.0000
# recall_30                9       1.0000
# recall_100               9       1.0000
# recall_200               9       1.0000
# recall_500               9       1.0000
# recall_1000              9       1.0000
# infAP                    9       0.0588
# gm_bpref                 9       -11.5129
# Rprec_mult_0.20          9       0.0000
# Rprec_mult_0.40          9       0.0000
# Rprec_mult_0.60          9       0.0000
# Rprec_mult_0.80          9       0.0000
# Rprec_mult_1.00          9       0.0000
# Rprec_mult_1.20          9       0.0000
# Rprec_mult_1.40          9       0.0000
# Rprec_mult_1.60          9       0.0000
# Rprec_mult_1.80          9       0.0000
# Rprec_mult_2.00          9       0.0000
# utility                  9       -25.0000
# 11pt_avg                 9       0.0588
# binG                     9       0.2398
# G                        9       0.2398
# ndcg                     9       0.2398
# ndcg_rel                 9       0.2398
# Rndcg                    9       0.1199
# ndcg_cut_5               9       0.0000
# ndcg_cut_10              9       0.0000
# ndcg_cut_15              9       0.0000
# ndcg_cut_20              9       0.2398
# ndcg_cut_30              9       0.2398
# ndcg_cut_100             9       0.2398
# ndcg_cut_200             9       0.2398
# ndcg_cut_500             9       0.2398
# ndcg_cut_1000            9       0.2398
# map_cut_5                9       0.0000
# map_cut_10               9       0.0000
# map_cut_15               9       0.0000
# map_cut_20               9       0.0588
# map_cut_30               9       0.0588
# map_cut_100              9       0.0588
# map_cut_200              9       0.0588
# map_cut_500              9       0.0588
# map_cut_1000             9       0.0588
# relative_P_5             9       0.0000
# relative_P_10            9       0.0000
# relative_P_15            9       0.0000
# relative_P_20            9       1.0000
# relative_P_30            9       1.0000
# relative_P_100           9       1.0000
# relative_P_200           9       1.0000
# relative_P_500           9       1.0000
# relative_P_1000          9       1.0000
# success_1                9       0.0000
# success_5                9       0.0000
# success_10               9       0.0000
# set_P                    9       0.0370
# set_relative_P           9       1.0000
# set_recall               9       1.0000
# set_map                  9       0.0370
# set_F                    9       0.0714
# num_nonrel_judged_ret    9       23.0000
# num_q                    10      1.0000
# num_ret                  10      54.0000
# num_rel                  10      1.0000
# num_rel_ret              10      1.0000
# map                      10      0.2500
# gm_map                   10      -1.3863
# Rprec                    10      0.0000
# bpref                    10      0.0000
# recip_rank               10      0.2500
# iprec_at_recall_0.00     10      0.2500
# iprec_at_recall_0.10     10      0.2500
# iprec_at_recall_0.20     10      0.2500
# iprec_at_recall_0.30     10      0.2500
# iprec_at_recall_0.40     10      0.2500
# iprec_at_recall_0.50     10      0.2500
# iprec_at_recall_0.60     10      0.2500
# iprec_at_recall_0.70     10      0.2500
# iprec_at_recall_0.80     10      0.2500
# iprec_at_recall_0.90     10      0.2500
# iprec_at_recall_1.00     10      0.2500
# P_5                      10      0.2000
# P_10                     10      0.1000
# P_15                     10      0.0667
# P_20                     10      0.0500
# P_30                     10      0.0333
# P_100                    10      0.0100
# P_200                    10      0.0050
# P_500                    10      0.0020
# P_1000                   10      0.0010
# relstring                10      0.0000
# recall_5                 10      1.0000
# recall_10                10      1.0000
# recall_15                10      1.0000
# recall_20                10      1.0000
# recall_30                10      1.0000
# recall_100               10      1.0000
# recall_200               10      1.0000
# recall_500               10      1.0000
# recall_1000              10      1.0000
# infAP                    10      0.2500
# gm_bpref                 10      -11.5129
# Rprec_mult_0.20          10      0.0000
# Rprec_mult_0.40          10      0.0000
# Rprec_mult_0.60          10      0.0000
# Rprec_mult_0.80          10      0.0000
# Rprec_mult_1.00          10      0.0000
# Rprec_mult_1.20          10      0.0000
# Rprec_mult_1.40          10      0.0000
# Rprec_mult_1.60          10      0.0000
# Rprec_mult_1.80          10      0.0000
# Rprec_mult_2.00          10      0.0000
# utility                  10      -52.0000
# 11pt_avg                 10      0.2500
# binG                     10      0.4307
# G                        10      0.4307
# ndcg                     10      0.4307
# ndcg_rel                 10      0.4307
# Rndcg                    10      0.2153
# ndcg_cut_5               10      0.4307
# ndcg_cut_10              10      0.4307
# ndcg_cut_15              10      0.4307
# ndcg_cut_20              10      0.4307
# ndcg_cut_30              10      0.4307
# ndcg_cut_100             10      0.4307
# ndcg_cut_200             10      0.4307
# ndcg_cut_500             10      0.4307
# ndcg_cut_1000            10      0.4307
# map_cut_5                10      0.2500
# map_cut_10               10      0.2500
# map_cut_15               10      0.2500
# map_cut_20               10      0.2500
# map_cut_30               10      0.2500
# map_cut_100              10      0.2500
# map_cut_200              10      0.2500
# map_cut_500              10      0.2500
# map_cut_1000             10      0.2500
# relative_P_5             10      1.0000
# relative_P_10            10      1.0000
# relative_P_15            10      1.0000
# relative_P_20            10      1.0000
# relative_P_30            10      1.0000
# relative_P_100           10      1.0000
# relative_P_200           10      1.0000
# relative_P_500           10      1.0000
# relative_P_1000          10      1.0000
# success_1                10      0.0000
# success_5                10      1.0000
# success_10               10      1.0000
# set_P                    10      0.0185
# set_relative_P           10      1.0000
# set_recall               10      1.0000
# set_map                  10      0.0185
# set_F                    10      0.0364
# num_nonrel_judged_ret    10      16.0000
# num_q                    14      1.0000
# num_ret                  14      26.0000
# num_rel                  14      1.0000
# num_rel_ret              14      1.0000
# map                      14      1.0000
# gm_map                   14      0.0000
# Rprec                    14      1.0000
# bpref                    14      1.0000
# recip_rank               14      1.0000
# iprec_at_recall_0.00     14      1.0000
# iprec_at_recall_0.10     14      1.0000
# iprec_at_recall_0.20     14      1.0000
# iprec_at_recall_0.30     14      1.0000
# iprec_at_recall_0.40     14      1.0000
# iprec_at_recall_0.50     14      1.0000
# iprec_at_recall_0.60     14      1.0000
# iprec_at_recall_0.70     14      1.0000
# iprec_at_recall_0.80     14      1.0000
# iprec_at_recall_0.90     14      1.0000
# iprec_at_recall_1.00     14      1.0000
# P_5                      14      0.2000
# P_10                     14      0.1000
# P_15                     14      0.0667
# P_20                     14      0.0500
# P_30                     14      0.0333
# P_100                    14      0.0100
# P_200                    14      0.0050
# P_500                    14      0.0020
# P_1000                   14      0.0010
# relstring                14      0.0000
# recall_5                 14      1.0000
# recall_10                14      1.0000
# recall_15                14      1.0000
# recall_20                14      1.0000
# recall_30                14      1.0000
# recall_100               14      1.0000
# recall_200               14      1.0000
# recall_500               14      1.0000
# recall_1000              14      1.0000
# infAP                    14      1.0000
# gm_bpref                 14      0.0000
# Rprec_mult_0.20          14      1.0000
# Rprec_mult_0.40          14      1.0000
# Rprec_mult_0.60          14      1.0000
# Rprec_mult_0.80          14      1.0000
# Rprec_mult_1.00          14      1.0000
# Rprec_mult_1.20          14      0.5000
# Rprec_mult_1.40          14      0.5000
# Rprec_mult_1.60          14      0.5000
# Rprec_mult_1.80          14      0.5000
# Rprec_mult_2.00          14      0.5000
# utility                  14      -24.0000
# 11pt_avg                 14      1.0000
# binG                     14      1.0000
# G                        14      1.0000
# ndcg                     14      1.0000
# ndcg_rel                 14      1.0000
# Rndcg                    14      1.0000
# ndcg_cut_5               14      1.0000
# ndcg_cut_10              14      1.0000
# ndcg_cut_15              14      1.0000
# ndcg_cut_20              14      1.0000
# ndcg_cut_30              14      1.0000
# ndcg_cut_100             14      1.0000
# ndcg_cut_200             14      1.0000
# ndcg_cut_500             14      1.0000
# ndcg_cut_1000            14      1.0000
# map_cut_5                14      1.0000
# map_cut_10               14      1.0000
# map_cut_15               14      1.0000
# map_cut_20               14      1.0000
# map_cut_30               14      1.0000
# map_cut_100              14      1.0000
# map_cut_200              14      1.0000
# map_cut_500              14      1.0000
# map_cut_1000             14      1.0000
# relative_P_5             14      1.0000
# relative_P_10            14      1.0000
# relative_P_15            14      1.0000
# relative_P_20            14      1.0000
# relative_P_30            14      1.0000
# relative_P_100           14      1.0000
# relative_P_200           14      1.0000
# relative_P_500           14      1.0000
# relative_P_1000          14      1.0000
# success_1                14      1.0000
# success_5                14      1.0000
# success_10               14      1.0000
# set_P                    14      0.0385
# set_relative_P           14      1.0000
# set_recall               14      1.0000
# set_map                  14      0.0385
# set_F                    14      0.0741
# num_nonrel_judged_ret    14      20.0000
# num_q                    16      1.0000
# num_ret                  16      33.0000
# num_rel                  16      7.0000
# num_rel_ret              16      0.0000
# map                      16      0.0000
# gm_map                   16      -11.5129
# Rprec                    16      0.0000
# bpref                    16      0.0000
# recip_rank               16      0.0000
# iprec_at_recall_0.00     16      0.0000
# iprec_at_recall_0.10     16      0.0000
# iprec_at_recall_0.20     16      0.0000
# iprec_at_recall_0.30     16      0.0000
# iprec_at_recall_0.40     16      0.0000
# iprec_at_recall_0.50     16      0.0000
# iprec_at_recall_0.60     16      0.0000
# iprec_at_recall_0.70     16      0.0000
# iprec_at_recall_0.80     16      0.0000
# iprec_at_recall_0.90     16      0.0000
# iprec_at_recall_1.00     16      0.0000
# P_5                      16      0.0000
# P_10                     16      0.0000
# P_15                     16      0.0000
# P_20                     16      0.0000
# P_30                     16      0.0000
# P_100                    16      0.0000
# P_200                    16      0.0000
# P_500                    16      0.0000
# P_1000                   16      0.0000
# relstring                16      0.0000
# recall_5                 16      0.0000
# recall_10                16      0.0000
# recall_15                16      0.0000
# recall_20                16      0.0000
# recall_30                16      0.0000
# recall_100               16      0.0000
# recall_200               16      0.0000
# recall_500               16      0.0000
# recall_1000              16      0.0000
# infAP                    16      0.0000
# gm_bpref                 16      -11.5129
# Rprec_mult_0.20          16      0.0000
# Rprec_mult_0.40          16      0.0000
# Rprec_mult_0.60          16      0.0000
# Rprec_mult_0.80          16      0.0000
# Rprec_mult_1.00          16      0.0000
# Rprec_mult_1.20          16      0.0000
# Rprec_mult_1.40          16      0.0000
# Rprec_mult_1.60          16      0.0000
# Rprec_mult_1.80          16      0.0000
# Rprec_mult_2.00          16      0.0000
# utility                  16      -33.0000
# 11pt_avg                 16      0.0000
# binG                     16      0.0000
# G                        16      0.0000
# ndcg                     16      0.0000
# ndcg_rel                 16      0.0000
# Rndcg                    16      0.0000
# ndcg_cut_5               16      0.0000
# ndcg_cut_10              16      0.0000
# ndcg_cut_15              16      0.0000
# ndcg_cut_20              16      0.0000
# ndcg_cut_30              16      0.0000
# ndcg_cut_100             16      0.0000
# ndcg_cut_200             16      0.0000
# ndcg_cut_500             16      0.0000
# ndcg_cut_1000            16      0.0000
# map_cut_5                16      0.0000
# map_cut_10               16      0.0000
# map_cut_15               16      0.0000
# map_cut_20               16      0.0000
# map_cut_30               16      0.0000
# map_cut_100              16      0.0000
# map_cut_200              16      0.0000
# map_cut_500              16      0.0000
# map_cut_1000             16      0.0000
# relative_P_5             16      0.0000
# relative_P_10            16      0.0000
# relative_P_15            16      0.0000
# relative_P_20            16      0.0000
# relative_P_30            16      0.0000
# relative_P_100           16      0.0000
# relative_P_200           16      0.0000
# relative_P_500           16      0.0000
# relative_P_1000          16      0.0000
# success_1                16      0.0000
# success_5                16      0.0000
# success_10               16      0.0000
# set_P                    16      0.0000
# set_relative_P           16      0.0000
# set_recall               16      0.0000
# set_map                  16      0.0000
# set_F                    16      0.0000
# num_nonrel_judged_ret    16      20.0000
# num_q                    18      1.0000
# num_ret                  18      32.0000
# num_rel                  18      1.0000
# num_rel_ret              18      1.0000
# map                      18      1.0000
# gm_map                   18      0.0000
# Rprec                    18      1.0000
# bpref                    18      1.0000
# recip_rank               18      1.0000
# iprec_at_recall_0.00     18      1.0000
# iprec_at_recall_0.10     18      1.0000
# iprec_at_recall_0.20     18      1.0000
# iprec_at_recall_0.30     18      1.0000
# iprec_at_recall_0.40     18      1.0000
# iprec_at_recall_0.50     18      1.0000
# iprec_at_recall_0.60     18      1.0000
# iprec_at_recall_0.70     18      1.0000
# iprec_at_recall_0.80     18      1.0000
# iprec_at_recall_0.90     18      1.0000
# iprec_at_recall_1.00     18      1.0000
# P_5                      18      0.2000
# P_10                     18      0.1000
# P_15                     18      0.0667
# P_20                     18      0.0500
# P_30                     18      0.0333
# P_100                    18      0.0100
# P_200                    18      0.0050
# P_500                    18      0.0020
# P_1000                   18      0.0010
# relstring                18      0.0000
# recall_5                 18      1.0000
# recall_10                18      1.0000
# recall_15                18      1.0000
# recall_20                18      1.0000
# recall_30                18      1.0000
# recall_100               18      1.0000
# recall_200               18      1.0000
# recall_500               18      1.0000
# recall_1000              18      1.0000
# infAP                    18      1.0000
# gm_bpref                 18      0.0000
# Rprec_mult_0.20          18      1.0000
# Rprec_mult_0.40          18      1.0000
# Rprec_mult_0.60          18      1.0000
# Rprec_mult_0.80          18      1.0000
# Rprec_mult_1.00          18      1.0000
# Rprec_mult_1.20          18      0.5000
# Rprec_mult_1.40          18      0.5000
# Rprec_mult_1.60          18      0.5000
# Rprec_mult_1.80          18      0.5000
# Rprec_mult_2.00          18      0.5000
# utility                  18      -30.0000
# 11pt_avg                 18      1.0000
# binG                     18      1.0000
# G                        18      1.0000
# ndcg                     18      1.0000
# ndcg_rel                 18      1.0000
# Rndcg                    18      1.0000
# ndcg_cut_5               18      1.0000
# ndcg_cut_10              18      1.0000
# ndcg_cut_15              18      1.0000
# ndcg_cut_20              18      1.0000
# ndcg_cut_30              18      1.0000
# ndcg_cut_100             18      1.0000
# ndcg_cut_200             18      1.0000
# ndcg_cut_500             18      1.0000
# ndcg_cut_1000            18      1.0000
# map_cut_5                18      1.0000
# map_cut_10               18      1.0000
# map_cut_15               18      1.0000
# map_cut_20               18      1.0000
# map_cut_30               18      1.0000
# map_cut_100              18      1.0000
# map_cut_200              18      1.0000
# map_cut_500              18      1.0000
# map_cut_1000             18      1.0000
# relative_P_5             18      1.0000
# relative_P_10            18      1.0000
# relative_P_15            18      1.0000
# relative_P_20            18      1.0000
# relative_P_30            18      1.0000
# relative_P_100           18      1.0000
# relative_P_200           18      1.0000
# relative_P_500           18      1.0000
# relative_P_1000          18      1.0000
# success_1                18      1.0000
# success_5                18      1.0000
# success_10               18      1.0000
# set_P                    18      0.0312
# set_relative_P           18      1.0000
# set_recall               18      1.0000
# set_map                  18      0.0312
# set_F                    18      0.0606
# num_nonrel_judged_ret    18      30.0000
# num_q                    19      1.0000
# num_ret                  19      5.0000
# num_rel                  19      2.0000
# num_rel_ret              19      1.0000
# map                      19      0.5000
# gm_map                   19      -0.6931
# Rprec                    19      0.5000
# bpref                    19      0.5000
# recip_rank               19      1.0000
# iprec_at_recall_0.00     19      1.0000
# iprec_at_recall_0.10     19      1.0000
# iprec_at_recall_0.20     19      1.0000
# iprec_at_recall_0.30     19      1.0000
# iprec_at_recall_0.40     19      1.0000
# iprec_at_recall_0.50     19      1.0000
# iprec_at_recall_0.60     19      0.0000
# iprec_at_recall_0.70     19      0.0000
# iprec_at_recall_0.80     19      0.0000
# iprec_at_recall_0.90     19      0.0000
# iprec_at_recall_1.00     19      0.0000
# P_5                      19      0.2000
# P_10                     19      0.1000
# P_15                     19      0.0667
# P_20                     19      0.0500
# P_30                     19      0.0333
# P_100                    19      0.0100
# P_200                    19      0.0050
# P_500                    19      0.0020
# P_1000                   19      0.0010
# relstring                19      0.0000
# recall_5                 19      0.5000
# recall_10                19      0.5000
# recall_15                19      0.5000
# recall_20                19      0.5000
# recall_30                19      0.5000
# recall_100               19      0.5000
# recall_200               19      0.5000
# recall_500               19      0.5000
# recall_1000              19      0.5000
# infAP                    19      0.5000
# gm_bpref                 19      -0.6931
# Rprec_mult_0.20          19      1.0000
# Rprec_mult_0.40          19      1.0000
# Rprec_mult_0.60          19      0.5000
# Rprec_mult_0.80          19      0.5000
# Rprec_mult_1.00          19      0.5000
# Rprec_mult_1.20          19      0.3333
# Rprec_mult_1.40          19      0.3333
# Rprec_mult_1.60          19      0.2500
# Rprec_mult_1.80          19      0.2500
# Rprec_mult_2.00          19      0.2500
# utility                  19      -3.0000
# 11pt_avg                 19      0.5455
# binG                     19      0.5000
# G                        19      0.5000
# ndcg                     19      0.6131
# ndcg_rel                 19      0.8066
# Rndcg                    19      0.6131
# ndcg_cut_5               19      0.6131
# ndcg_cut_10              19      0.6131
# ndcg_cut_15              19      0.6131
# ndcg_cut_20              19      0.6131
# ndcg_cut_30              19      0.6131
# ndcg_cut_100             19      0.6131
# ndcg_cut_200             19      0.6131
# ndcg_cut_500             19      0.6131
# ndcg_cut_1000            19      0.6131
# map_cut_5                19      0.5000
# map_cut_10               19      0.5000
# map_cut_15               19      0.5000
# map_cut_20               19      0.5000
# map_cut_30               19      0.5000
# map_cut_100              19      0.5000
# map_cut_200              19      0.5000
# map_cut_500              19      0.5000
# map_cut_1000             19      0.5000
# relative_P_5             19      0.5000
# relative_P_10            19      0.5000
# relative_P_15            19      0.5000
# relative_P_20            19      0.5000
# relative_P_30            19      0.5000
# relative_P_100           19      0.5000
# relative_P_200           19      0.5000
# relative_P_500           19      0.5000
# relative_P_1000          19      0.5000
# success_1                19      1.0000
# success_5                19      1.0000
# success_10               19      1.0000
# set_P                    19      0.2000
# set_relative_P           19      0.5000
# set_recall               19      0.5000
# set_map                  19      0.1000
# set_F                    19      0.2857
# num_nonrel_judged_ret    19      4.0000
# num_q                    22      1.0000
# num_ret                  22      107.0000
# num_rel                  22      1.0000
# num_rel_ret              22      1.0000
# map                      22      0.0357
# gm_map                   22      -3.3322
# Rprec                    22      0.0000
# bpref                    22      0.0000
# recip_rank               22      0.0357
# iprec_at_recall_0.00     22      0.0357
# iprec_at_recall_0.10     22      0.0357
# iprec_at_recall_0.20     22      0.0357
# iprec_at_recall_0.30     22      0.0357
# iprec_at_recall_0.40     22      0.0357
# iprec_at_recall_0.50     22      0.0357
# iprec_at_recall_0.60     22      0.0357
# iprec_at_recall_0.70     22      0.0357
# iprec_at_recall_0.80     22      0.0357
# iprec_at_recall_0.90     22      0.0357
# iprec_at_recall_1.00     22      0.0357
# P_5                      22      0.0000
# P_10                     22      0.0000
# P_15                     22      0.0000
# P_20                     22      0.0000
# P_30                     22      0.0333
# P_100                    22      0.0100
# P_200                    22      0.0050
# P_500                    22      0.0020
# P_1000                   22      0.0010
# relstring                22      0.0000
# recall_5                 22      0.0000
# recall_10                22      0.0000
# recall_15                22      0.0000
# recall_20                22      0.0000
# recall_30                22      1.0000
# recall_100               22      1.0000
# recall_200               22      1.0000
# recall_500               22      1.0000
# recall_1000              22      1.0000
# infAP                    22      0.0357
# gm_bpref                 22      -11.5129
# Rprec_mult_0.20          22      0.0000
# Rprec_mult_0.40          22      0.0000
# Rprec_mult_0.60          22      0.0000
# Rprec_mult_0.80          22      0.0000
# Rprec_mult_1.00          22      0.0000
# Rprec_mult_1.20          22      0.0000
# Rprec_mult_1.40          22      0.0000
# Rprec_mult_1.60          22      0.0000
# Rprec_mult_1.80          22      0.0000
# Rprec_mult_2.00          22      0.0000
# utility                  22      -105.0000
# 11pt_avg                 22      0.0357
# binG                     22      0.2058
# G                        22      0.2058
# ndcg                     22      0.2058
# ndcg_rel                 22      0.2058
# Rndcg                    22      0.1029
# ndcg_cut_5               22      0.0000
# ndcg_cut_10              22      0.0000
# ndcg_cut_15              22      0.0000
# ndcg_cut_20              22      0.0000
# ndcg_cut_30              22      0.2058
# ndcg_cut_100             22      0.2058
# ndcg_cut_200             22      0.2058
# ndcg_cut_500             22      0.2058
# ndcg_cut_1000            22      0.2058
# map_cut_5                22      0.0000
# map_cut_10               22      0.0000
# map_cut_15               22      0.0000
# map_cut_20               22      0.0000
# map_cut_30               22      0.0357
# map_cut_100              22      0.0357
# map_cut_200              22      0.0357
# map_cut_500              22      0.0357
# map_cut_1000             22      0.0357
# relative_P_5             22      0.0000
# relative_P_10            22      0.0000
# relative_P_15            22      0.0000
# relative_P_20            22      0.0000
# relative_P_30            22      1.0000
# relative_P_100           22      1.0000
# relative_P_200           22      1.0000
# relative_P_500           22      1.0000
# relative_P_1000          22      1.0000
# success_1                22      0.0000
# success_5                22      0.0000
# success_10               22      0.0000
# set_P                    22      0.0093
# set_relative_P           22      1.0000
# set_recall               22      1.0000
# set_map                  22      0.0093
# set_F                    22      0.0185
# num_nonrel_judged_ret    22      72.0000
# num_q                    24      1.0000
# num_ret                  24      24.0000
# num_rel                  24      1.0000
# num_rel_ret              24      1.0000
# map                      24      1.0000
# gm_map                   24      0.0000
# Rprec                    24      1.0000
# bpref                    24      1.0000
# recip_rank               24      1.0000
# iprec_at_recall_0.00     24      1.0000
# iprec_at_recall_0.10     24      1.0000
# iprec_at_recall_0.20     24      1.0000
# iprec_at_recall_0.30     24      1.0000
# iprec_at_recall_0.40     24      1.0000
# iprec_at_recall_0.50     24      1.0000
# iprec_at_recall_0.60     24      1.0000
# iprec_at_recall_0.70     24      1.0000
# iprec_at_recall_0.80     24      1.0000
# iprec_at_recall_0.90     24      1.0000
# iprec_at_recall_1.00     24      1.0000
# P_5                      24      0.2000
# P_10                     24      0.1000
# P_15                     24      0.0667
# P_20                     24      0.0500
# P_30                     24      0.0333
# P_100                    24      0.0100
# P_200                    24      0.0050
# P_500                    24      0.0020
# P_1000                   24      0.0010
# relstring                24      0.0000
# recall_5                 24      1.0000
# recall_10                24      1.0000
# recall_15                24      1.0000
# recall_20                24      1.0000
# recall_30                24      1.0000
# recall_100               24      1.0000
# recall_200               24      1.0000
# recall_500               24      1.0000
# recall_1000              24      1.0000
# infAP                    24      1.0000
# gm_bpref                 24      0.0000
# Rprec_mult_0.20          24      1.0000
# Rprec_mult_0.40          24      1.0000
# Rprec_mult_0.60          24      1.0000
# Rprec_mult_0.80          24      1.0000
# Rprec_mult_1.00          24      1.0000
# Rprec_mult_1.20          24      0.5000
# Rprec_mult_1.40          24      0.5000
# Rprec_mult_1.60          24      0.5000
# Rprec_mult_1.80          24      0.5000
# Rprec_mult_2.00          24      0.5000
# utility                  24      -22.0000
# 11pt_avg                 24      1.0000
# binG                     24      1.0000
# G                        24      1.0000
# ndcg                     24      1.0000
# ndcg_rel                 24      1.0000
# Rndcg                    24      1.0000
# ndcg_cut_5               24      1.0000
# ndcg_cut_10              24      1.0000
# ndcg_cut_15              24      1.0000
# ndcg_cut_20              24      1.0000
# ndcg_cut_30              24      1.0000
# ndcg_cut_100             24      1.0000
# ndcg_cut_200             24      1.0000
# ndcg_cut_500             24      1.0000
# ndcg_cut_1000            24      1.0000
# map_cut_5                24      1.0000
# map_cut_10               24      1.0000
# map_cut_15               24      1.0000
# map_cut_20               24      1.0000
# map_cut_30               24      1.0000
# map_cut_100              24      1.0000
# map_cut_200              24      1.0000
# map_cut_500              24      1.0000
# map_cut_1000             24      1.0000
# relative_P_5             24      1.0000
# relative_P_10            24      1.0000
# relative_P_15            24      1.0000
# relative_P_20            24      1.0000
# relative_P_30            24      1.0000
# relative_P_100           24      1.0000
# relative_P_200           24      1.0000
# relative_P_500           24      1.0000
# relative_P_1000          24      1.0000
# success_1                24      1.0000
# success_5                24      1.0000
# success_10               24      1.0000
# set_P                    24      0.0417
# set_relative_P           24      1.0000
# set_recall               24      1.0000
# set_map                  24      0.0417
# set_F                    24      0.0800
# num_nonrel_judged_ret    24      18.0000
# num_q                    26      1.0000
# num_ret                  26      52.0000
# num_rel                  26      3.0000
# num_rel_ret              26      2.0000
# map                      26      0.0771
# gm_map                   26      -2.5632
# Rprec                    26      0.0000
# bpref                    26      0.0000
# recip_rank               26      0.1667
# iprec_at_recall_0.00     26      0.1667
# iprec_at_recall_0.10     26      0.1667
# iprec_at_recall_0.20     26      0.1667
# iprec_at_recall_0.30     26      0.1667
# iprec_at_recall_0.40     26      0.0645
# iprec_at_recall_0.50     26      0.0645
# iprec_at_recall_0.60     26      0.0645
# iprec_at_recall_0.70     26      0.0645
# iprec_at_recall_0.80     26      0.0000
# iprec_at_recall_0.90     26      0.0000
# iprec_at_recall_1.00     26      0.0000
# P_5                      26      0.0000
# P_10                     26      0.1000
# P_15                     26      0.0667
# P_20                     26      0.0500
# P_30                     26      0.0333
# P_100                    26      0.0200
# P_200                    26      0.0100
# P_500                    26      0.0040
# P_1000                   26      0.0020
# relstring                26      0.0000
# recall_5                 26      0.0000
# recall_10                26      0.3333
# recall_15                26      0.3333
# recall_20                26      0.3333
# recall_30                26      0.3333
# recall_100               26      0.6667
# recall_200               26      0.6667
# recall_500               26      0.6667
# recall_1000              26      0.6667
# infAP                    26      0.0771
# gm_bpref                 26      -11.5129
# Rprec_mult_0.20          26      0.0000
# Rprec_mult_0.40          26      0.0000
# Rprec_mult_0.60          26      0.0000
# Rprec_mult_0.80          26      0.0000
# Rprec_mult_1.00          26      0.0000
# Rprec_mult_1.20          26      0.0000
# Rprec_mult_1.40          26      0.0000
# Rprec_mult_1.60          26      0.0000
# Rprec_mult_1.80          26      0.1667
# Rprec_mult_2.00          26      0.1667
# utility                  26      -48.0000
# 11pt_avg                 26      0.0841
# binG                     26      0.1860
# G                        26      0.1860
# ndcg                     26      0.2610
# ndcg_rel                 26      0.2297
# Rndcg                    26      0.1305
# ndcg_cut_5               26      0.0000
# ndcg_cut_10              26      0.1672
# ndcg_cut_15              26      0.1672
# ndcg_cut_20              26      0.1672
# ndcg_cut_30              26      0.1672
# ndcg_cut_100             26      0.2610
# ndcg_cut_200             26      0.2610
# ndcg_cut_500             26      0.2610
# ndcg_cut_1000            26      0.2610
# map_cut_5                26      0.0000
# map_cut_10               26      0.0556
# map_cut_15               26      0.0556
# map_cut_20               26      0.0556
# map_cut_30               26      0.0556
# map_cut_100              26      0.0771
# map_cut_200              26      0.0771
# map_cut_500              26      0.0771
# map_cut_1000             26      0.0771
# relative_P_5             26      0.0000
# relative_P_10            26      0.3333
# relative_P_15            26      0.3333
# relative_P_20            26      0.3333
# relative_P_30            26      0.3333
# relative_P_100           26      0.6667
# relative_P_200           26      0.6667
# relative_P_500           26      0.6667
# relative_P_1000          26      0.6667
# success_1                26      0.0000
# success_5                26      0.0000
# success_10               26      1.0000
# set_P                    26      0.0385
# set_relative_P           26      0.6667
# set_recall               26      0.6667
# set_map                  26      0.0256
# set_F                    26      0.0727
# num_nonrel_judged_ret    26      36.0000
# num_q                    28      1.0000
# num_ret                  28      64.0000
# num_rel                  28      2.0000
# num_rel_ret              28      2.0000
# map                      28      0.2262
# gm_map                   28      -1.4864
# Rprec                    28      0.0000
# bpref                    28      0.0000
# recip_rank               28      0.1667
# iprec_at_recall_0.00     28      0.2857
# iprec_at_recall_0.10     28      0.2857
# iprec_at_recall_0.20     28      0.2857
# iprec_at_recall_0.30     28      0.2857
# iprec_at_recall_0.40     28      0.2857
# iprec_at_recall_0.50     28      0.2857
# iprec_at_recall_0.60     28      0.2857
# iprec_at_recall_0.70     28      0.2857
# iprec_at_recall_0.80     28      0.2857
# iprec_at_recall_0.90     28      0.2857
# iprec_at_recall_1.00     28      0.2857
# P_5                      28      0.0000
# P_10                     28      0.2000
# P_15                     28      0.1333
# P_20                     28      0.1000
# P_30                     28      0.0667
# P_100                    28      0.0200
# P_200                    28      0.0100
# P_500                    28      0.0040
# P_1000                   28      0.0020
# relstring                28      0.0000
# recall_5                 28      0.0000
# recall_10                28      1.0000
# recall_15                28      1.0000
# recall_20                28      1.0000
# recall_30                28      1.0000
# recall_100               28      1.0000
# recall_200               28      1.0000
# recall_500               28      1.0000
# recall_1000              28      1.0000
# infAP                    28      0.2262
# gm_bpref                 28      -11.5129
# Rprec_mult_0.20          28      0.0000
# Rprec_mult_0.40          28      0.0000
# Rprec_mult_0.60          28      0.0000
# Rprec_mult_0.80          28      0.0000
# Rprec_mult_1.00          28      0.0000
# Rprec_mult_1.20          28      0.0000
# Rprec_mult_1.40          28      0.0000
# Rprec_mult_1.60          28      0.0000
# Rprec_mult_1.80          28      0.0000
# Rprec_mult_2.00          28      0.0000
# utility                  28      -60.0000
# 11pt_avg                 28      0.2857
# binG                     28      0.3562
# G                        28      0.3562
# ndcg                     28      0.4228
# ndcg_rel                 28      0.3206
# Rndcg                    28      0.2114
# ndcg_cut_5               28      0.0000
# ndcg_cut_10              28      0.4228
# ndcg_cut_15              28      0.4228
# ndcg_cut_20              28      0.4228
# ndcg_cut_30              28      0.4228
# ndcg_cut_100             28      0.4228
# ndcg_cut_200             28      0.4228
# ndcg_cut_500             28      0.4228
# ndcg_cut_1000            28      0.4228
# map_cut_5                28      0.0000
# map_cut_10               28      0.2262
# map_cut_15               28      0.2262
# map_cut_20               28      0.2262
# map_cut_30               28      0.2262
# map_cut_100              28      0.2262
# map_cut_200              28      0.2262
# map_cut_500              28      0.2262
# map_cut_1000             28      0.2262
# relative_P_5             28      0.0000
# relative_P_10            28      1.0000
# relative_P_15            28      1.0000
# relative_P_20            28      1.0000
# relative_P_30            28      1.0000
# relative_P_100           28      1.0000
# relative_P_200           28      1.0000
# relative_P_500           28      1.0000
# relative_P_1000          28      1.0000
# success_1                28      0.0000
# success_5                28      0.0000
# success_10               28      1.0000
# set_P                    28      0.0312
# set_relative_P           28      1.0000
# set_recall               28      1.0000
# set_map                  28      0.0312
# set_F                    28      0.0606
# num_nonrel_judged_ret    28      28.0000
# num_q                    all     15.0000
# num_ret                  all     510.0000
# num_rel                  all     35.0000
# num_rel_ret              all     15.0000
# map                      all     0.3456
# gm_map                   all     0.0187
# Rprec                    all     0.3000
# bpref                    all     0.3000
# recip_rank               all     0.4452
# iprec_at_recall_0.00     all     0.4531
# iprec_at_recall_0.10     all     0.4531
# iprec_at_recall_0.20     all     0.4531
# iprec_at_recall_0.30     all     0.4531
# iprec_at_recall_0.40     all     0.4463
# iprec_at_recall_0.50     all     0.4463
# iprec_at_recall_0.60     all     0.2558
# iprec_at_recall_0.70     all     0.2558
# iprec_at_recall_0.80     all     0.2420
# iprec_at_recall_0.90     all     0.2420
# iprec_at_recall_1.00     all     0.2420
# P_5                      all     0.1067
# P_10                     all     0.0733
# P_15                     all     0.0489
# P_20                     all     0.0400
# P_30                     all     0.0311
# P_100                    all     0.0100
# P_200                    all     0.0050
# P_500                    all     0.0020
# P_1000                   all     0.0010
# relstring                all     0.0000
# recall_5                 all     0.3667
# recall_10                all     0.4556
# recall_15                all     0.4556
# recall_20                all     0.5222
# recall_30                all     0.6056
# recall_100               all     0.6278
# recall_200               all     0.6278
# recall_500               all     0.6278
# recall_1000              all     0.6278
# infAP                    all     0.3456
# gm_bpref                 all     0.0009
# Rprec_mult_0.20          all     0.4000
# Rprec_mult_0.40          all     0.4000
# Rprec_mult_0.60          all     0.3111
# Rprec_mult_0.80          all     0.3000
# Rprec_mult_1.00          all     0.3000
# Rprec_mult_1.20          all     0.1711
# Rprec_mult_1.40          all     0.1667
# Rprec_mult_1.60          all     0.1524
# Rprec_mult_1.80          all     0.1611
# Rprec_mult_2.00          all     0.1611
# utility                  all     -32.0000
# 11pt_avg                 all     0.3584
# binG                     all     0.3984
# G                        all     0.3984
# ndcg                     all     0.4340
# ndcg_rel                 all     0.4601
# Rndcg                    all     0.3791
# ndcg_cut_5               all     0.3529
# ndcg_cut_10              all     0.3922
# ndcg_cut_15              all     0.3922
# ndcg_cut_20              all     0.4082
# ndcg_cut_30              all     0.4278
# ndcg_cut_100             all     0.4340
# ndcg_cut_200             all     0.4340
# ndcg_cut_500             all     0.4340
# ndcg_cut_1000            all     0.4340
# map_cut_5                all     0.3167
# map_cut_10               all     0.3354
# map_cut_15               all     0.3354
# map_cut_20               all     0.3394
# map_cut_30               all     0.3441
# map_cut_100              all     0.3456
# map_cut_200              all     0.3456
# map_cut_500              all     0.3456
# map_cut_1000             all     0.3456
# relative_P_5             all     0.3667
# relative_P_10            all     0.4556
# relative_P_15            all     0.4556
# relative_P_20            all     0.5222
# relative_P_30            all     0.6056
# relative_P_100           all     0.6278
# relative_P_200           all     0.6278
# relative_P_500           all     0.6278
# relative_P_1000          all     0.6278
# success_1                all     0.4000
# success_5                all     0.4667
# success_10               all     0.6000
# set_P                    all     0.0397
# set_relative_P           all     0.6278
# set_recall               all     0.6278
# set_map                  all     0.0284
# set_F                    all     0.0684
# num_nonrel_judged_ret    all     330.0000

# %%
q3.print_rel_name('9')
# Out:
# ---------------------------Topic_id and Topic_phrase----------------------------------
# 9 genealogy searches
# ---------------------------Return documents----------------------------------
# 9 Q0 G00-30-0221651 0 14.375038 test
# 9 Q0 G00-79-2892445 1 13.424951 test
# 9 Q0 G00-26-1048210 2 12.392029 test
# 9 Q0 G00-55-0643570 3 11.497054 test
# 9 Q0 G00-08-1314254 4 10.777542 test
# 9 Q0 G00-08-0900666 5 10.777542 test
# 9 Q0 G00-02-1372443 6 10.777542 test
# 9 Q0 G00-88-2629440 7 10.405809 test
# 9 Q0 G00-95-3755341 8 10.405809 test
# 9 Q0 G00-06-1975174 9 10.405809 test
# 9 Q0 G00-59-0523165 10 10.405809 test
# 9 Q0 G00-24-0016657 11 10.353919 test
# 9 Q0 G00-95-3337324 12 10.353919 test
# 9 Q0 G00-01-2134408 13 10.181420 test
# 9 Q0 G00-33-1729611 14 10.070069 test
# 9 Q0 G00-01-2898660 15 9.879991 test
# 9 Q0 G00-91-3181951 16 9.815247 test
# 9 Q0 G00-43-3812747 17 9.743916 test
# 9 Q0 G00-21-1529615 18 9.435812 test
# 9 Q0 G00-67-1176122 19 9.147730 test
# 9 Q0 G00-08-3780534 20 9.093147 test
# 9 Q0 G00-49-2630728 21 8.601573 test
# 9 Q0 G00-00-2016453 22 8.542644 test
# 9 Q0 G00-59-3622783 23 7.592935 test
# 9 Q0 G00-48-2464830 24 6.138607 test
# 9 Q0 G00-22-3171818 25 6.031817 test
# 9 Q0 G00-21-2737022 26 4.565078 test
# ---------------------------Relevant documents----------------------------------
# 9 0 G00-91-3181951 1

# %% [markdown]
# ### Q3 (c): Provide answer to Q3 (c) here [markdown cell]

# %% [markdown]
# I applied the stemming method from NLTK's stemmers and lemmatizers, and added a RegexTokenizer to separate the sentence into words. I also used LowercaseFilter to convert the words to lower case and StopFilter to remove common stop words that are not relevant.
#
# The result of this improvement showed a higher MAP score of 0.3456 compared to the previous score of 0.1971. Additionally, the gm_ap score increased from 0.0015 to 0.0187, indicating that these improvements have improved the performance of Whoosh.
#
# The false negative example (G00-91-3181951) has been resolved and is now included in the sample results. However, false positive issues still persist, as 27 files were returned, none of which were in the qrels file, compared to only 2 files returned previously.

# %% [markdown]
# ### Q3 (d): Provide answer to Q3 (d) here [markdown cell]

# %% [markdown]
# yes

# %% [markdown]
# ### Q3 (e): Provide answer to Q3 (e) here [markdown cell]

# %% [markdown]
# Yes,while the performance of topic 28 has improved, as it now has a MAP score of 0.2262 compared to previously having a score of 0, other topics such as topic 26 have not seen improvement. The MAP score for topic 26 has dropped from 0.1111 to 0.0771, meaning its performance has worsened. Additionally, there are still false positive results and an increase in the number of false positive results compared to before.

# %% [markdown]
# ### Q3 (f): Provide answer to Q3 (f) here [markdown cell]

# %% [markdown]
# The overall performance of the system has improved as evidenced by the higher MAP score and gm_map score. Furthermore, the implementation of filters has allowed for the retrieval of more relevant documents compared to before, which has also fixed the previous false negative issue. However, this has also led to an increase in false positive results, but the overall performance improvement still stands.

# %% [markdown]
# ## Question 4

# %% [markdown]
# ### Q4 (a): Provide answer to Q4 (a) here [markdown cell]

# %% [markdown]
# Lack of relevance: If the search engine doesn't return relevant results to the user's query, then it can lead to low-performance.
#
# Insufficient data preprocessing: If the data is not cleaned, filtered, and preprocessed properly before indexing, it can lead to poor results.
#
# Poor tokenization: If the tokenization process is not effective, it can result in poor indexing and retrieval of documents.
#
# Lack of stemming/lemmatization: If the search engine is unable to understand words in different forms (e.g. plurals, conjugates), it can negatively impact performance.
#
# Unoptimized scoring functions: If the scoring function used by the search engine is not optimal, it can result in poor relevance ranking of the results.

# %% [markdown]
# ### Q4 (b): Write your code below

# %% [markdown]
# **1. The auto-grader will extract and use the following variables, DON'T change the their names:**
#
#       self.topic_file
#       self.qrels_file
#       self.document_dir
#       self.file_list
#       self.index_sys
#       self.query_parser
#       self.searcher
#
#
#
# **2. DON'T change the names of the already defined funtions**
# **3. DON'T change the py_trec_eval function**
# **4. DON'T change the class names including CustomFilter, IRSystem, IRQ2, IRQ3, IRQ4**
# **5. DON'T change the CustomFilter class and DON'T create any new custom filter class that is used to define Whoosh schema**

# %%
import nltk
nltk.download('omw-1.4')
# Out:
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# True

# %%
class IRQ4(IRSystem):
    def create_index(self):
        """
        INPUT:
            None
        OUTPUT:
            None
        
        NOTE: Please update self.index_sys which should have type whoosh.index.FileIndex
        """        
        # DON't change the name of 'index_sys'
        myFilter = RegexTokenizer() | LowercaseFilter() | IntraWordFilter() | StopFilter() | StemFilter()|CustomFilter(LancasterStemmer().stem)|CustomFilter(WordNetLemmatizer().lemmatize)
        mySchema = Schema(file_path = ID(stored=True),
                          file_content = TEXT(analyzer = myFilter))

         # Generate a temporary directory for the index
        indexDir = tempfile.mkdtemp()

        # create and return the index
        self.index_sys = index.create_in(indexDir, mySchema)


    def add_files(self):
        """
        INPUT:
            None
        OUTPUT:
            None
        
        NOTE: Add buffer to self.index_sys
        """
        # Build a list of files to index
        filesToIndex = [str(filePath) for filePath in Path(self.document_dir).glob("**/*") if filePath.is_file()]
        # open writer
        writer = writing.BufferedWriter(self.index_sys, period=None, limit=1000)
        try:
          # write each file to index
          for docNum, filePath in enumerate(filesToIndex):
              with open(filePath, "r", encoding="utf-8") as f:
                  fileContent = f.read()
                  writer.add_document(file_path = filePath,
                                      file_content = fileContent)

                  # print status every 1000 documents
                  if (docNum+1) % 1000 == 0:
                      print("already indexed:", docNum+1)
          print("done indexing.")

        finally:
            # close the index
            writer.close()

    def create_parser_searcher(self):
        """
        INPUT:
            None
        OUTPUT:
            None
        
        NOTE: Please update self.query_parser and self.searcher which should have type whoosh.qparser.default.QueryParser and whoosh.searching.Searcher respectively 
        """
        # define a query parser for the field "file_content" in the index
         # DON't change the names of 'query_parser' and 'searcher'
        self.query_parser = QueryParser("file_content", schema=self.index_sys.schema, group=qparser.OrGroup.factory(0.8))
        self.searcher = self.index_sys.searcher(weighting=scoring.BM25F(B=0.5,K1=5))

    def perform_search(self, topic_phrase):
        """
        INPUT:
            topic_phrase: string
        OUTPUT:
            topic_results: whoosh.searching.Results
        
        NOTE: Utilize self.query_parser and self.searcher to calculate the result for topic_phrase
        """
        sampleQuery = self.query_parser.parse(topic_phrase)
        topic_results = self.searcher.search(sampleQuery, limit=None)
        return topic_results

# %%
q4 = IRQ4("government")
# Out:
# already indexed: 1000
# already indexed: 2000
# already indexed: 3000
# already indexed: 4000
# done indexing.

# %%
q4.py_trec_eval()
# Out:
# num_q                    1       1.0000
# num_ret                  1       470.0000
# num_rel                  1       5.0000
# num_rel_ret              1       5.0000
# map                      1       0.0674
# gm_map                   1       -2.6978
# Rprec                    1       0.0000
# bpref                    1       0.0000
# recip_rank               1       0.0556
# iprec_at_recall_0.00     1       0.0938
# iprec_at_recall_0.10     1       0.0938
# iprec_at_recall_0.20     1       0.0938
# iprec_at_recall_0.30     1       0.0938
# iprec_at_recall_0.40     1       0.0938
# iprec_at_recall_0.50     1       0.0938
# iprec_at_recall_0.60     1       0.0938
# iprec_at_recall_0.70     1       0.0519
# iprec_at_recall_0.80     1       0.0519
# iprec_at_recall_0.90     1       0.0485
# iprec_at_recall_1.00     1       0.0485
# P_5                      1       0.0000
# P_10                     1       0.0000
# P_15                     1       0.0000
# P_20                     1       0.0500
# P_30                     1       0.0667
# P_100                    1       0.0400
# P_200                    1       0.0250
# P_500                    1       0.0100
# P_1000                   1       0.0050
# relstring                1       0.0000
# recall_5                 1       0.0000
# recall_10                1       0.0000
# recall_15                1       0.0000
# recall_20                1       0.2000
# recall_30                1       0.4000
# recall_100               1       0.8000
# recall_200               1       1.0000
# recall_500               1       1.0000
# recall_1000              1       1.0000
# infAP                    1       0.0674
# gm_bpref                 1       -11.5129
# Rprec_mult_0.20          1       0.0000
# Rprec_mult_0.40          1       0.0000
# Rprec_mult_0.60          1       0.0000
# Rprec_mult_0.80          1       0.0000
# Rprec_mult_1.00          1       0.0000
# Rprec_mult_1.20          1       0.0000
# Rprec_mult_1.40          1       0.0000
# Rprec_mult_1.60          1       0.0000
# Rprec_mult_1.80          1       0.0000
# Rprec_mult_2.00          1       0.0000
# utility                  1       -460.0000
# 11pt_avg                 1       0.0779
# binG                     1       0.1939
# G                        1       0.1939
# ndcg                     1       0.3256
# ndcg_rel                 1       0.2111
# Rndcg                    1       0.1628
# ndcg_cut_5               1       0.0000
# ndcg_cut_10              1       0.0000
# ndcg_cut_15              1       0.0000
# ndcg_cut_20              1       0.0798
# ndcg_cut_30              1       0.1538
# ndcg_cut_100             1       0.2750
# ndcg_cut_200             1       0.3256
# ndcg_cut_500             1       0.3256
# ndcg_cut_1000            1       0.3256
# map_cut_5                1       0.0000
# map_cut_10               1       0.0000
# map_cut_15               1       0.0000
# map_cut_20               1       0.0111
# map_cut_30               1       0.0285
# map_cut_100              1       0.0576
# map_cut_200              1       0.0674
# map_cut_500              1       0.0674
# map_cut_1000             1       0.0674
# relative_P_5             1       0.0000
# relative_P_10            1       0.0000
# relative_P_15            1       0.0000
# relative_P_20            1       0.2000
# relative_P_30            1       0.4000
# relative_P_100           1       0.8000
# relative_P_200           1       1.0000
# relative_P_500           1       1.0000
# relative_P_1000          1       1.0000
# success_1                1       0.0000
# success_5                1       0.0000
# success_10               1       0.0000
# set_P                    1       0.0106
# set_relative_P           1       1.0000
# set_recall               1       1.0000
# set_map                  1       0.0106
# set_F                    1       0.0211
# num_nonrel_judged_ret    1       68.0000
# num_q                    2       1.0000
# num_ret                  2       59.0000
# num_rel                  2       2.0000
# num_rel_ret              2       2.0000
# map                      2       0.5286
# gm_map                   2       -0.6376
# Rprec                    2       0.5000
# bpref                    2       0.5000
# recip_rank               2       1.0000
# iprec_at_recall_0.00     2       1.0000
# iprec_at_recall_0.10     2       1.0000
# iprec_at_recall_0.20     2       1.0000
# iprec_at_recall_0.30     2       1.0000
# iprec_at_recall_0.40     2       1.0000
# iprec_at_recall_0.50     2       1.0000
# iprec_at_recall_0.60     2       0.0571
# iprec_at_recall_0.70     2       0.0571
# iprec_at_recall_0.80     2       0.0571
# iprec_at_recall_0.90     2       0.0571
# iprec_at_recall_1.00     2       0.0571
# P_5                      2       0.2000
# P_10                     2       0.1000
# P_15                     2       0.0667
# P_20                     2       0.0500
# P_30                     2       0.0333
# P_100                    2       0.0200
# P_200                    2       0.0100
# P_500                    2       0.0040
# P_1000                   2       0.0020
# relstring                2       0.0000
# recall_5                 2       0.5000
# recall_10                2       0.5000
# recall_15                2       0.5000
# recall_20                2       0.5000
# recall_30                2       0.5000
# recall_100               2       1.0000
# recall_200               2       1.0000
# recall_500               2       1.0000
# recall_1000              2       1.0000
# infAP                    2       0.5286
# gm_bpref                 2       -0.6931
# Rprec_mult_0.20          2       1.0000
# Rprec_mult_0.40          2       1.0000
# Rprec_mult_0.60          2       0.5000
# Rprec_mult_0.80          2       0.5000
# Rprec_mult_1.00          2       0.5000
# Rprec_mult_1.20          2       0.3333
# Rprec_mult_1.40          2       0.3333
# Rprec_mult_1.60          2       0.2500
# Rprec_mult_1.80          2       0.2500
# Rprec_mult_2.00          2       0.2500
# utility                  2       -55.0000
# 11pt_avg                 2       0.5714
# binG                     2       0.5975
# G                        2       0.5975
# ndcg                     2       0.7317
# ndcg_rel                 2       0.8659
# Rndcg                    2       0.6724
# ndcg_cut_5               2       0.6131
# ndcg_cut_10              2       0.6131
# ndcg_cut_15              2       0.6131
# ndcg_cut_20              2       0.6131
# ndcg_cut_30              2       0.6131
# ndcg_cut_100             2       0.7317
# ndcg_cut_200             2       0.7317
# ndcg_cut_500             2       0.7317
# ndcg_cut_1000            2       0.7317
# map_cut_5                2       0.5000
# map_cut_10               2       0.5000
# map_cut_15               2       0.5000
# map_cut_20               2       0.5000
# map_cut_30               2       0.5000
# map_cut_100              2       0.5286
# map_cut_200              2       0.5286
# map_cut_500              2       0.5286
# map_cut_1000             2       0.5286
# relative_P_5             2       0.5000
# relative_P_10            2       0.5000
# relative_P_15            2       0.5000
# relative_P_20            2       0.5000
# relative_P_30            2       0.5000
# relative_P_100           2       1.0000
# relative_P_200           2       1.0000
# relative_P_500           2       1.0000
# relative_P_1000          2       1.0000
# success_1                2       1.0000
# success_5                2       1.0000
# success_10               2       1.0000
# set_P                    2       0.0339
# set_relative_P           2       1.0000
# set_recall               2       1.0000
# set_map                  2       0.0339
# set_F                    2       0.0656
# num_nonrel_judged_ret    2       28.0000
# num_q                    4       1.0000
# num_ret                  4       902.0000
# num_rel                  4       4.0000
# num_rel_ret              4       4.0000
# map                      4       0.5397
# gm_map                   4       -0.6168
# Rprec                    4       0.5000
# bpref                    4       0.5000
# recip_rank               4       1.0000
# iprec_at_recall_0.00     4       1.0000
# iprec_at_recall_0.10     4       1.0000
# iprec_at_recall_0.20     4       1.0000
# iprec_at_recall_0.30     4       1.0000
# iprec_at_recall_0.40     4       1.0000
# iprec_at_recall_0.50     4       1.0000
# iprec_at_recall_0.60     4       0.1111
# iprec_at_recall_0.70     4       0.1111
# iprec_at_recall_0.80     4       0.0476
# iprec_at_recall_0.90     4       0.0476
# iprec_at_recall_1.00     4       0.0476
# P_5                      4       0.4000
# P_10                     4       0.2000
# P_15                     4       0.1333
# P_20                     4       0.1000
# P_30                     4       0.1000
# P_100                    4       0.0400
# P_200                    4       0.0200
# P_500                    4       0.0080
# P_1000                   4       0.0040
# relstring                4       0.0000
# recall_5                 4       0.5000
# recall_10                4       0.5000
# recall_15                4       0.5000
# recall_20                4       0.5000
# recall_30                4       0.7500
# recall_100               4       1.0000
# recall_200               4       1.0000
# recall_500               4       1.0000
# recall_1000              4       1.0000
# infAP                    4       0.5397
# gm_bpref                 4       -0.6931
# Rprec_mult_0.20          4       1.0000
# Rprec_mult_0.40          4       1.0000
# Rprec_mult_0.60          4       0.6667
# Rprec_mult_0.80          4       0.5000
# Rprec_mult_1.00          4       0.5000
# Rprec_mult_1.20          4       0.4000
# Rprec_mult_1.40          4       0.3333
# Rprec_mult_1.60          4       0.2857
# Rprec_mult_1.80          4       0.2500
# Rprec_mult_2.00          4       0.2500
# utility                  4       -894.0000
# 11pt_avg                 4       0.5786
# binG                     4       0.5925
# G                        4       0.5925
# ndcg                     4       0.7788
# ndcg_rel                 4       0.8742
# Rndcg                    4       0.7077
# ndcg_cut_5               4       0.6367
# ndcg_cut_10              4       0.6367
# ndcg_cut_15              4       0.6367
# ndcg_cut_20              4       0.6367
# ndcg_cut_30              4       0.7179
# ndcg_cut_100             4       0.7788
# ndcg_cut_200             4       0.7788
# ndcg_cut_500             4       0.7788
# ndcg_cut_1000            4       0.7788
# map_cut_5                4       0.5000
# map_cut_10               4       0.5000
# map_cut_15               4       0.5000
# map_cut_20               4       0.5000
# map_cut_30               4       0.5278
# map_cut_100              4       0.5397
# map_cut_200              4       0.5397
# map_cut_500              4       0.5397
# map_cut_1000             4       0.5397
# relative_P_5             4       0.5000
# relative_P_10            4       0.5000
# relative_P_15            4       0.5000
# relative_P_20            4       0.5000
# relative_P_30            4       0.7500
# relative_P_100           4       1.0000
# relative_P_200           4       1.0000
# relative_P_500           4       1.0000
# relative_P_1000          4       1.0000
# success_1                4       1.0000
# success_5                4       1.0000
# success_10               4       1.0000
# set_P                    4       0.0044
# set_relative_P           4       1.0000
# set_recall               4       1.0000
# set_map                  4       0.0044
# set_F                    4       0.0088
# num_nonrel_judged_ret    4       76.0000
# num_q                    6       1.0000
# num_ret                  6       460.0000
# num_rel                  6       1.0000
# num_rel_ret              6       1.0000
# map                      6       0.1429
# gm_map                   6       -1.9459
# Rprec                    6       0.0000
# bpref                    6       0.0000
# recip_rank               6       0.1429
# iprec_at_recall_0.00     6       0.1429
# iprec_at_recall_0.10     6       0.1429
# iprec_at_recall_0.20     6       0.1429
# iprec_at_recall_0.30     6       0.1429
# iprec_at_recall_0.40     6       0.1429
# iprec_at_recall_0.50     6       0.1429
# iprec_at_recall_0.60     6       0.1429
# iprec_at_recall_0.70     6       0.1429
# iprec_at_recall_0.80     6       0.1429
# iprec_at_recall_0.90     6       0.1429
# iprec_at_recall_1.00     6       0.1429
# P_5                      6       0.0000
# P_10                     6       0.1000
# P_15                     6       0.0667
# P_20                     6       0.0500
# P_30                     6       0.0333
# P_100                    6       0.0100
# P_200                    6       0.0050
# P_500                    6       0.0020
# P_1000                   6       0.0010
# relstring                6       0.0000
# recall_5                 6       0.0000
# recall_10                6       1.0000
# recall_15                6       1.0000
# recall_20                6       1.0000
# recall_30                6       1.0000
# recall_100               6       1.0000
# recall_200               6       1.0000
# recall_500               6       1.0000
# recall_1000              6       1.0000
# infAP                    6       0.1429
# gm_bpref                 6       -11.5129
# Rprec_mult_0.20          6       0.0000
# Rprec_mult_0.40          6       0.0000
# Rprec_mult_0.60          6       0.0000
# Rprec_mult_0.80          6       0.0000
# Rprec_mult_1.00          6       0.0000
# Rprec_mult_1.20          6       0.0000
# Rprec_mult_1.40          6       0.0000
# Rprec_mult_1.60          6       0.0000
# Rprec_mult_1.80          6       0.0000
# Rprec_mult_2.00          6       0.0000
# utility                  6       -458.0000
# 11pt_avg                 6       0.1429
# binG                     6       0.3333
# G                        6       0.3333
# ndcg                     6       0.3333
# ndcg_rel                 6       0.3333
# Rndcg                    6       0.1667
# ndcg_cut_5               6       0.0000
# ndcg_cut_10              6       0.3333
# ndcg_cut_15              6       0.3333
# ndcg_cut_20              6       0.3333
# ndcg_cut_30              6       0.3333
# ndcg_cut_100             6       0.3333
# ndcg_cut_200             6       0.3333
# ndcg_cut_500             6       0.3333
# ndcg_cut_1000            6       0.3333
# map_cut_5                6       0.0000
# map_cut_10               6       0.1429
# map_cut_15               6       0.1429
# map_cut_20               6       0.1429
# map_cut_30               6       0.1429
# map_cut_100              6       0.1429
# map_cut_200              6       0.1429
# map_cut_500              6       0.1429
# map_cut_1000             6       0.1429
# relative_P_5             6       0.0000
# relative_P_10            6       1.0000
# relative_P_15            6       1.0000
# relative_P_20            6       1.0000
# relative_P_30            6       1.0000
# relative_P_100           6       1.0000
# relative_P_200           6       1.0000
# relative_P_500           6       1.0000
# relative_P_1000          6       1.0000
# success_1                6       0.0000
# success_5                6       0.0000
# success_10               6       1.0000
# set_P                    6       0.0022
# set_relative_P           6       1.0000
# set_recall               6       1.0000
# set_map                  6       0.0022
# set_F                    6       0.0043
# num_nonrel_judged_ret    6       96.0000
# num_q                    7       1.0000
# num_ret                  7       494.0000
# num_rel                  7       3.0000
# num_rel_ret              7       2.0000
# map                      7       0.2167
# gm_map                   7       -1.5294
# Rprec                    7       0.0000
# bpref                    7       0.0000
# recip_rank               7       0.2500
# iprec_at_recall_0.00     7       0.4000
# iprec_at_recall_0.10     7       0.4000
# iprec_at_recall_0.20     7       0.4000
# iprec_at_recall_0.30     7       0.4000
# iprec_at_recall_0.40     7       0.4000
# iprec_at_recall_0.50     7       0.4000
# iprec_at_recall_0.60     7       0.4000
# iprec_at_recall_0.70     7       0.4000
# iprec_at_recall_0.80     7       0.0000
# iprec_at_recall_0.90     7       0.0000
# iprec_at_recall_1.00     7       0.0000
# P_5                      7       0.4000
# P_10                     7       0.2000
# P_15                     7       0.1333
# P_20                     7       0.1000
# P_30                     7       0.0667
# P_100                    7       0.0200
# P_200                    7       0.0100
# P_500                    7       0.0040
# P_1000                   7       0.0020
# relstring                7       0.0000
# recall_5                 7       0.6667
# recall_10                7       0.6667
# recall_15                7       0.6667
# recall_20                7       0.6667
# recall_30                7       0.6667
# recall_100               7       0.6667
# recall_200               7       0.6667
# recall_500               7       0.6667
# recall_1000              7       0.6667
# infAP                    7       0.2167
# gm_bpref                 7       -11.5129
# Rprec_mult_0.20          7       0.0000
# Rprec_mult_0.40          7       0.0000
# Rprec_mult_0.60          7       0.0000
# Rprec_mult_0.80          7       0.0000
# Rprec_mult_1.00          7       0.0000
# Rprec_mult_1.20          7       0.2500
# Rprec_mult_1.40          7       0.4000
# Rprec_mult_1.60          7       0.4000
# Rprec_mult_1.80          7       0.3333
# Rprec_mult_2.00          7       0.3333
# utility                  7       -490.0000
# 11pt_avg                 7       0.2909
# binG                     7       0.2871
# G                        7       0.2871
# ndcg                     7       0.3836
# ndcg_rel                 7       0.3231
# Rndcg                    7       0.1918
# ndcg_cut_5               7       0.3836
# ndcg_cut_10              7       0.3836
# ndcg_cut_15              7       0.3836
# ndcg_cut_20              7       0.3836
# ndcg_cut_30              7       0.3836
# ndcg_cut_100             7       0.3836
# ndcg_cut_200             7       0.3836
# ndcg_cut_500             7       0.3836
# ndcg_cut_1000            7       0.3836
# map_cut_5                7       0.2167
# map_cut_10               7       0.2167
# map_cut_15               7       0.2167
# map_cut_20               7       0.2167
# map_cut_30               7       0.2167
# map_cut_100              7       0.2167
# map_cut_200              7       0.2167
# map_cut_500              7       0.2167
# map_cut_1000             7       0.2167
# relative_P_5             7       0.6667
# relative_P_10            7       0.6667
# relative_P_15            7       0.6667
# relative_P_20            7       0.6667
# relative_P_30            7       0.6667
# relative_P_100           7       0.6667
# relative_P_200           7       0.6667
# relative_P_500           7       0.6667
# relative_P_1000          7       0.6667
# success_1                7       0.0000
# success_5                7       1.0000
# success_10               7       1.0000
# set_P                    7       0.0040
# set_relative_P           7       0.6667
# set_recall               7       0.6667
# set_map                  7       0.0027
# set_F                    7       0.0080
# num_nonrel_judged_ret    7       96.0000
# num_q                    9       1.0000
# num_ret                  9       1856.0000
# num_rel                  9       1.0000
# num_rel_ret              9       1.0000
# map                      9       0.2500
# gm_map                   9       -1.3863
# Rprec                    9       0.0000
# bpref                    9       0.0000
# recip_rank               9       0.2500
# iprec_at_recall_0.00     9       0.2500
# iprec_at_recall_0.10     9       0.2500
# iprec_at_recall_0.20     9       0.2500
# iprec_at_recall_0.30     9       0.2500
# iprec_at_recall_0.40     9       0.2500
# iprec_at_recall_0.50     9       0.2500
# iprec_at_recall_0.60     9       0.2500
# iprec_at_recall_0.70     9       0.2500
# iprec_at_recall_0.80     9       0.2500
# iprec_at_recall_0.90     9       0.2500
# iprec_at_recall_1.00     9       0.2500
# P_5                      9       0.2000
# P_10                     9       0.1000
# P_15                     9       0.0667
# P_20                     9       0.0500
# P_30                     9       0.0333
# P_100                    9       0.0100
# P_200                    9       0.0050
# P_500                    9       0.0020
# P_1000                   9       0.0010
# relstring                9       0.0000
# recall_5                 9       1.0000
# recall_10                9       1.0000
# recall_15                9       1.0000
# recall_20                9       1.0000
# recall_30                9       1.0000
# recall_100               9       1.0000
# recall_200               9       1.0000
# recall_500               9       1.0000
# recall_1000              9       1.0000
# infAP                    9       0.2500
# gm_bpref                 9       -11.5129
# Rprec_mult_0.20          9       0.0000
# Rprec_mult_0.40          9       0.0000
# Rprec_mult_0.60          9       0.0000
# Rprec_mult_0.80          9       0.0000
# Rprec_mult_1.00          9       0.0000
# Rprec_mult_1.20          9       0.0000
# Rprec_mult_1.40          9       0.0000
# Rprec_mult_1.60          9       0.0000
# Rprec_mult_1.80          9       0.0000
# Rprec_mult_2.00          9       0.0000
# utility                  9       -1854.0000
# 11pt_avg                 9       0.2500
# binG                     9       0.4307
# G                        9       0.4307
# ndcg                     9       0.4307
# ndcg_rel                 9       0.4307
# Rndcg                    9       0.2153
# ndcg_cut_5               9       0.4307
# ndcg_cut_10              9       0.4307
# ndcg_cut_15              9       0.4307
# ndcg_cut_20              9       0.4307
# ndcg_cut_30              9       0.4307
# ndcg_cut_100             9       0.4307
# ndcg_cut_200             9       0.4307
# ndcg_cut_500             9       0.4307
# ndcg_cut_1000            9       0.4307
# map_cut_5                9       0.2500
# map_cut_10               9       0.2500
# map_cut_15               9       0.2500
# map_cut_20               9       0.2500
# map_cut_30               9       0.2500
# map_cut_100              9       0.2500
# map_cut_200              9       0.2500
# map_cut_500              9       0.2500
# map_cut_1000             9       0.2500
# relative_P_5             9       1.0000
# relative_P_10            9       1.0000
# relative_P_15            9       1.0000
# relative_P_20            9       1.0000
# relative_P_30            9       1.0000
# relative_P_100           9       1.0000
# relative_P_200           9       1.0000
# relative_P_500           9       1.0000
# relative_P_1000          9       1.0000
# success_1                9       0.0000
# success_5                9       1.0000
# success_10               9       1.0000
# set_P                    9       0.0005
# set_relative_P           9       1.0000
# set_recall               9       1.0000
# set_map                  9       0.0005
# set_F                    9       0.0011
# num_nonrel_judged_ret    9       170.0000
# num_q                    10      1.0000
# num_ret                  10      490.0000
# num_rel                  10      1.0000
# num_rel_ret              10      1.0000
# map                      10      0.3333
# gm_map                   10      -1.0986
# Rprec                    10      0.0000
# bpref                    10      0.0000
# recip_rank               10      0.3333
# iprec_at_recall_0.00     10      0.3333
# iprec_at_recall_0.10     10      0.3333
# iprec_at_recall_0.20     10      0.3333
# iprec_at_recall_0.30     10      0.3333
# iprec_at_recall_0.40     10      0.3333
# iprec_at_recall_0.50     10      0.3333
# iprec_at_recall_0.60     10      0.3333
# iprec_at_recall_0.70     10      0.3333
# iprec_at_recall_0.80     10      0.3333
# iprec_at_recall_0.90     10      0.3333
# iprec_at_recall_1.00     10      0.3333
# P_5                      10      0.2000
# P_10                     10      0.1000
# P_15                     10      0.0667
# P_20                     10      0.0500
# P_30                     10      0.0333
# P_100                    10      0.0100
# P_200                    10      0.0050
# P_500                    10      0.0020
# P_1000                   10      0.0010
# relstring                10      0.0000
# recall_5                 10      1.0000
# recall_10                10      1.0000
# recall_15                10      1.0000
# recall_20                10      1.0000
# recall_30                10      1.0000
# recall_100               10      1.0000
# recall_200               10      1.0000
# recall_500               10      1.0000
# recall_1000              10      1.0000
# infAP                    10      0.3333
# gm_bpref                 10      -11.5129
# Rprec_mult_0.20          10      0.0000
# Rprec_mult_0.40          10      0.0000
# Rprec_mult_0.60          10      0.0000
# Rprec_mult_0.80          10      0.0000
# Rprec_mult_1.00          10      0.0000
# Rprec_mult_1.20          10      0.0000
# Rprec_mult_1.40          10      0.0000
# Rprec_mult_1.60          10      0.0000
# Rprec_mult_1.80          10      0.0000
# Rprec_mult_2.00          10      0.0000
# utility                  10      -488.0000
# 11pt_avg                 10      0.3333
# binG                     10      0.5000
# G                        10      0.5000
# ndcg                     10      0.5000
# ndcg_rel                 10      0.5000
# Rndcg                    10      0.2500
# ndcg_cut_5               10      0.5000
# ndcg_cut_10              10      0.5000
# ndcg_cut_15              10      0.5000
# ndcg_cut_20              10      0.5000
# ndcg_cut_30              10      0.5000
# ndcg_cut_100             10      0.5000
# ndcg_cut_200             10      0.5000
# ndcg_cut_500             10      0.5000
# ndcg_cut_1000            10      0.5000
# map_cut_5                10      0.3333
# map_cut_10               10      0.3333
# map_cut_15               10      0.3333
# map_cut_20               10      0.3333
# map_cut_30               10      0.3333
# map_cut_100              10      0.3333
# map_cut_200              10      0.3333
# map_cut_500              10      0.3333
# map_cut_1000             10      0.3333
# relative_P_5             10      1.0000
# relative_P_10            10      1.0000
# relative_P_15            10      1.0000
# relative_P_20            10      1.0000
# relative_P_30            10      1.0000
# relative_P_100           10      1.0000
# relative_P_200           10      1.0000
# relative_P_500           10      1.0000
# relative_P_1000          10      1.0000
# success_1                10      0.0000
# success_5                10      1.0000
# success_10               10      1.0000
# set_P                    10      0.0020
# set_relative_P           10      1.0000
# set_recall               10      1.0000
# set_map                  10      0.0020
# set_F                    10      0.0041
# num_nonrel_judged_ret    10      82.0000
# num_q                    14      1.0000
# num_ret                  14      315.0000
# num_rel                  14      1.0000
# num_rel_ret              14      1.0000
# map                      14      1.0000
# gm_map                   14      0.0000
# Rprec                    14      1.0000
# bpref                    14      1.0000
# recip_rank               14      1.0000
# iprec_at_recall_0.00     14      1.0000
# iprec_at_recall_0.10     14      1.0000
# iprec_at_recall_0.20     14      1.0000
# iprec_at_recall_0.30     14      1.0000
# iprec_at_recall_0.40     14      1.0000
# iprec_at_recall_0.50     14      1.0000
# iprec_at_recall_0.60     14      1.0000
# iprec_at_recall_0.70     14      1.0000
# iprec_at_recall_0.80     14      1.0000
# iprec_at_recall_0.90     14      1.0000
# iprec_at_recall_1.00     14      1.0000
# P_5                      14      0.2000
# P_10                     14      0.1000
# P_15                     14      0.0667
# P_20                     14      0.0500
# P_30                     14      0.0333
# P_100                    14      0.0100
# P_200                    14      0.0050
# P_500                    14      0.0020
# P_1000                   14      0.0010
# relstring                14      0.0000
# recall_5                 14      1.0000
# recall_10                14      1.0000
# recall_15                14      1.0000
# recall_20                14      1.0000
# recall_30                14      1.0000
# recall_100               14      1.0000
# recall_200               14      1.0000
# recall_500               14      1.0000
# recall_1000              14      1.0000
# infAP                    14      1.0000
# gm_bpref                 14      0.0000
# Rprec_mult_0.20          14      1.0000
# Rprec_mult_0.40          14      1.0000
# Rprec_mult_0.60          14      1.0000
# Rprec_mult_0.80          14      1.0000
# Rprec_mult_1.00          14      1.0000
# Rprec_mult_1.20          14      0.5000
# Rprec_mult_1.40          14      0.5000
# Rprec_mult_1.60          14      0.5000
# Rprec_mult_1.80          14      0.5000
# Rprec_mult_2.00          14      0.5000
# utility                  14      -313.0000
# 11pt_avg                 14      1.0000
# binG                     14      1.0000
# G                        14      1.0000
# ndcg                     14      1.0000
# ndcg_rel                 14      1.0000
# Rndcg                    14      1.0000
# ndcg_cut_5               14      1.0000
# ndcg_cut_10              14      1.0000
# ndcg_cut_15              14      1.0000
# ndcg_cut_20              14      1.0000
# ndcg_cut_30              14      1.0000
# ndcg_cut_100             14      1.0000
# ndcg_cut_200             14      1.0000
# ndcg_cut_500             14      1.0000
# ndcg_cut_1000            14      1.0000
# map_cut_5                14      1.0000
# map_cut_10               14      1.0000
# map_cut_15               14      1.0000
# map_cut_20               14      1.0000
# map_cut_30               14      1.0000
# map_cut_100              14      1.0000
# map_cut_200              14      1.0000
# map_cut_500              14      1.0000
# map_cut_1000             14      1.0000
# relative_P_5             14      1.0000
# relative_P_10            14      1.0000
# relative_P_15            14      1.0000
# relative_P_20            14      1.0000
# relative_P_30            14      1.0000
# relative_P_100           14      1.0000
# relative_P_200           14      1.0000
# relative_P_500           14      1.0000
# relative_P_1000          14      1.0000
# success_1                14      1.0000
# success_5                14      1.0000
# success_10               14      1.0000
# set_P                    14      0.0032
# set_relative_P           14      1.0000
# set_recall               14      1.0000
# set_map                  14      0.0032
# set_F                    14      0.0063
# num_nonrel_judged_ret    14      101.0000
# num_q                    16      1.0000
# num_ret                  16      1111.0000
# num_rel                  16      7.0000
# num_rel_ret              16      7.0000
# map                      16      0.2432
# gm_map                   16      -1.4138
# Rprec                    16      0.1429
# bpref                    16      0.1224
# recip_rank               16      0.5000
# iprec_at_recall_0.00     16      0.5000
# iprec_at_recall_0.10     16      0.5000
# iprec_at_recall_0.20     16      0.2500
# iprec_at_recall_0.30     16      0.2500
# iprec_at_recall_0.40     16      0.2500
# iprec_at_recall_0.50     16      0.2353
# iprec_at_recall_0.60     16      0.2273
# iprec_at_recall_0.70     16      0.2273
# iprec_at_recall_0.80     16      0.1400
# iprec_at_recall_0.90     16      0.1400
# iprec_at_recall_1.00     16      0.1400
# P_5                      16      0.2000
# P_10                     16      0.2000
# P_15                     16      0.2000
# P_20                     16      0.2000
# P_30                     16      0.1667
# P_100                    16      0.0700
# P_200                    16      0.0350
# P_500                    16      0.0140
# P_1000                   16      0.0070
# relstring                16      0.0000
# recall_5                 16      0.1429
# recall_10                16      0.2857
# recall_15                16      0.4286
# recall_20                16      0.5714
# recall_30                16      0.7143
# recall_100               16      1.0000
# recall_200               16      1.0000
# recall_500               16      1.0000
# recall_1000              16      1.0000
# infAP                    16      0.2432
# gm_bpref                 16      -2.1001
# Rprec_mult_0.20          16      0.5000
# Rprec_mult_0.40          16      0.3333
# Rprec_mult_0.60          16      0.2000
# Rprec_mult_0.80          16      0.1667
# Rprec_mult_1.00          16      0.1429
# Rprec_mult_1.20          16      0.2222
# Rprec_mult_1.40          16      0.2000
# Rprec_mult_1.60          16      0.2500
# Rprec_mult_1.80          16      0.2308
# Rprec_mult_2.00          16      0.2143
# utility                  16      -1097.0000
# 11pt_avg                 16      0.2600
# binG                     16      0.2990
# G                        16      0.2990
# ndcg                     16      0.5548
# ndcg_rel                 16      0.4126
# Rndcg                    16      0.3641
# ndcg_cut_5               16      0.2140
# ndcg_cut_10              16      0.2562
# ndcg_cut_15              16      0.3305
# ndcg_cut_20              16      0.3964
# ndcg_cut_30              16      0.4571
# ndcg_cut_100             16      0.5548
# ndcg_cut_200             16      0.5548
# ndcg_cut_500             16      0.5548
# ndcg_cut_1000            16      0.5548
# map_cut_5                16      0.0714
# map_cut_10               16      0.1032
# map_cut_15               16      0.1389
# map_cut_20               16      0.1725
# map_cut_30               16      0.2050
# map_cut_100              16      0.2432
# map_cut_200              16      0.2432
# map_cut_500              16      0.2432
# map_cut_1000             16      0.2432
# relative_P_5             16      0.2000
# relative_P_10            16      0.2857
# relative_P_15            16      0.4286
# relative_P_20            16      0.5714
# relative_P_30            16      0.7143
# relative_P_100           16      1.0000
# relative_P_200           16      1.0000
# relative_P_500           16      1.0000
# relative_P_1000          16      1.0000
# success_1                16      0.0000
# success_5                16      1.0000
# success_10               16      1.0000
# set_P                    16      0.0063
# set_relative_P           16      1.0000
# set_recall               16      1.0000
# set_map                  16      0.0063
# set_F                    16      0.0125
# num_nonrel_judged_ret    16      86.0000
# num_q                    18      1.0000
# num_ret                  18      32.0000
# num_rel                  18      1.0000
# num_rel_ret              18      1.0000
# map                      18      1.0000
# gm_map                   18      0.0000
# Rprec                    18      1.0000
# bpref                    18      1.0000
# recip_rank               18      1.0000
# iprec_at_recall_0.00     18      1.0000
# iprec_at_recall_0.10     18      1.0000
# iprec_at_recall_0.20     18      1.0000
# iprec_at_recall_0.30     18      1.0000
# iprec_at_recall_0.40     18      1.0000
# iprec_at_recall_0.50     18      1.0000
# iprec_at_recall_0.60     18      1.0000
# iprec_at_recall_0.70     18      1.0000
# iprec_at_recall_0.80     18      1.0000
# iprec_at_recall_0.90     18      1.0000
# iprec_at_recall_1.00     18      1.0000
# P_5                      18      0.2000
# P_10                     18      0.1000
# P_15                     18      0.0667
# P_20                     18      0.0500
# P_30                     18      0.0333
# P_100                    18      0.0100
# P_200                    18      0.0050
# P_500                    18      0.0020
# P_1000                   18      0.0010
# relstring                18      0.0000
# recall_5                 18      1.0000
# recall_10                18      1.0000
# recall_15                18      1.0000
# recall_20                18      1.0000
# recall_30                18      1.0000
# recall_100               18      1.0000
# recall_200               18      1.0000
# recall_500               18      1.0000
# recall_1000              18      1.0000
# infAP                    18      1.0000
# gm_bpref                 18      0.0000
# Rprec_mult_0.20          18      1.0000
# Rprec_mult_0.40          18      1.0000
# Rprec_mult_0.60          18      1.0000
# Rprec_mult_0.80          18      1.0000
# Rprec_mult_1.00          18      1.0000
# Rprec_mult_1.20          18      0.5000
# Rprec_mult_1.40          18      0.5000
# Rprec_mult_1.60          18      0.5000
# Rprec_mult_1.80          18      0.5000
# Rprec_mult_2.00          18      0.5000
# utility                  18      -30.0000
# 11pt_avg                 18      1.0000
# binG                     18      1.0000
# G                        18      1.0000
# ndcg                     18      1.0000
# ndcg_rel                 18      1.0000
# Rndcg                    18      1.0000
# ndcg_cut_5               18      1.0000
# ndcg_cut_10              18      1.0000
# ndcg_cut_15              18      1.0000
# ndcg_cut_20              18      1.0000
# ndcg_cut_30              18      1.0000
# ndcg_cut_100             18      1.0000
# ndcg_cut_200             18      1.0000
# ndcg_cut_500             18      1.0000
# ndcg_cut_1000            18      1.0000
# map_cut_5                18      1.0000
# map_cut_10               18      1.0000
# map_cut_15               18      1.0000
# map_cut_20               18      1.0000
# map_cut_30               18      1.0000
# map_cut_100              18      1.0000
# map_cut_200              18      1.0000
# map_cut_500              18      1.0000
# map_cut_1000             18      1.0000
# relative_P_5             18      1.0000
# relative_P_10            18      1.0000
# relative_P_15            18      1.0000
# relative_P_20            18      1.0000
# relative_P_30            18      1.0000
# relative_P_100           18      1.0000
# relative_P_200           18      1.0000
# relative_P_500           18      1.0000
# relative_P_1000          18      1.0000
# success_1                18      1.0000
# success_5                18      1.0000
# success_10               18      1.0000
# set_P                    18      0.0312
# set_relative_P           18      1.0000
# set_recall               18      1.0000
# set_map                  18      0.0312
# set_F                    18      0.0606
# num_nonrel_judged_ret    18      30.0000
# num_q                    19      1.0000
# num_ret                  19      628.0000
# num_rel                  19      2.0000
# num_rel_ret              19      1.0000
# map                      19      0.5000
# gm_map                   19      -0.6931
# Rprec                    19      0.5000
# bpref                    19      0.5000
# recip_rank               19      1.0000
# iprec_at_recall_0.00     19      1.0000
# iprec_at_recall_0.10     19      1.0000
# iprec_at_recall_0.20     19      1.0000
# iprec_at_recall_0.30     19      1.0000
# iprec_at_recall_0.40     19      1.0000
# iprec_at_recall_0.50     19      1.0000
# iprec_at_recall_0.60     19      0.0000
# iprec_at_recall_0.70     19      0.0000
# iprec_at_recall_0.80     19      0.0000
# iprec_at_recall_0.90     19      0.0000
# iprec_at_recall_1.00     19      0.0000
# P_5                      19      0.2000
# P_10                     19      0.1000
# P_15                     19      0.0667
# P_20                     19      0.0500
# P_30                     19      0.0333
# P_100                    19      0.0100
# P_200                    19      0.0050
# P_500                    19      0.0020
# P_1000                   19      0.0010
# relstring                19      0.0000
# recall_5                 19      0.5000
# recall_10                19      0.5000
# recall_15                19      0.5000
# recall_20                19      0.5000
# recall_30                19      0.5000
# recall_100               19      0.5000
# recall_200               19      0.5000
# recall_500               19      0.5000
# recall_1000              19      0.5000
# infAP                    19      0.5000
# gm_bpref                 19      -0.6931
# Rprec_mult_0.20          19      1.0000
# Rprec_mult_0.40          19      1.0000
# Rprec_mult_0.60          19      0.5000
# Rprec_mult_0.80          19      0.5000
# Rprec_mult_1.00          19      0.5000
# Rprec_mult_1.20          19      0.3333
# Rprec_mult_1.40          19      0.3333
# Rprec_mult_1.60          19      0.2500
# Rprec_mult_1.80          19      0.2500
# Rprec_mult_2.00          19      0.2500
# utility                  19      -626.0000
# 11pt_avg                 19      0.5455
# binG                     19      0.5000
# G                        19      0.5000
# ndcg                     19      0.6131
# ndcg_rel                 19      0.8066
# Rndcg                    19      0.6131
# ndcg_cut_5               19      0.6131
# ndcg_cut_10              19      0.6131
# ndcg_cut_15              19      0.6131
# ndcg_cut_20              19      0.6131
# ndcg_cut_30              19      0.6131
# ndcg_cut_100             19      0.6131
# ndcg_cut_200             19      0.6131
# ndcg_cut_500             19      0.6131
# ndcg_cut_1000            19      0.6131
# map_cut_5                19      0.5000
# map_cut_10               19      0.5000
# map_cut_15               19      0.5000
# map_cut_20               19      0.5000
# map_cut_30               19      0.5000
# map_cut_100              19      0.5000
# map_cut_200              19      0.5000
# map_cut_500              19      0.5000
# map_cut_1000             19      0.5000
# relative_P_5             19      0.5000
# relative_P_10            19      0.5000
# relative_P_15            19      0.5000
# relative_P_20            19      0.5000
# relative_P_30            19      0.5000
# relative_P_100           19      0.5000
# relative_P_200           19      0.5000
# relative_P_500           19      0.5000
# relative_P_1000          19      0.5000
# success_1                19      1.0000
# success_5                19      1.0000
# success_10               19      1.0000
# set_P                    19      0.0016
# set_relative_P           19      0.5000
# set_recall               19      0.5000
# set_map                  19      0.0008
# set_F                    19      0.0032
# num_nonrel_judged_ret    19      84.0000
# num_q                    22      1.0000
# num_ret                  22      468.0000
# num_rel                  22      1.0000
# num_rel_ret              22      1.0000
# map                      22      0.0370
# gm_map                   22      -3.2958
# Rprec                    22      0.0000
# bpref                    22      0.0000
# recip_rank               22      0.0370
# iprec_at_recall_0.00     22      0.0370
# iprec_at_recall_0.10     22      0.0370
# iprec_at_recall_0.20     22      0.0370
# iprec_at_recall_0.30     22      0.0370
# iprec_at_recall_0.40     22      0.0370
# iprec_at_recall_0.50     22      0.0370
# iprec_at_recall_0.60     22      0.0370
# iprec_at_recall_0.70     22      0.0370
# iprec_at_recall_0.80     22      0.0370
# iprec_at_recall_0.90     22      0.0370
# iprec_at_recall_1.00     22      0.0370
# P_5                      22      0.0000
# P_10                     22      0.0000
# P_15                     22      0.0000
# P_20                     22      0.0000
# P_30                     22      0.0333
# P_100                    22      0.0100
# P_200                    22      0.0050
# P_500                    22      0.0020
# P_1000                   22      0.0010
# relstring                22      0.0000
# recall_5                 22      0.0000
# recall_10                22      0.0000
# recall_15                22      0.0000
# recall_20                22      0.0000
# recall_30                22      1.0000
# recall_100               22      1.0000
# recall_200               22      1.0000
# recall_500               22      1.0000
# recall_1000              22      1.0000
# infAP                    22      0.0370
# gm_bpref                 22      -11.5129
# Rprec_mult_0.20          22      0.0000
# Rprec_mult_0.40          22      0.0000
# Rprec_mult_0.60          22      0.0000
# Rprec_mult_0.80          22      0.0000
# Rprec_mult_1.00          22      0.0000
# Rprec_mult_1.20          22      0.0000
# Rprec_mult_1.40          22      0.0000
# Rprec_mult_1.60          22      0.0000
# Rprec_mult_1.80          22      0.0000
# Rprec_mult_2.00          22      0.0000
# utility                  22      -466.0000
# 11pt_avg                 22      0.0370
# binG                     22      0.2080
# G                        22      0.2080
# ndcg                     22      0.2080
# ndcg_rel                 22      0.2080
# Rndcg                    22      0.1040
# ndcg_cut_5               22      0.0000
# ndcg_cut_10              22      0.0000
# ndcg_cut_15              22      0.0000
# ndcg_cut_20              22      0.0000
# ndcg_cut_30              22      0.2080
# ndcg_cut_100             22      0.2080
# ndcg_cut_200             22      0.2080
# ndcg_cut_500             22      0.2080
# ndcg_cut_1000            22      0.2080
# map_cut_5                22      0.0000
# map_cut_10               22      0.0000
# map_cut_15               22      0.0000
# map_cut_20               22      0.0000
# map_cut_30               22      0.0370
# map_cut_100              22      0.0370
# map_cut_200              22      0.0370
# map_cut_500              22      0.0370
# map_cut_1000             22      0.0370
# relative_P_5             22      0.0000
# relative_P_10            22      0.0000
# relative_P_15            22      0.0000
# relative_P_20            22      0.0000
# relative_P_30            22      1.0000
# relative_P_100           22      1.0000
# relative_P_200           22      1.0000
# relative_P_500           22      1.0000
# relative_P_1000          22      1.0000
# success_1                22      0.0000
# success_5                22      0.0000
# success_10               22      0.0000
# set_P                    22      0.0021
# set_relative_P           22      1.0000
# set_recall               22      1.0000
# set_map                  22      0.0021
# set_F                    22      0.0043
# num_nonrel_judged_ret    22      128.0000
# num_q                    24      1.0000
# num_ret                  24      690.0000
# num_rel                  24      1.0000
# num_rel_ret              24      1.0000
# map                      24      1.0000
# gm_map                   24      0.0000
# Rprec                    24      1.0000
# bpref                    24      1.0000
# recip_rank               24      1.0000
# iprec_at_recall_0.00     24      1.0000
# iprec_at_recall_0.10     24      1.0000
# iprec_at_recall_0.20     24      1.0000
# iprec_at_recall_0.30     24      1.0000
# iprec_at_recall_0.40     24      1.0000
# iprec_at_recall_0.50     24      1.0000
# iprec_at_recall_0.60     24      1.0000
# iprec_at_recall_0.70     24      1.0000
# iprec_at_recall_0.80     24      1.0000
# iprec_at_recall_0.90     24      1.0000
# iprec_at_recall_1.00     24      1.0000
# P_5                      24      0.2000
# P_10                     24      0.1000
# P_15                     24      0.0667
# P_20                     24      0.0500
# P_30                     24      0.0333
# P_100                    24      0.0100
# P_200                    24      0.0050
# P_500                    24      0.0020
# P_1000                   24      0.0010
# relstring                24      0.0000
# recall_5                 24      1.0000
# recall_10                24      1.0000
# recall_15                24      1.0000
# recall_20                24      1.0000
# recall_30                24      1.0000
# recall_100               24      1.0000
# recall_200               24      1.0000
# recall_500               24      1.0000
# recall_1000              24      1.0000
# infAP                    24      1.0000
# gm_bpref                 24      0.0000
# Rprec_mult_0.20          24      1.0000
# Rprec_mult_0.40          24      1.0000
# Rprec_mult_0.60          24      1.0000
# Rprec_mult_0.80          24      1.0000
# Rprec_mult_1.00          24      1.0000
# Rprec_mult_1.20          24      0.5000
# Rprec_mult_1.40          24      0.5000
# Rprec_mult_1.60          24      0.5000
# Rprec_mult_1.80          24      0.5000
# Rprec_mult_2.00          24      0.5000
# utility                  24      -688.0000
# 11pt_avg                 24      1.0000
# binG                     24      1.0000
# G                        24      1.0000
# ndcg                     24      1.0000
# ndcg_rel                 24      1.0000
# Rndcg                    24      1.0000
# ndcg_cut_5               24      1.0000
# ndcg_cut_10              24      1.0000
# ndcg_cut_15              24      1.0000
# ndcg_cut_20              24      1.0000
# ndcg_cut_30              24      1.0000
# ndcg_cut_100             24      1.0000
# ndcg_cut_200             24      1.0000
# ndcg_cut_500             24      1.0000
# ndcg_cut_1000            24      1.0000
# map_cut_5                24      1.0000
# map_cut_10               24      1.0000
# map_cut_15               24      1.0000
# map_cut_20               24      1.0000
# map_cut_30               24      1.0000
# map_cut_100              24      1.0000
# map_cut_200              24      1.0000
# map_cut_500              24      1.0000
# map_cut_1000             24      1.0000
# relative_P_5             24      1.0000
# relative_P_10            24      1.0000
# relative_P_15            24      1.0000
# relative_P_20            24      1.0000
# relative_P_30            24      1.0000
# relative_P_100           24      1.0000
# relative_P_200           24      1.0000
# relative_P_500           24      1.0000
# relative_P_1000          24      1.0000
# success_1                24      1.0000
# success_5                24      1.0000
# success_10               24      1.0000
# set_P                    24      0.0014
# set_relative_P           24      1.0000
# set_recall               24      1.0000
# set_map                  24      0.0014
# set_F                    24      0.0029
# num_nonrel_judged_ret    24      119.0000
# num_q                    26      1.0000
# num_ret                  26      589.0000
# num_rel                  26      3.0000
# num_rel_ret              26      3.0000
# map                      26      0.0875
# gm_map                   26      -2.4361
# Rprec                    26      0.0000
# bpref                    26      0.0000
# recip_rank               26      0.1250
# iprec_at_recall_0.00     26      0.1250
# iprec_at_recall_0.10     26      0.1250
# iprec_at_recall_0.20     26      0.1250
# iprec_at_recall_0.30     26      0.1250
# iprec_at_recall_0.40     26      0.0750
# iprec_at_recall_0.50     26      0.0750
# iprec_at_recall_0.60     26      0.0750
# iprec_at_recall_0.70     26      0.0750
# iprec_at_recall_0.80     26      0.0750
# iprec_at_recall_0.90     26      0.0750
# iprec_at_recall_1.00     26      0.0750
# P_5                      26      0.0000
# P_10                     26      0.1000
# P_15                     26      0.0667
# P_20                     26      0.0500
# P_30                     26      0.0333
# P_100                    26      0.0300
# P_200                    26      0.0150
# P_500                    26      0.0060
# P_1000                   26      0.0030
# relstring                26      0.0000
# recall_5                 26      0.0000
# recall_10                26      0.3333
# recall_15                26      0.3333
# recall_20                26      0.3333
# recall_30                26      0.3333
# recall_100               26      1.0000
# recall_200               26      1.0000
# recall_500               26      1.0000
# recall_1000              26      1.0000
# infAP                    26      0.0875
# gm_bpref                 26      -11.5129
# Rprec_mult_0.20          26      0.0000
# Rprec_mult_0.40          26      0.0000
# Rprec_mult_0.60          26      0.0000
# Rprec_mult_0.80          26      0.0000
# Rprec_mult_1.00          26      0.0000
# Rprec_mult_1.20          26      0.0000
# Rprec_mult_1.40          26      0.0000
# Rprec_mult_1.60          26      0.0000
# Rprec_mult_1.80          26      0.0000
# Rprec_mult_2.00          26      0.0000
# utility                  26      -583.0000
# 11pt_avg                 26      0.0932
# binG                     26      0.2349
# G                        26      0.2349
# ndcg                     26      0.3287
# ndcg_rel                 26      0.2393
# Rndcg                    26      0.1643
# ndcg_cut_5               26      0.0000
# ndcg_cut_10              26      0.1480
# ndcg_cut_15              26      0.1480
# ndcg_cut_20              26      0.1480
# ndcg_cut_30              26      0.1480
# ndcg_cut_100             26      0.3287
# ndcg_cut_200             26      0.3287
# ndcg_cut_500             26      0.3287
# ndcg_cut_1000            26      0.3287
# map_cut_5                26      0.0000
# map_cut_10               26      0.0417
# map_cut_15               26      0.0417
# map_cut_20               26      0.0417
# map_cut_30               26      0.0417
# map_cut_100              26      0.0875
# map_cut_200              26      0.0875
# map_cut_500              26      0.0875
# map_cut_1000             26      0.0875
# relative_P_5             26      0.0000
# relative_P_10            26      0.3333
# relative_P_15            26      0.3333
# relative_P_20            26      0.3333
# relative_P_30            26      0.3333
# relative_P_100           26      1.0000
# relative_P_200           26      1.0000
# relative_P_500           26      1.0000
# relative_P_1000          26      1.0000
# success_1                26      0.0000
# success_5                26      0.0000
# success_10               26      1.0000
# set_P                    26      0.0051
# set_relative_P           26      1.0000
# set_recall               26      1.0000
# set_map                  26      0.0051
# set_F                    26      0.0101
# num_nonrel_judged_ret    26      115.0000
# num_q                    28      1.0000
# num_ret                  28      1071.0000
# num_rel                  28      2.0000
# num_rel_ret              28      2.0000
# map                      28      0.2111
# gm_map                   28      -1.5554
# Rprec                    28      0.0000
# bpref                    28      0.0000
# recip_rank               28      0.2000
# iprec_at_recall_0.00     28      0.2222
# iprec_at_recall_0.10     28      0.2222
# iprec_at_recall_0.20     28      0.2222
# iprec_at_recall_0.30     28      0.2222
# iprec_at_recall_0.40     28      0.2222
# iprec_at_recall_0.50     28      0.2222
# iprec_at_recall_0.60     28      0.2222
# iprec_at_recall_0.70     28      0.2222
# iprec_at_recall_0.80     28      0.2222
# iprec_at_recall_0.90     28      0.2222
# iprec_at_recall_1.00     28      0.2222
# P_5                      28      0.2000
# P_10                     28      0.2000
# P_15                     28      0.1333
# P_20                     28      0.1000
# P_30                     28      0.0667
# P_100                    28      0.0200
# P_200                    28      0.0100
# P_500                    28      0.0040
# P_1000                   28      0.0020
# relstring                28      0.0000
# recall_5                 28      0.5000
# recall_10                28      1.0000
# recall_15                28      1.0000
# recall_20                28      1.0000
# recall_30                28      1.0000
# recall_100               28      1.0000
# recall_200               28      1.0000
# recall_500               28      1.0000
# recall_1000              28      1.0000
# infAP                    28      0.2111
# gm_bpref                 28      -11.5129
# Rprec_mult_0.20          28      0.0000
# Rprec_mult_0.40          28      0.0000
# Rprec_mult_0.60          28      0.0000
# Rprec_mult_0.80          28      0.0000
# Rprec_mult_1.00          28      0.0000
# Rprec_mult_1.20          28      0.0000
# Rprec_mult_1.40          28      0.0000
# Rprec_mult_1.60          28      0.0000
# Rprec_mult_1.80          28      0.0000
# Rprec_mult_2.00          28      0.0000
# utility                  28      -1067.0000
# 11pt_avg                 28      0.2222
# binG                     28      0.3512
# G                        28      0.3512
# ndcg                     28      0.4218
# ndcg_rel                 28      0.3295
# Rndcg                    28      0.2109
# ndcg_cut_5               28      0.2372
# ndcg_cut_10              28      0.4218
# ndcg_cut_15              28      0.4218
# ndcg_cut_20              28      0.4218
# ndcg_cut_30              28      0.4218
# ndcg_cut_100             28      0.4218
# ndcg_cut_200             28      0.4218
# ndcg_cut_500             28      0.4218
# ndcg_cut_1000            28      0.4218
# map_cut_5                28      0.1000
# map_cut_10               28      0.2111
# map_cut_15               28      0.2111
# map_cut_20               28      0.2111
# map_cut_30               28      0.2111
# map_cut_100              28      0.2111
# map_cut_200              28      0.2111
# map_cut_500              28      0.2111
# map_cut_1000             28      0.2111
# relative_P_5             28      0.5000
# relative_P_10            28      1.0000
# relative_P_15            28      1.0000
# relative_P_20            28      1.0000
# relative_P_30            28      1.0000
# relative_P_100           28      1.0000
# relative_P_200           28      1.0000
# relative_P_500           28      1.0000
# relative_P_1000          28      1.0000
# success_1                28      0.0000
# success_5                28      1.0000
# success_10               28      1.0000
# set_P                    28      0.0019
# set_relative_P           28      1.0000
# set_recall               28      1.0000
# set_map                  28      0.0019
# set_F                    28      0.0037
# num_nonrel_judged_ret    28      107.0000
# num_q                    all     15.0000
# num_ret                  all     9635.0000
# num_rel                  all     35.0000
# num_rel_ret              all     33.0000
# map                      all     0.4105
# gm_map                   all     0.2761
# Rprec                    all     0.3095
# bpref                    all     0.3082
# recip_rank               all     0.5263
# iprec_at_recall_0.00     all     0.5403
# iprec_at_recall_0.10     all     0.5403
# iprec_at_recall_0.20     all     0.5236
# iprec_at_recall_0.30     all     0.5236
# iprec_at_recall_0.40     all     0.5203
# iprec_at_recall_0.50     all     0.5193
# iprec_at_recall_0.60     all     0.3300
# iprec_at_recall_0.70     all     0.3272
# iprec_at_recall_0.80     all     0.2905
# iprec_at_recall_0.90     all     0.2903
# iprec_at_recall_1.00     all     0.2903
# P_5                      all     0.1733
# P_10                     all     0.1133
# P_15                     all     0.0800
# P_20                     all     0.0667
# P_30                     all     0.0533
# P_100                    all     0.0213
# P_200                    all     0.0110
# P_500                    all     0.0044
# P_1000                   all     0.0022
# relstring                all     0.0000
# recall_5                 all     0.5206
# recall_10                all     0.6524
# recall_15                all     0.6619
# recall_20                all     0.6848
# recall_30                all     0.7910
# recall_100               all     0.9311
# recall_200               all     0.9444
# recall_500               all     0.9444
# recall_1000              all     0.9444
# infAP                    all     0.4105
# gm_bpref                 all     0.0016
# Rprec_mult_0.20          all     0.4333
# Rprec_mult_0.40          all     0.4222
# Rprec_mult_0.60          all     0.3244
# Rprec_mult_0.80          all     0.3111
# Rprec_mult_1.00          all     0.3095
# Rprec_mult_1.20          all     0.2026
# Rprec_mult_1.40          all     0.2067
# Rprec_mult_1.60          all     0.1957
# Rprec_mult_1.80          all     0.1876
# Rprec_mult_2.00          all     0.1865
# utility                  all     -637.9333
# 11pt_avg                 all     0.4269
# binG                     all     0.5019
# G                        all     0.5019
# ndcg                     all     0.5740
# ndcg_rel                 all     0.5689
# Rndcg                    all     0.4549
# ndcg_cut_5               all     0.4419
# ndcg_cut_10              all     0.4891
# ndcg_cut_15              all     0.4941
# ndcg_cut_20              all     0.5038
# ndcg_cut_30              all     0.5320
# ndcg_cut_100             all     0.5706
# ndcg_cut_200             all     0.5740
# ndcg_cut_500             all     0.5740
# ndcg_cut_1000            all     0.5740
# map_cut_5                all     0.3648
# map_cut_10               all     0.3866
# map_cut_15               all     0.3890
# map_cut_20               all     0.3919
# map_cut_30               all     0.3996
# map_cut_100              all     0.4098
# map_cut_200              all     0.4105
# map_cut_500              all     0.4105
# map_cut_1000             all     0.4105
# relative_P_5             all     0.5244
# relative_P_10            all     0.6524
# relative_P_15            all     0.6619
# relative_P_20            all     0.6848
# relative_P_30            all     0.7910
# relative_P_100           all     0.9311
# relative_P_200           all     0.9444
# relative_P_500           all     0.9444
# relative_P_1000          all     0.9444
# success_1                all     0.4000
# success_5                all     0.7333
# success_10               all     0.8667
# set_P                    all     0.0074
# set_relative_P           all     0.9444
# set_recall               all     0.9444
# set_map                  all     0.0072
# set_F                    all     0.0144
# num_nonrel_judged_ret    all     1386.0000

# %%
q4.print_rel_name('9')
# Out:
# ---------------------------Topic_id and Topic_phrase----------------------------------
# 9 genealogy searches
# ---------------------------Return documents----------------------------------
# 9 Q0 G00-30-0221651 0 13.704827 test
# 9 Q0 G00-79-2892445 1 13.065959 test
# 9 Q0 G00-26-1048210 2 9.465239 test
# 9 Q0 G00-91-3181951 3 8.414106 test
# 9 Q0 G00-55-0643570 4 7.484404 test
# 9 Q0 G00-08-1314254 5 7.098417 test
# 9 Q0 G00-08-0900666 6 7.098417 test
# 9 Q0 G00-02-1372443 7 7.098417 test
# 9 Q0 G00-43-3812747 8 6.449216 test
# 9 Q0 G00-24-0016657 9 6.324979 test
# 9 Q0 G00-95-3337324 10 6.324979 test
# 9 Q0 G00-01-2134408 11 6.217790 test
# 9 Q0 G00-48-2464830 12 5.933189 test
# 9 Q0 G00-28-3598417 13 5.728867 test
# 9 Q0 G00-01-2898660 14 5.706292 test
# 9 Q0 G00-88-2629440 15 5.584208 test
# 9 Q0 G00-95-3755341 16 5.584208 test
# 9 Q0 G00-06-1975174 17 5.584208 test
# 9 Q0 G00-59-0523165 18 5.584208 test
# 9 Q0 G00-59-3622783 19 5.522089 test
# 9 Q0 G00-33-1729611 20 5.411123 test
# 9 Q0 G00-08-3780534 21 5.250793 test
# 9 Q0 G00-49-2630728 22 5.240705 test
# 9 Q0 G00-21-1529615 23 5.084908 test
# 9 Q0 G00-67-1176122 24 4.937070 test
# 9 Q0 G00-13-3039445 25 4.792327 test
# 9 Q0 G00-73-2660773 26 4.783762 test
# 9 Q0 G00-65-3011991 27 4.715695 test
# 9 Q0 G00-89-3859322 28 4.694380 test
# 9 Q0 G00-68-2708425 29 4.655718 test
# 9 Q0 G00-00-2016453 30 4.627219 test
# 9 Q0 G00-20-1794595 31 4.582383 test
# 9 Q0 G00-44-2717261 32 4.547192 test
# 9 Q0 G00-50-1467118 33 4.532931 test
# 9 Q0 G00-11-1749431 34 4.462621 test
# 9 Q0 G00-73-3632837 35 4.434616 test
# 9 Q0 G00-88-1543350 36 4.409044 test
# 9 Q0 G00-01-2162850 37 4.407243 test
# 9 Q0 G00-07-1762179 38 4.374045 test
# 9 Q0 G00-90-1020923 39 4.358687 test
# 9 Q0 G00-57-0204493 40 4.306166 test
# 9 Q0 G00-64-0652907 41 4.212200 test
# 9 Q0 G00-98-0261576 42 4.164947 test
# 9 Q0 G00-45-0770756 43 4.131446 test
# 9 Q0 G00-97-0745395 44 4.113497 test
# 9 Q0 G00-99-2279811 45 4.102561 test
# 9 Q0 G00-99-2653385 46 4.096562 test
# 9 Q0 G00-19-3375396 47 4.083276 test
# 9 Q0 G00-53-1996585 48 4.076999 test
# 9 Q0 G00-53-2171886 49 4.074237 test
# 9 Q0 G00-03-4112125 50 4.065775 test
# 9 Q0 G00-01-3224659 51 4.058045 test
# 9 Q0 G00-05-2323106 52 4.058045 test
# 9 Q0 G00-17-0115496 53 4.048424 test
# 9 Q0 G00-65-0000000 54 4.040928 test
# 9 Q0 G00-09-4133514 55 4.023626 test
# 9 Q0 G00-21-0841529 56 4.014152 test
# 9 Q0 G00-13-2965738 57 3.979288 test
# 9 Q0 G00-18-1660493 58 3.967525 test
# 9 Q0 G00-82-0465076 59 3.944624 test
# 9 Q0 G00-67-2253092 60 3.943700 test
# 9 Q0 G00-16-1821796 61 3.941076 test
# 9 Q0 G00-54-1409324 62 3.941076 test
# 9 Q0 G00-15-2101996 63 3.941076 test
# 9 Q0 G00-96-2382474 64 3.918360 test
# 9 Q0 G00-01-0996489 65 3.895133 test
# 9 Q0 G00-03-4098316 66 3.879192 test
# 9 Q0 G00-65-3240095 67 3.870850 test
# 9 Q0 G00-38-1744932 68 3.842540 test
# 9 Q0 G00-16-2086899 69 3.833912 test
# 9 Q0 G00-86-2719389 70 3.814641 test
# 9 Q0 G00-97-1730213 71 3.814641 test
# 9 Q0 G00-79-2399698 72 3.786552 test
# 9 Q0 G00-86-3794943 73 3.778292 test
# 9 Q0 G00-30-1592409 74 3.756842 test
# 9 Q0 G00-40-3261210 75 3.755618 test
# 9 Q0 G00-01-1504689 76 3.751598 test
# 9 Q0 G00-91-0820679 77 3.734223 test
# 9 Q0 G00-91-1609512 78 3.733293 test
# 9 Q0 G00-55-2195428 79 3.728017 test
# 9 Q0 G00-67-2999597 80 3.722865 test
# 9 Q0 G00-63-3813621 81 3.717087 test
# 9 Q0 G00-07-2291379 82 3.709013 test
# 9 Q0 G00-74-4030396 83 3.684424 test
# 9 Q0 G00-54-1823367 84 3.683853 test
# 9 Q0 G00-87-0765639 85 3.682351 test
# 9 Q0 G00-22-0400264 86 3.652334 test
# 9 Q0 G00-09-1011869 87 3.641208 test
# 9 Q0 G00-36-2916036 88 3.609695 test
# 9 Q0 G00-18-4042118 89 3.609695 test
# 9 Q0 G00-03-1771651 90 3.606055 test
# 9 Q0 G00-18-2123316 91 3.595208 test
# 9 Q0 G00-02-4047734 92 3.595208 test
# 9 Q0 G00-55-3300136 93 3.582539 test
# 9 Q0 G00-47-1094341 94 3.582539 test
# 9 Q0 G00-74-1664646 95 3.554579 test
# 9 Q0 G00-23-3399952 96 3.501140 test
# 9 Q0 G00-18-2295266 97 3.498398 test
# 9 Q0 G00-03-2869813 98 3.498135 test
# 9 Q0 G00-40-2252497 99 3.484121 test
# 9 Q0 G00-00-3451251 100 3.479735 test
# 9 Q0 G00-06-0000000 101 3.467947 test
# 9 Q0 G00-09-0395878 102 3.444636 test
# 9 Q0 G00-74-0751435 103 3.433412 test
# 9 Q0 G00-87-4011875 104 3.426218 test
# 9 Q0 G00-02-2211051 105 3.420727 test
# 9 Q0 G00-22-2107598 106 3.420313 test
# 9 Q0 G00-52-3395425 107 3.415398 test
# 9 Q0 G00-41-1157769 108 3.415191 test
# 9 Q0 G00-77-0448511 109 3.404358 test
# 9 Q0 G00-68-0320800 110 3.402294 test
# 9 Q0 G00-25-1743771 111 3.388146 test
# 9 Q0 G00-20-4189759 112 3.388146 test
# 9 Q0 G00-63-0953850 113 3.364115 test
# 9 Q0 G00-59-0607040 114 3.353544 test
# 9 Q0 G00-22-3171818 115 3.351080 test
# 9 Q0 G00-97-3608484 116 3.327404 test
# 9 Q0 G00-35-3820003 117 3.321781 test
# 9 Q0 G00-40-0635599 118 3.321781 test
# 9 Q0 G00-17-2871119 119 3.306783 test
# 9 Q0 G00-63-3154141 120 3.306771 test
# 9 Q0 G00-60-1532208 121 3.291896 test
# 9 Q0 G00-65-3333979 122 3.275059 test
# 9 Q0 G00-09-0487171 123 3.274153 test
# 9 Q0 G00-26-2049181 124 3.263802 test
# 9 Q0 G00-47-1040824 125 3.263802 test
# 9 Q0 G00-04-1731548 126 3.251373 test
# 9 Q0 G00-62-2271006 127 3.241896 test
# 9 Q0 G00-48-0374136 128 3.239037 test
# 9 Q0 G00-67-0038636 129 3.237827 test
# 9 Q0 G00-84-3542587 130 3.233410 test
# 9 Q0 G00-01-3251318 131 3.212552 test
# 9 Q0 G00-97-1475424 132 3.212552 test
# 9 Q0 G00-99-2186810 133 3.188235 test
# 9 Q0 G00-28-3008506 134 3.188235 test
# 9 Q0 G00-07-0709451 135 3.171642 test
# 9 Q0 G00-47-2117970 136 3.158428 test
# 9 Q0 G00-10-0852358 137 3.154067 test
# 9 Q0 G00-03-2027773 138 3.151184 test
# 9 Q0 G00-68-1537883 139 3.132093 test
# 9 Q0 G00-45-0636707 140 3.110995 test
# 9 Q0 G00-97-2698410 141 3.110995 test
# 9 Q0 G00-67-0637954 142 3.102500 test
# 9 Q0 G00-68-1850883 143 3.102481 test
# 9 Q0 G00-10-1966794 144 3.085696 test
# 9 Q0 G00-04-1296411 145 3.085696 test
# 9 Q0 G00-09-3881335 146 3.074557 test
# 9 Q0 G00-01-1070603 147 3.071250 test
# 9 Q0 G00-10-2673853 148 3.071250 test
# 9 Q0 G00-13-3656253 149 3.071250 test
# 9 Q0 G00-64-3410298 150 3.043248 test
# 9 Q0 G00-58-0287418 151 3.038459 test
# 9 Q0 G00-04-1881110 152 3.038459 test
# 9 Q0 G00-99-3441506 153 3.038459 test
# 9 Q0 G00-05-1786459 154 3.031659 test
# 9 Q0 G00-62-1249629 155 3.028235 test
# 9 Q0 G00-83-3031351 156 3.017532 test
# 9 Q0 G00-83-1566739 157 3.011299 test
# 9 Q0 G00-91-1069766 158 2.993725 test
# 9 Q0 G00-45-3659650 159 2.993725 test
# 9 Q0 G00-41-0410179 160 2.968726 test
# 9 Q0 G00-48-2560174 161 2.968726 test
# 9 Q0 G00-81-3327332 162 2.967684 test
# 9 Q0 G00-46-1122260 163 2.964916 test
# 9 Q0 G00-66-2028129 164 2.959992 test
# 9 Q0 G00-31-0283929 165 2.959992 test
# 9 Q0 G00-74-2972556 166 2.950260 test
# 9 Q0 G00-07-0085827 167 2.934557 test
# 9 Q0 G00-05-2863370 168 2.923646 test
# 9 Q0 G00-88-2120454 169 2.914009 test
# 9 Q0 G00-01-0658356 170 2.909555 test
# 9 Q0 G00-10-2151573 171 2.894757 test
# 9 Q0 G00-62-0870952 172 2.894757 test
# 9 Q0 G00-91-3997333 173 2.894252 test
# 9 Q0 G00-58-0468921 174 2.882540 test
# 9 Q0 G00-04-2494323 175 2.882540 test
# 9 Q0 G00-35-3237468 176 2.876043 test
# 9 Q0 G00-20-1369470 177 2.874761 test
# 9 Q0 G00-92-0364153 178 2.872863 test
# 9 Q0 G00-42-1834554 179 2.868015 test
# 9 Q0 G00-21-0118799 180 2.866433 test
# 9 Q0 G00-72-2677026 181 2.853636 test
# 9 Q0 G00-07-3252715 182 2.853622 test
# 9 Q0 G00-18-3998125 183 2.852024 test
# 9 Q0 G00-09-3470441 184 2.850482 test
# 9 Q0 G00-01-0420692 185 2.850482 test
# 9 Q0 G00-57-3572192 186 2.850482 test
# 9 Q0 G00-36-0475923 187 2.837041 test
# 9 Q0 G00-02-1147404 188 2.837041 test
# 9 Q0 G00-01-0552893 189 2.832791 test
# 9 Q0 G00-94-3227831 190 2.832791 test
# 9 Q0 G00-30-3320486 191 2.825277 test
# 9 Q0 G00-58-0264438 192 2.822970 test
# 9 Q0 G00-39-3477058 193 2.822715 test
# 9 Q0 G00-62-2770020 194 2.822214 test
# 9 Q0 G00-39-3855269 195 2.812263 test
# 9 Q0 G00-53-3569283 196 2.812263 test
# 9 Q0 G00-25-1076458 197 2.809830 test
# 9 Q0 G00-07-3593654 198 2.803678 test
# 9 Q0 G00-05-3437619 199 2.802101 test
# 9 Q0 G00-00-2737496 200 2.790674 test
# 9 Q0 G00-01-1906654 201 2.790674 test
# 9 Q0 G00-90-0222848 202 2.790205 test
# 9 Q0 G00-95-0371226 203 2.774801 test
# 9 Q0 G00-06-3965004 204 2.774801 test
# 9 Q0 G00-09-0524984 205 2.768490 test
# 9 Q0 G00-95-3919947 206 2.759108 test
# 9 Q0 G00-06-4174747 207 2.759108 test
# 9 Q0 G00-07-0325733 208 2.759108 test
# 9 Q0 G00-90-2241076 209 2.755627 test
# 9 Q0 G00-55-3547612 210 2.752416 test
# 9 Q0 G00-05-1218739 211 2.747110 test
# 9 Q0 G00-62-2366852 212 2.741389 test
# 9 Q0 G00-73-3912994 213 2.737747 test
# 9 Q0 G00-16-2494170 214 2.724319 test
# 9 Q0 G00-47-4117952 215 2.724319 test
# 9 Q0 G00-66-2062069 216 2.723896 test
# 9 Q0 G00-52-1224492 217 2.720301 test
# 9 Q0 G00-68-3094820 218 2.706626 test
# 9 Q0 G00-50-3231467 219 2.706626 test
# 9 Q0 G00-28-3705847 220 2.706626 test
# 9 Q0 G00-05-3764273 221 2.701902 test
# 9 Q0 G00-05-3703958 222 2.700185 test
# 9 Q0 G00-28-0647082 223 2.700185 test
# 9 Q0 G00-09-3637766 224 2.689572 test
# 9 Q0 G00-84-2792674 225 2.679852 test
# 9 Q0 G00-39-4042977 226 2.673410 test
# 9 Q0 G00-08-0264118 227 2.670642 test
# 9 Q0 G00-45-1301562 228 2.663718 test
# 9 Q0 G00-05-3086404 229 2.663718 test
# 9 Q0 G00-86-2289049 230 2.655782 test
# 9 Q0 G00-41-1515340 231 2.654852 test
# 9 Q0 G00-66-0145846 232 2.654852 test
# 9 Q0 G00-46-3010333 233 2.651977 test
# 9 Q0 G00-03-0215521 234 2.645794 test
# 9 Q0 G00-97-4114543 235 2.644467 test
# 9 Q0 G00-80-2670974 236 2.633571 test
# 9 Q0 G00-03-3843811 237 2.631936 test
# 9 Q0 G00-06-0670692 238 2.631936 test
# 9 Q0 G00-34-1517989 239 2.618742 test
# 9 Q0 G00-91-1932391 240 2.615418 test
# 9 Q0 G00-01-0423383 241 2.615418 test
# 9 Q0 G00-49-2602614 242 2.615418 test
# 9 Q0 G00-42-0000000 243 2.615418 test
# 9 Q0 G00-21-2737022 244 2.612681 test
# 9 Q0 G00-03-2081400 245 2.609442 test
# 9 Q0 G00-86-0241003 246 2.607818 test
# 9 Q0 G00-36-1620676 247 2.598851 test
# 9 Q0 G00-09-0600961 248 2.575333 test
# 9 Q0 G00-03-1387912 249 2.575333 test
# 9 Q0 G00-66-1114257 250 2.575333 test
# 9 Q0 G00-72-3522367 251 2.575333 test
# 9 Q0 G00-89-0896876 252 2.562450 test
# 9 Q0 G00-36-0199656 253 2.562450 test
# 9 Q0 G00-30-1463695 254 2.562450 test
# 9 Q0 G00-49-3068476 255 2.562450 test
# 9 Q0 G00-05-0081436 256 2.557815 test
# 9 Q0 G00-35-0873391 257 2.554764 test
# 9 Q0 G00-02-3807812 258 2.554764 test
# 9 Q0 G00-59-3066205 259 2.549696 test
# 9 Q0 G00-08-2963185 260 2.537068 test
# 9 Q0 G00-36-0856406 261 2.524564 test
# 9 Q0 G00-10-1960260 262 2.524564 test
# 9 Q0 G00-07-2536891 263 2.524564 test
# 9 Q0 G00-03-0697220 264 2.513398 test
# 9 Q0 G00-48-0783760 265 2.513398 test
# 9 Q0 G00-07-1735413 266 2.513398 test
# 9 Q0 G00-27-0576256 267 2.513398 test
# 9 Q0 G00-25-0870759 268 2.509722 test
# 9 Q0 G00-44-3240389 269 2.508219 test
# 9 Q0 G00-17-1006883 270 2.491395 test
# 9 Q0 G00-70-3783746 271 2.482959 test
# 9 Q0 G00-03-3297483 272 2.482959 test
# 9 Q0 G00-56-2914829 273 2.482959 test
# 9 Q0 G00-05-3121512 274 2.482959 test
# 9 Q0 G00-64-2095540 275 2.481969 test
# 9 Q0 G00-16-1925033 276 2.474353 test
# 9 Q0 G00-17-0868458 277 2.469773 test
# 9 Q0 G00-04-1018827 278 2.469773 test
# 9 Q0 G00-08-1145623 279 2.468600 test
# 9 Q0 G00-06-3152191 280 2.468600 test
# 9 Q0 G00-07-1018832 281 2.468600 test
# 9 Q0 G00-59-2783898 282 2.468600 test
# 9 Q0 G00-44-1932731 283 2.452057 test
# 9 Q0 G00-01-3395222 284 2.452057 test
# 9 Q0 G00-05-0390218 285 2.452057 test
# 9 Q0 G00-05-2114059 286 2.452057 test
# 9 Q0 G00-06-3939376 287 2.452057 test
# 9 Q0 G00-20-1054384 288 2.452057 test
# 9 Q0 G00-07-1680987 289 2.452057 test
# 9 Q0 G00-07-2244658 290 2.452057 test
# 9 Q0 G00-69-0005329 291 2.449678 test
# 9 Q0 G00-95-3043676 292 2.448524 test
# 9 Q0 G00-30-2216168 293 2.438052 test
# 9 Q0 G00-77-1178393 294 2.438052 test
# 9 Q0 G00-43-3227387 295 2.429700 test
# 9 Q0 G00-36-3945230 296 2.425912 test
# 9 Q0 G00-00-1711483 297 2.421914 test
# 9 Q0 G00-52-2562368 298 2.421914 test
# 9 Q0 G00-97-1817307 299 2.421914 test
# 9 Q0 G00-24-0730942 300 2.421914 test
# 9 Q0 G00-06-2446510 301 2.421914 test
# 9 Q0 G00-62-2252378 302 2.421914 test
# 9 Q0 G00-02-2980653 303 2.421914 test
# 9 Q0 G00-00-1717907 304 2.405989 test
# 9 Q0 G00-60-1236252 305 2.405989 test
# 9 Q0 G00-38-0022868 306 2.405989 test
# 9 Q0 G00-15-2697443 307 2.390271 test
# 9 Q0 G00-23-0817674 308 2.390271 test
# 9 Q0 G00-02-0114963 309 2.390271 test
# 9 Q0 G00-06-1727652 310 2.381919 test
# 9 Q0 G00-02-4057099 311 2.381919 test
# 9 Q0 G00-03-1342151 312 2.374758 test
# 9 Q0 G00-22-3396139 313 2.374758 test
# 9 Q0 G00-36-3746009 314 2.374758 test
# 9 Q0 G00-97-2215955 315 2.374758 test
# 9 Q0 G00-82-0211909 316 2.374758 test
# 9 Q0 G00-00-2257471 317 2.357273 test
# 9 Q0 G00-53-0192769 318 2.357273 test
# 9 Q0 G00-84-2647789 319 2.357273 test
# 9 Q0 G00-09-4172401 320 2.357257 test
# 9 Q0 G00-86-0344148 321 2.357257 test
# 9 Q0 G00-15-1296457 322 2.357257 test
# 9 Q0 G00-59-3586444 323 2.349464 test
# 9 Q0 G00-10-2753840 324 2.344358 test
# 9 Q0 G00-00-0465038 325 2.341143 test
# 9 Q0 G00-06-2445973 326 2.341143 test
# 9 Q0 G00-00-0990763 327 2.340043 test
# 9 Q0 G00-73-2863491 328 2.340043 test
# 9 Q0 G00-08-0210913 329 2.340043 test
# 9 Q0 G00-82-3336838 330 2.340043 test
# 9 Q0 G00-07-0452218 331 2.340043 test
# 9 Q0 G00-82-2477299 332 2.335538 test
# 9 Q0 G00-70-3522936 333 2.323064 test
# 9 Q0 G00-19-2902623 334 2.318887 test
# 9 Q0 G00-39-2581160 335 2.315743 test
# 9 Q0 G00-79-0218457 336 2.310997 test
# 9 Q0 G00-74-1280036 337 2.306329 test
# 9 Q0 G00-98-2611944 338 2.306329 test
# 9 Q0 G00-10-4133035 339 2.287818 test
# 9 Q0 G00-06-0233752 340 2.287818 test
# 9 Q0 G00-03-2173112 341 2.287789 test
# 9 Q0 G00-17-2845878 342 2.287789 test
# 9 Q0 G00-94-1328230 343 2.286243 test
# 9 Q0 G00-20-2822947 344 2.286243 test
# 9 Q0 G00-93-0389371 345 2.265907 test
# 9 Q0 G00-89-0031748 346 2.251587 test
# 9 Q0 G00-39-2294981 347 2.251587 test
# 9 Q0 G00-95-2757938 348 2.251587 test
# 9 Q0 G00-28-2286602 349 2.251587 test
# 9 Q0 G00-41-1343353 350 2.237404 test
# 9 Q0 G00-69-0982341 351 2.236867 test
# 9 Q0 G00-19-2536913 352 2.236867 test
# 9 Q0 G00-22-2758386 353 2.233913 test
# 9 Q0 G00-16-0625124 354 2.231022 test
# 9 Q0 G00-59-2294330 355 2.216541 test
# 9 Q0 G00-47-0072041 356 2.214598 test
# 9 Q0 G00-51-0498788 357 2.209794 test
# 9 Q0 G00-69-3929158 358 2.209608 test
# 9 Q0 G00-66-0456093 359 2.209608 test
# 9 Q0 G00-59-2349259 360 2.209608 test
# 9 Q0 G00-03-2245885 361 2.195613 test
# 9 Q0 G00-21-3009650 362 2.195613 test
# 9 Q0 G00-04-1824402 363 2.190945 test
# 9 Q0 G00-53-3329958 364 2.188097 test
# 9 Q0 G00-07-0600291 365 2.188097 test
# 9 Q0 G00-50-2469238 366 2.175103 test
# 9 Q0 G00-16-0059045 367 2.175103 test
# 9 Q0 G00-07-3425686 368 2.175103 test
# 9 Q0 G00-03-3137314 369 2.174206 test
# 9 Q0 G00-60-1981260 370 2.174206 test
# 9 Q0 G00-06-2661322 371 2.174206 test
# 9 Q0 G00-43-2715210 372 2.165932 test
# 9 Q0 G00-03-1585062 373 2.163149 test
# 9 Q0 G00-00-2764912 374 2.163149 test
# 9 Q0 G00-04-1527192 375 2.163149 test
# 9 Q0 G00-71-3304650 376 2.157721 test
# 9 Q0 G00-07-2654723 377 2.157721 test
# 9 Q0 G00-36-2296936 378 2.154972 test
# 9 Q0 G00-89-0575056 379 2.146869 test
# 9 Q0 G00-80-0880722 380 2.146869 test
# 9 Q0 G00-42-1249322 381 2.138802 test
# 9 Q0 G00-29-1544211 382 2.137425 test
# 9 Q0 G00-35-2527252 383 2.135211 test
# 9 Q0 G00-95-3548730 384 2.135211 test
# 9 Q0 G00-92-0578141 385 2.135211 test
# 9 Q0 G00-59-3730691 386 2.135211 test
# 9 Q0 G00-27-2669897 387 2.135211 test
# 9 Q0 G00-08-1077424 388 2.120212 test
# 9 Q0 G00-04-0538799 389 2.120212 test
# 9 Q0 G00-04-0785331 390 2.114062 test
# 9 Q0 G00-05-0719078 391 2.114062 test
# 9 Q0 G00-27-3174236 392 2.114062 test
# 9 Q0 G00-17-0194527 393 2.109733 test
# 9 Q0 G00-28-4051184 394 2.109733 test
# 9 Q0 G00-02-2129251 395 2.109733 test
# 9 Q0 G00-04-1324842 396 2.099358 test
# 9 Q0 G00-01-3511414 397 2.093328 test
# 9 Q0 G00-94-4070183 398 2.093328 test
# 9 Q0 G00-55-0513571 399 2.089084 test
# 9 Q0 G00-08-3960707 400 2.089084 test
# 9 Q0 G00-88-2066673 401 2.089084 test
# 9 Q0 G00-05-0758583 402 2.089084 test
# 9 Q0 G00-97-2750090 403 2.076382 test
# 9 Q0 G00-07-2746381 404 2.076382 test
# 9 Q0 G00-22-0643864 405 2.072997 test
# 9 Q0 G00-18-1959000 406 2.072997 test
# 9 Q0 G00-43-2871497 407 2.072997 test
# 9 Q0 G00-09-1783499 408 2.066331 test
# 9 Q0 G00-34-2691400 409 2.066331 test
# 9 Q0 G00-01-0604374 410 2.066331 test
# 9 Q0 G00-09-3116633 411 2.056377 test
# 9 Q0 G00-65-3431980 412 2.056377 test
# 9 Q0 G00-04-0209451 413 2.056377 test
# 9 Q0 G00-77-1684446 414 2.056377 test
# 9 Q0 G00-06-2351076 415 2.056377 test
# 9 Q0 G00-49-2685671 416 2.044068 test
# 9 Q0 G00-43-0086742 417 2.044068 test
# 9 Q0 G00-68-1075400 418 2.031906 test
# 9 Q0 G00-44-1544965 419 2.031906 test
# 9 Q0 G00-04-3355472 420 2.031906 test
# 9 Q0 G00-23-1251181 421 2.031906 test
# 9 Q0 G00-20-1424362 422 2.031906 test
# 9 Q0 G00-46-1439567 423 2.030273 test
# 9 Q0 G00-72-3310984 424 2.030273 test
# 9 Q0 G00-50-0181286 425 2.019888 test
# 9 Q0 G00-89-3143135 426 2.019888 test
# 9 Q0 G00-05-3046426 427 2.019888 test
# 9 Q0 G00-24-3733379 428 2.019888 test
# 9 Q0 G00-69-3541913 429 2.009564 test
# 9 Q0 G00-10-0865843 430 2.009564 test
# 9 Q0 G00-06-0690672 431 2.009564 test
# 9 Q0 G00-11-0456889 432 2.008011 test
# 9 Q0 G00-12-0039547 433 2.008011 test
# 9 Q0 G00-15-4189524 434 2.008011 test
# 9 Q0 G00-38-1569212 435 2.008011 test
# 9 Q0 G00-43-2860595 436 2.008011 test
# 9 Q0 G00-98-0000000 437 2.007027 test
# 9 Q0 G00-36-0132989 438 1.996273 test
# 9 Q0 G00-08-0868177 439 1.996273 test
# 9 Q0 G00-88-2177598 440 1.996273 test
# 9 Q0 G00-05-0743969 441 1.996273 test
# 9 Q0 G00-02-4085175 442 1.996273 test
# 9 Q0 G00-55-3900830 443 1.986189 test
# 9 Q0 G00-58-2162083 444 1.986189 test
# 9 Q0 G00-10-1843562 445 1.986189 test
# 9 Q0 G00-64-3063239 446 1.986189 test
# 9 Q0 G00-02-0267227 447 1.986189 test
# 9 Q0 G00-00-2308409 448 1.982368 test
# 9 Q0 G00-32-1470031 449 1.982368 test
# 9 Q0 G00-08-0825121 450 1.982368 test
# 9 Q0 G00-08-1609604 451 1.982368 test
# 9 Q0 G00-12-0572170 452 1.980036 test
# 9 Q0 G00-94-2502192 453 1.980036 test
# 9 Q0 G00-44-3191702 454 1.970927 test
# 9 Q0 G00-69-4177280 455 1.970927 test
# 9 Q0 G00-18-2665440 456 1.970927 test
# 9 Q0 G00-11-2005001 457 1.970927 test
# 9 Q0 G00-06-3861158 458 1.970927 test
# 9 Q0 G00-03-0858819 459 1.964857 test
# 9 Q0 G00-05-2480927 460 1.964857 test
# 9 Q0 G00-40-1469629 461 1.964857 test
# 9 Q0 G00-84-2265835 462 1.964857 test
# 9 Q0 G00-07-1561076 463 1.964857 test
# 9 Q0 G00-91-3056625 464 1.957371 test
# 9 Q0 G00-21-2096695 465 1.957371 test
# 9 Q0 G00-04-3319765 466 1.957371 test
# 9 Q0 G00-35-4101243 467 1.957371 test
# 9 Q0 G00-05-1408124 468 1.957371 test
# 9 Q0 G00-60-0305942 469 1.957371 test
# 9 Q0 G00-07-0261374 470 1.957371 test
# 9 Q0 G00-07-3578277 471 1.957371 test
# 9 Q0 G00-89-3274987 472 1.944000 test
# 9 Q0 G00-00-1569310 473 1.944000 test
# 9 Q0 G00-80-1682195 474 1.944000 test
# 9 Q0 G00-57-1321673 475 1.944000 test
# 9 Q0 G00-10-0136170 476 1.944000 test
# 9 Q0 G00-10-0704121 477 1.944000 test
# 9 Q0 G00-11-0354032 478 1.944000 test
# 9 Q0 G00-30-1042227 479 1.944000 test
# 9 Q0 G00-30-0401307 480 1.944000 test
# 9 Q0 G00-12-1154511 481 1.944000 test
# 9 Q0 G00-93-3967570 482 1.944000 test
# 9 Q0 G00-05-2552502 483 1.944000 test
# 9 Q0 G00-94-3433584 484 1.944000 test
# 9 Q0 G00-48-2946724 485 1.944000 test
# 9 Q0 G00-81-3820772 486 1.944000 test
# 9 Q0 G00-02-3720828 487 1.944000 test
# 9 Q0 G00-05-2357004 488 1.942505 test
# 9 Q0 G00-60-4042439 489 1.942505 test
# 9 Q0 G00-00-1277838 490 1.928630 test
# 9 Q0 G00-32-0551737 491 1.928630 test
# 9 Q0 G00-22-1831204 492 1.928630 test
# 9 Q0 G00-08-2772972 493 1.928630 test
# 9 Q0 G00-10-2990313 494 1.928630 test
# 9 Q0 G00-06-1679297 495 1.928630 test
# 9 Q0 G00-67-1920188 496 1.928630 test
# 9 Q0 G00-01-0682299 497 1.919216 test
# 9 Q0 G00-10-1931044 498 1.919216 test
# 9 Q0 G00-03-2200929 499 1.915647 test
# 9 Q0 G00-36-2458572 500 1.915647 test
# 9 Q0 G00-10-3090724 501 1.915647 test
# 9 Q0 G00-11-3911519 502 1.915647 test
# 9 Q0 G00-93-0843597 503 1.915647 test
# 9 Q0 G00-05-0272455 504 1.915647 test
# 9 Q0 G00-05-3621484 505 1.915647 test
# 9 Q0 G00-02-0256830 506 1.915647 test
# 9 Q0 G00-00-2682418 507 1.900721 test
# 9 Q0 G00-01-0400712 508 1.900721 test
# 9 Q0 G00-21-0494028 509 1.900721 test
# 9 Q0 G00-08-0028902 510 1.900721 test
# 9 Q0 G00-49-0846427 511 1.900721 test
# 9 Q0 G00-93-4012578 512 1.900721 test
# 9 Q0 G00-35-0053029 513 1.900721 test
# 9 Q0 G00-05-0927949 514 1.900721 test
# 9 Q0 G00-05-1146514 515 1.900721 test
# 9 Q0 G00-40-2173588 516 1.900721 test
# 9 Q0 G00-03-0991989 517 1.898567 test
# 9 Q0 G00-91-1567424 518 1.886024 test
# 9 Q0 G00-09-2641304 519 1.886024 test
# 9 Q0 G00-71-3257178 520 1.886024 test
# 9 Q0 G00-08-2472523 521 1.886024 test
# 9 Q0 G00-31-0429249 522 1.886024 test
# 9 Q0 G00-21-2018063 523 1.874274 test
# 9 Q0 G00-03-3996998 524 1.871554 test
# 9 Q0 G00-08-1007258 525 1.871554 test
# 9 Q0 G00-11-0225161 526 1.871554 test
# 9 Q0 G00-79-1442062 527 1.871554 test
# 9 Q0 G00-49-2094879 528 1.871554 test
# 9 Q0 G00-99-3505460 529 1.871554 test
# 9 Q0 G00-06-2290619 530 1.871554 test
# 9 Q0 G00-07-3859091 531 1.871554 test
# 9 Q0 G00-62-2030604 532 1.871554 test
# 9 Q0 G00-27-1448789 533 1.860803 test
# 9 Q0 G00-65-4078383 534 1.858482 test
# 9 Q0 G00-09-2058065 535 1.857304 test
# 9 Q0 G00-03-0931579 536 1.857304 test
# 9 Q0 G00-01-4041583 537 1.857304 test
# 9 Q0 G00-15-3874791 538 1.857304 test
# 9 Q0 G00-52-2991521 539 1.857304 test
# 9 Q0 G00-52-3677624 540 1.857304 test
# 9 Q0 G00-87-1872370 541 1.857304 test
# 9 Q0 G00-24-4000056 542 1.857304 test
# 9 Q0 G00-48-2924130 543 1.857304 test
# 9 Q0 G00-31-3612634 544 1.857304 test
# 9 Q0 G00-02-1268088 545 1.857304 test
# 9 Q0 G00-18-0374568 546 1.851244 test
# 9 Q0 G00-31-0402761 547 1.851244 test
# 9 Q0 G00-10-3170109 548 1.841281 test
# 9 Q0 G00-11-0184364 549 1.841281 test
# 9 Q0 G00-04-0276405 550 1.841281 test
# 9 Q0 G00-47-1562233 551 1.841281 test
# 9 Q0 G00-13-0091418 552 1.841281 test
# 9 Q0 G00-03-2104296 553 1.827468 test
# 9 Q0 G00-74-2685794 554 1.825533 test
# 9 Q0 G00-03-2010455 555 1.825533 test
# 9 Q0 G00-01-3825845 556 1.825533 test
# 9 Q0 G00-56-2425288 557 1.825533 test
# 9 Q0 G00-68-2200781 558 1.810052 test
# 9 Q0 G00-91-3069407 559 1.810052 test
# 9 Q0 G00-03-1927535 560 1.810052 test
# 9 Q0 G00-01-1404039 561 1.810052 test
# 9 Q0 G00-16-1314498 562 1.810052 test
# 9 Q0 G00-04-3085148 563 1.810052 test
# 9 Q0 G00-94-2249557 564 1.810052 test
# 9 Q0 G00-93-3425780 565 1.804295 test
# 9 Q0 G00-82-4103082 566 1.804295 test
# 9 Q0 G00-09-0660674 567 1.794831 test
# 9 Q0 G00-09-1704111 568 1.794831 test
# 9 Q0 G00-26-3134051 569 1.794831 test
# 9 Q0 G00-77-3295130 570 1.794831 test
# 9 Q0 G00-25-0946134 571 1.794831 test
# 9 Q0 G00-28-1450394 572 1.794831 test
# 9 Q0 G00-10-3849661 573 1.778010 test
# 9 Q0 G00-05-0623935 574 1.778010 test
# 9 Q0 G00-07-1172041 575 1.778010 test
# 9 Q0 G00-60-2564326 576 1.762385 test
# 9 Q0 G00-00-2121363 577 1.761502 test
# 9 Q0 G00-39-1521404 578 1.761502 test
# 9 Q0 G00-57-1064839 579 1.761502 test
# 9 Q0 G00-10-2917540 580 1.761502 test
# 9 Q0 G00-10-2418697 581 1.761502 test
# 9 Q0 G00-98-0789839 582 1.761502 test
# 9 Q0 G00-05-0212361 583 1.761502 test
# 9 Q0 G00-77-1847967 584 1.761502 test
# 9 Q0 G00-25-3064175 585 1.761502 test
# 9 Q0 G00-40-3277263 586 1.761502 test
# 9 Q0 G00-01-0261040 587 1.756050 test
# 9 Q0 G00-49-0669001 588 1.756050 test
# 9 Q0 G00-50-1032874 589 1.745298 test
# 9 Q0 G00-34-2999931 590 1.745298 test
# 9 Q0 G00-01-2822805 591 1.745298 test
# 9 Q0 G00-49-3982133 592 1.745298 test
# 9 Q0 G00-94-1117794 593 1.745298 test
# 9 Q0 G00-53-0263242 594 1.745298 test
# 9 Q0 G00-06-0615550 595 1.745298 test
# 9 Q0 G00-02-2095762 596 1.745298 test
# 9 Q0 G00-70-3424520 597 1.735516 test
# 9 Q0 G00-63-3377143 598 1.732296 test
# 9 Q0 G00-03-0886424 599 1.729389 test
# 9 Q0 G00-01-2038545 600 1.729389 test
# 9 Q0 G00-57-1534179 601 1.729389 test
# 9 Q0 G00-04-2035920 602 1.729389 test
# 9 Q0 G00-05-2082516 603 1.729389 test
# 9 Q0 G00-05-0771435 604 1.729389 test
# 9 Q0 G00-06-2221728 605 1.729389 test
# 9 Q0 G00-07-0894074 606 1.729389 test
# 9 Q0 G00-01-0320371 607 1.712049 test
# 9 Q0 G00-93-1698165 608 1.712049 test
# 9 Q0 G00-24-0537894 609 1.712049 test
# 9 Q0 G00-07-1593969 610 1.712049 test
# 9 Q0 G00-07-1479427 611 1.712049 test
# 9 Q0 G00-43-1317779 612 1.712049 test
# 9 Q0 G00-79-4144643 613 1.709177 test
# 9 Q0 G00-47-1352318 614 1.698075 test
# 9 Q0 G00-03-2429650 615 1.695053 test
# 9 Q0 G00-01-2851595 616 1.695053 test
# 9 Q0 G00-57-0508479 617 1.695053 test
# 9 Q0 G00-18-1062516 618 1.695053 test
# 9 Q0 G00-10-2719392 619 1.695053 test
# 9 Q0 G00-04-3016417 620 1.695053 test
# 9 Q0 G00-05-0137212 621 1.695053 test
# 9 Q0 G00-53-1733327 622 1.695053 test
# 9 Q0 G00-07-2059058 623 1.695053 test
# 9 Q0 G00-59-0879264 624 1.695053 test
# 9 Q0 G00-02-0832578 625 1.684447 test
# 9 Q0 G00-58-2205749 626 1.681338 test
# 9 Q0 G00-23-3822276 627 1.681338 test
# 9 Q0 G00-15-3695921 628 1.680020 test
# 9 Q0 G00-70-2194949 629 1.676744 test
# 9 Q0 G00-00-3057225 630 1.676744 test
# 9 Q0 G00-01-3672955 631 1.676744 test
# 9 Q0 G00-71-0161321 632 1.676744 test
# 9 Q0 G00-57-3290405 633 1.676744 test
# 9 Q0 G00-10-0818874 634 1.676744 test
# 9 Q0 G00-06-1479477 635 1.676744 test
# 9 Q0 G00-83-2023652 636 1.660423 test
# 9 Q0 G00-21-4103271 637 1.660423 test
# 9 Q0 G00-09-0550713 638 1.658825 test
# 9 Q0 G00-03-1970588 639 1.658825 test
# 9 Q0 G00-00-0666975 640 1.658825 test
# 9 Q0 G00-19-2800132 641 1.658825 test
# 9 Q0 G00-54-0905235 642 1.658825 test
# 9 Q0 G00-98-3928796 643 1.658825 test
# 9 Q0 G00-87-1492488 644 1.658825 test
# 9 Q0 G00-06-1168781 645 1.658825 test
# 9 Q0 G00-72-3133704 646 1.658825 test
# 9 Q0 G00-17-1802707 647 1.641286 test
# 9 Q0 G00-10-4116640 648 1.641286 test
# 9 Q0 G00-93-0901470 649 1.641286 test
# 9 Q0 G00-87-2869473 650 1.641286 test
# 9 Q0 G00-38-2501293 651 1.641286 test
# 9 Q0 G00-02-0599362 652 1.641286 test
# 9 Q0 G00-17-2521440 653 1.636029 test
# 9 Q0 G00-19-0753142 654 1.622570 test
# 9 Q0 G00-11-0700527 655 1.622570 test
# 9 Q0 G00-04-3693239 656 1.622570 test
# 9 Q0 G00-48-0930923 657 1.622570 test
# 9 Q0 G00-06-2929062 658 1.622570 test
# 9 Q0 G00-90-0874739 659 1.621928 test
# 9 Q0 G00-77-3788231 660 1.611327 test
# 9 Q0 G00-74-2775206 661 1.604277 test
# 9 Q0 G00-00-1037714 662 1.604277 test
# 9 Q0 G00-86-0205886 663 1.604277 test
# 9 Q0 G00-65-0162935 664 1.604277 test
# 9 Q0 G00-04-3257250 665 1.604277 test
# 9 Q0 G00-84-1633108 666 1.604277 test
# 9 Q0 G00-28-0628343 667 1.604277 test
# 9 Q0 G00-34-2902209 668 1.587360 test
# 9 Q0 G00-34-3591274 669 1.586391 test
# 9 Q0 G00-16-1088156 670 1.586391 test
# 9 Q0 G00-36-3147953 671 1.586391 test
# 9 Q0 G00-95-0612583 672 1.586391 test
# 9 Q0 G00-67-3576955 673 1.586391 test
# 9 Q0 G00-70-2681284 674 1.567459 test
# 9 Q0 G00-74-3136755 675 1.567459 test
# 9 Q0 G00-01-1184872 676 1.567459 test
# 9 Q0 G00-01-0270065 677 1.567459 test
# 9 Q0 G00-36-1960831 678 1.567459 test
# 9 Q0 G00-52-2522868 679 1.567459 test
# 9 Q0 G00-07-0430412 680 1.567459 test
# 9 Q0 G00-59-0641167 681 1.567459 test
# 9 Q0 G00-95-1976041 682 1.563141 test
# 9 Q0 G00-43-0195911 683 1.563141 test
# 9 Q0 G00-68-2213331 684 1.548974 test
# 9 Q0 G00-09-2977161 685 1.548974 test
# 9 Q0 G00-10-0460101 686 1.548974 test
# 9 Q0 G00-10-0361005 687 1.548974 test
# 9 Q0 G00-99-0804220 688 1.548974 test
# 9 Q0 G00-53-1466983 689 1.548974 test
# 9 Q0 G00-06-0808843 690 1.548974 test
# 9 Q0 G00-68-2999154 691 1.543354 test
# 9 Q0 G00-30-3726817 692 1.538725 test
# 9 Q0 G00-03-3107666 693 1.530920 test
# 9 Q0 G00-00-0350612 694 1.530920 test
# 9 Q0 G00-73-1499832 695 1.530920 test
# 9 Q0 G00-46-4090374 696 1.530920 test
# 9 Q0 G00-10-0844304 697 1.530920 test
# 9 Q0 G00-47-1267820 698 1.530920 test
# 9 Q0 G00-51-0815543 699 1.515950 test
# 9 Q0 G00-10-2011620 700 1.510643 test
# 9 Q0 G00-41-1695955 701 1.510605 test
# 9 Q0 G00-80-1927471 702 1.510605 test
# 9 Q0 G00-35-3085404 703 1.510605 test
# 9 Q0 G00-94-1294899 704 1.510605 test
# 9 Q0 G00-03-0131692 705 1.507974 test
# 9 Q0 G00-96-2877140 706 1.504255 test
# 9 Q0 G00-03-0991043 707 1.500026 test
# 9 Q0 G00-09-1393028 708 1.492124 test
# 9 Q0 G00-11-3493478 709 1.492124 test
# 9 Q0 G00-97-2327881 710 1.489508 test
# 9 Q0 G00-05-2762833 711 1.484378 test
# 9 Q0 G00-17-1742060 712 1.479234 test
# 9 Q0 G00-54-0007236 713 1.472818 test
# 9 Q0 G00-02-3981961 714 1.472818 test
# 9 Q0 G00-49-1264822 715 1.468572 test
# 9 Q0 G00-64-1391646 716 1.466529 test
# 9 Q0 G00-68-1782021 717 1.464804 test
# 9 Q0 G00-17-3027297 718 1.464804 test
# 9 Q0 G00-20-1390240 719 1.464804 test
# 9 Q0 G00-16-0858333 720 1.461455 test
# 9 Q0 G00-51-3768244 721 1.461455 test
# 9 Q0 G00-24-3340215 722 1.459011 test
# 9 Q0 G00-05-0764940 723 1.454041 test
# 9 Q0 G00-07-0975373 724 1.454041 test
# 9 Q0 G00-17-3563194 725 1.452769 test
# 9 Q0 G00-93-1203370 726 1.452769 test
# 9 Q0 G00-99-3472326 727 1.452769 test
# 9 Q0 G00-07-3064254 728 1.452769 test
# 9 Q0 G00-10-0666948 729 1.449105 test
# 9 Q0 G00-04-0274135 730 1.449105 test
# 9 Q0 G00-01-0847467 731 1.444202 test
# 9 Q0 G00-07-0040146 732 1.440096 test
# 9 Q0 G00-01-1814152 733 1.439333 test
# 9 Q0 G00-32-0376398 734 1.434496 test
# 9 Q0 G00-07-3237370 735 1.434496 test
# 9 Q0 G00-44-0040735 736 1.433258 test
# 9 Q0 G00-00-1210895 737 1.433258 test
# 9 Q0 G00-56-0597632 738 1.433258 test
# 9 Q0 G00-04-0177999 739 1.433258 test
# 9 Q0 G00-60-0593267 740 1.433258 test
# 9 Q0 G00-07-1903067 741 1.433258 test
# 9 Q0 G00-66-0135225 742 1.429692 test
# 9 Q0 G00-02-0524966 743 1.429692 test
# 9 Q0 G00-08-0164002 744 1.424919 test
# 9 Q0 G00-93-3182623 745 1.424919 test
# 9 Q0 G00-06-2386747 746 1.424919 test
# 9 Q0 G00-44-0092425 747 1.417820 test
# 9 Q0 G00-03-3700882 748 1.417820 test
# 9 Q0 G00-36-0221750 749 1.414264 test
# 9 Q0 G00-91-2992636 750 1.413127 test
# 9 Q0 G00-10-4163494 751 1.413127 test
# 9 Q0 G00-04-1562575 752 1.408464 test
# 9 Q0 G00-93-1016588 753 1.408464 test
# 9 Q0 G00-52-3462296 754 1.408464 test
# 9 Q0 G00-06-1662495 755 1.408464 test
# 9 Q0 G00-71-3227595 756 1.401528 test
# 9 Q0 G00-79-1457025 757 1.401528 test
# 9 Q0 G00-05-1030627 758 1.401528 test
# 9 Q0 G00-92-2974327 759 1.401528 test
# 9 Q0 G00-28-0847842 760 1.401528 test
# 9 Q0 G00-03-1730521 761 1.396941 test
# 9 Q0 G00-01-2206923 762 1.396941 test
# 9 Q0 G00-57-3919967 763 1.396941 test
# 9 Q0 G00-04-4166204 764 1.394627 test
# 9 Q0 G00-64-2338458 765 1.394627 test
# 9 Q0 G00-82-2383456 766 1.394627 test
# 9 Q0 G00-26-3904897 767 1.390118 test
# 9 Q0 G00-00-1636809 768 1.383360 test
# 9 Q0 G00-04-3812745 769 1.383360 test
# 9 Q0 G00-87-0777423 770 1.383360 test
# 9 Q0 G00-13-0135077 771 1.383360 test
# 9 Q0 G00-86-1693753 772 1.381075 test
# 9 Q0 G00-06-1598494 773 1.376669 test
# 9 Q0 G00-09-0808205 774 1.374421 test
# 9 Q0 G00-22-3983334 775 1.374421 test
# 9 Q0 G00-46-1260939 776 1.374421 test
# 9 Q0 G00-45-4075347 777 1.374421 test
# 9 Q0 G00-99-0140748 778 1.374421 test
# 9 Q0 G00-40-0934119 779 1.374421 test
# 9 Q0 G00-71-0886607 780 1.370041 test
# 9 Q0 G00-10-3382518 781 1.370041 test
# 9 Q0 G00-20-4144119 782 1.370041 test
# 9 Q0 G00-67-1876619 783 1.370041 test
# 9 Q0 G00-63-4005575 784 1.367074 test
# 9 Q0 G00-06-1757034 785 1.367074 test
# 9 Q0 G00-58-3498167 786 1.363477 test
# 9 Q0 G00-80-3838765 787 1.363477 test
# 9 Q0 G00-93-1265148 788 1.363477 test
# 9 Q0 G00-05-0709830 789 1.363477 test
# 9 Q0 G00-83-2446108 790 1.356976 test
# 9 Q0 G00-58-1939983 791 1.356976 test
# 9 Q0 G00-05-2191460 792 1.356976 test
# 9 Q0 G00-20-3257357 793 1.356976 test
# 9 Q0 G00-42-1830673 794 1.356976 test
# 9 Q0 G00-01-1031819 795 1.354792 test
# 9 Q0 G00-36-2788975 796 1.354792 test
# 9 Q0 G00-35-3406418 797 1.354792 test
# 9 Q0 G00-63-2430531 798 1.350536 test
# 9 Q0 G00-91-0853670 799 1.350536 test
# 9 Q0 G00-09-2426973 800 1.350536 test
# 9 Q0 G00-09-2926931 801 1.350536 test
# 9 Q0 G00-32-0503644 802 1.350536 test
# 9 Q0 G00-98-3717752 803 1.350536 test
# 9 Q0 G00-20-0452715 804 1.350536 test
# 9 Q0 G00-89-3734824 805 1.342044 test
# 9 Q0 G00-03-3386274 806 1.342044 test
# 9 Q0 G00-38-0178600 807 1.342044 test
# 9 Q0 G00-03-0266073 808 1.335745 test
# 9 Q0 G00-86-3503020 809 1.335745 test
# 9 Q0 G00-18-0299814 810 1.335745 test
# 9 Q0 G00-23-3513349 811 1.335745 test
# 9 Q0 G00-51-1817629 812 1.335745 test
# 9 Q0 G00-34-0729018 813 1.334671 test
# 9 Q0 G00-80-2348597 814 1.334671 test
# 9 Q0 G00-88-1894712 815 1.328426 test
# 9 Q0 G00-91-3065008 816 1.327438 test
# 9 Q0 G00-09-2834741 817 1.327438 test
# 9 Q0 G00-23-1800567 818 1.327438 test
# 9 Q0 G00-07-1453949 819 1.327438 test
# 9 Q0 G00-00-1696968 820 1.321275 test
# 9 Q0 G00-00-3253540 821 1.321275 test
# 9 Q0 G00-45-1486246 822 1.321275 test
# 9 Q0 G00-60-1570476 823 1.321275 test
# 9 Q0 G00-99-2441663 824 1.321275 test
# 9 Q0 G00-45-1367785 825 1.319194 test
# 9 Q0 G00-66-2926228 826 1.314127 test
# 9 Q0 G00-87-2683912 827 1.314127 test
# 9 Q0 G00-91-3561460 828 1.313146 test
# 9 Q0 G00-16-4067677 829 1.313146 test
# 9 Q0 G00-16-3952320 830 1.313146 test
# 9 Q0 G00-93-2344882 831 1.313146 test
# 9 Q0 G00-06-3652121 832 1.313146 test
# 9 Q0 G00-72-3043721 833 1.313146 test
# 9 Q0 G00-91-3576409 834 1.305116 test
# 9 Q0 G00-09-2147303 835 1.305116 test
# 9 Q0 G00-01-1579878 836 1.305116 test
# 9 Q0 G00-41-3022936 837 1.305116 test
# 9 Q0 G00-10-2109040 838 1.305116 test
# 9 Q0 G00-11-0450519 839 1.305116 test
# 9 Q0 G00-99-0399954 840 1.305116 test
# 9 Q0 G00-82-0443423 841 1.305116 test
# 9 Q0 G00-25-0436750 842 1.305116 test
# 9 Q0 G00-27-3209717 843 1.305116 test
# 9 Q0 G00-09-2310962 844 1.297184 test
# 9 Q0 G00-03-0645441 845 1.297184 test
# 9 Q0 G00-03-2187270 846 1.297184 test
# 9 Q0 G00-86-3900916 847 1.297184 test
# 9 Q0 G00-39-2879677 848 1.297184 test
# 9 Q0 G00-90-0648858 849 1.297184 test
# 9 Q0 G00-58-2446566 850 1.297184 test
# 9 Q0 G00-08-0808916 851 1.297184 test
# 9 Q0 G00-49-2396146 852 1.297184 test
# 9 Q0 G00-05-1727482 853 1.297184 test
# 9 Q0 G00-77-2301754 854 1.297184 test
# 9 Q0 G00-38-2268943 855 1.297184 test
# 9 Q0 G00-81-2715832 856 1.297184 test
# 9 Q0 G00-62-2042932 857 1.297184 test
# 9 Q0 G00-56-2329426 858 1.294207 test
# 9 Q0 G00-35-3882703 859 1.294207 test
# 9 Q0 G00-31-0445278 860 1.294207 test
# 9 Q0 G00-74-3829250 861 1.287404 test
# 9 Q0 G00-03-2613061 862 1.287404 test
# 9 Q0 G00-00-0165832 863 1.287404 test
# 9 Q0 G00-46-3374400 864 1.287404 test
# 9 Q0 G00-66-1627965 865 1.287404 test
# 9 Q0 G00-45-2019689 866 1.287404 test
# 9 Q0 G00-04-0503448 867 1.287404 test
# 9 Q0 G00-04-1864045 868 1.287404 test
# 9 Q0 G00-97-3422992 869 1.287404 test
# 9 Q0 G00-92-1469046 870 1.287404 test
# 9 Q0 G00-42-3826078 871 1.287404 test
# 9 Q0 G00-91-3807220 872 1.279685 test
# 9 Q0 G00-03-0111352 873 1.279685 test
# 9 Q0 G00-10-0798979 874 1.279685 test
# 9 Q0 G00-94-3306767 875 1.279685 test
# 9 Q0 G00-95-0702657 876 1.279685 test
# 9 Q0 G00-95-0454461 877 1.279685 test
# 9 Q0 G00-30-1518511 878 1.274881 test
# 9 Q0 G00-77-1094989 879 1.274881 test
# 9 Q0 G00-89-0765423 880 1.272058 test
# 9 Q0 G00-00-3717374 881 1.272058 test
# 9 Q0 G00-00-1842603 882 1.272058 test
# 9 Q0 G00-00-3098344 883 1.272058 test
# 9 Q0 G00-01-3217456 884 1.272058 test
# 9 Q0 G00-36-0496639 885 1.272058 test
# 9 Q0 G00-11-0920146 886 1.272058 test
# 9 Q0 G00-05-0448193 887 1.272058 test
# 9 Q0 G00-97-0304787 888 1.272058 test
# 9 Q0 G00-33-0293490 889 1.272058 test
# 9 Q0 G00-77-2783812 890 1.272058 test
# 9 Q0 G00-07-3318478 891 1.272058 test
# 9 Q0 G00-09-2418472 892 1.262652 test
# 9 Q0 G00-00-3031135 893 1.262652 test
# 9 Q0 G00-56-3249614 894 1.262652 test
# 9 Q0 G00-39-3850837 895 1.262652 test
# 9 Q0 G00-08-3850896 896 1.262652 test
# 9 Q0 G00-18-0390418 897 1.262652 test
# 9 Q0 G00-10-1308595 898 1.262652 test
# 9 Q0 G00-79-1526684 899 1.262652 test
# 9 Q0 G00-05-1642328 900 1.262652 test
# 9 Q0 G00-05-1655757 901 1.262652 test
# 9 Q0 G00-67-1626082 902 1.262652 test
# 9 Q0 G00-27-0038969 903 1.262652 test
# 9 Q0 G00-02-1467454 904 1.262652 test
# 9 Q0 G00-58-3090637 905 1.254278 test
# 9 Q0 G00-08-4094617 906 1.254278 test
# 9 Q0 G00-50-1131981 907 1.253384 test
# 9 Q0 G00-69-0601069 908 1.253384 test
# 9 Q0 G00-09-3393396 909 1.253384 test
# 9 Q0 G00-09-3931526 910 1.253384 test
# 9 Q0 G00-09-1846234 911 1.253384 test
# 9 Q0 G00-03-2589138 912 1.253384 test
# 9 Q0 G00-00-0537233 913 1.253384 test
# 9 Q0 G00-01-1171351 914 1.253384 test
# 9 Q0 G00-98-1192401 915 1.253384 test
# 9 Q0 G00-99-3624858 916 1.253384 test
# 9 Q0 G00-95-2016892 917 1.253384 test
# 9 Q0 G00-20-3165511 918 1.253384 test
# 9 Q0 G00-07-0475488 919 1.253384 test
# 9 Q0 G00-07-0978415 920 1.253384 test
# 9 Q0 G00-44-2315826 921 1.244250 test
# 9 Q0 G00-74-3926994 922 1.244250 test
# 9 Q0 G00-69-1691089 923 1.244250 test
# 9 Q0 G00-09-1022942 924 1.244250 test
# 9 Q0 G00-03-0843413 925 1.244250 test
# 9 Q0 G00-00-2917282 926 1.244250 test
# 9 Q0 G00-01-2154945 927 1.244250 test
# 9 Q0 G00-04-1444976 928 1.244250 test
# 9 Q0 G00-05-0619345 929 1.244250 test
# 9 Q0 G00-87-1583924 930 1.244250 test
# 9 Q0 G00-33-4173024 931 1.244250 test
# 9 Q0 G00-62-2515352 932 1.244250 test
# 9 Q0 G00-43-3114822 933 1.244250 test
# 9 Q0 G00-89-3698265 934 1.235249 test
# 9 Q0 G00-89-0026341 935 1.235249 test
# 9 Q0 G00-19-2896720 936 1.235249 test
# 9 Q0 G00-16-3820731 937 1.235249 test
# 9 Q0 G00-54-3411561 938 1.235249 test
# 9 Q0 G00-08-3261667 939 1.235249 test
# 9 Q0 G00-57-0803089 940 1.235249 test
# 9 Q0 G00-98-3866861 941 1.235249 test
# 9 Q0 G00-04-3972022 942 1.235249 test
# 9 Q0 G00-05-0067428 943 1.235249 test
# 9 Q0 G00-60-3249607 944 1.235249 test
# 9 Q0 G00-06-0125838 945 1.235249 test
# 9 Q0 G00-44-0776281 946 1.234331 test
# 9 Q0 G00-10-1731941 947 1.234331 test
# 9 Q0 G00-83-2979577 948 1.226377 test
# 9 Q0 G00-03-2515741 949 1.226377 test
# 9 Q0 G00-17-1289316 950 1.226377 test
# 9 Q0 G00-01-1146668 951 1.226377 test
# 9 Q0 G00-56-1706812 952 1.226377 test
# 9 Q0 G00-96-3359934 953 1.226377 test
# 9 Q0 G00-79-0173131 954 1.226377 test
# 9 Q0 G00-15-2705772 955 1.226377 test
# 9 Q0 G00-94-3782465 956 1.226377 test
# 9 Q0 G00-82-1906104 957 1.226377 test
# 9 Q0 G00-38-4001700 958 1.226377 test
# 9 Q0 G00-40-3402544 959 1.226377 test
# 9 Q0 G00-20-0702603 960 1.226377 test
# 9 Q0 G00-81-3698412 961 1.226377 test
# 9 Q0 G00-45-0809730 962 1.223415 test
# 9 Q0 G00-68-0000000 963 1.215898 test
# 9 Q0 G00-09-0888336 964 1.215898 test
# 9 Q0 G00-03-1891070 965 1.215898 test
# 9 Q0 G00-03-2685070 966 1.215898 test
# 9 Q0 G00-01-1548658 967 1.215898 test
# 9 Q0 G00-21-3411003 968 1.215898 test
# 9 Q0 G00-16-1397775 969 1.215898 test
# 9 Q0 G00-36-3470419 970 1.215898 test
# 9 Q0 G00-58-1795138 971 1.215898 test
# 9 Q0 G00-80-2126087 972 1.215898 test
# 9 Q0 G00-08-2330518 973 1.215898 test
# 9 Q0 G00-10-0994585 974 1.215898 test
# 9 Q0 G00-98-2231918 975 1.215898 test
# 9 Q0 G00-51-3553948 976 1.215898 test
# 9 Q0 G00-06-3647346 977 1.215898 test
# 9 Q0 G00-06-1913581 978 1.215898 test
# 9 Q0 G00-25-3640781 979 1.215898 test
# 9 Q0 G00-47-0594475 980 1.215898 test
# 9 Q0 G00-43-1343266 981 1.215898 test
# 9 Q0 G00-02-2469809 982 1.215898 test
# 9 Q0 G00-32-2166728 983 1.214144 test
# 9 Q0 G00-72-2362421 984 1.214144 test
# 9 Q0 G00-20-0457640 985 1.214144 test
# 9 Q0 G00-68-0361254 986 1.207301 test
# 9 Q0 G00-69-1435616 987 1.207301 test
# 9 Q0 G00-41-0928621 988 1.207301 test
# 9 Q0 G00-39-0996057 989 1.207301 test
# 9 Q0 G00-55-3773526 990 1.207301 test
# 9 Q0 G00-55-3581191 991 1.207301 test
# 9 Q0 G00-55-3532648 992 1.207301 test
# 9 Q0 G00-46-2760766 993 1.207301 test
# 9 Q0 G00-54-3304332 994 1.207301 test
# 9 Q0 G00-10-2946905 995 1.207301 test
# 9 Q0 G00-10-0506282 996 1.207301 test
# 9 Q0 G00-15-3646536 997 1.207301 test
# 9 Q0 G00-53-4080590 998 1.207301 test
# 9 Q0 G00-92-3108734 999 1.207301 test
# 9 Q0 G00-44-2135933 1000 1.197143 test
# 9 Q0 G00-50-2186799 1001 1.197143 test
# 9 Q0 G00-96-1781066 1002 1.197143 test
# 9 Q0 G00-10-3017657 1003 1.197143 test
# 9 Q0 G00-11-0770745 1004 1.197143 test
# 9 Q0 G00-66-0313677 1005 1.197143 test
# 9 Q0 G00-12-3819195 1006 1.197143 test
# 9 Q0 G00-05-1324928 1007 1.197143 test
# 9 Q0 G00-06-2971917 1008 1.197143 test
# 9 Q0 G00-62-0415887 1009 1.197143 test
# 9 Q0 G00-67-3538835 1010 1.197143 test
# 9 Q0 G00-31-2469242 1011 1.197143 test
# 9 Q0 G00-02-1934959 1012 1.197143 test
# 9 Q0 G00-88-0648048 1013 1.193772 test
# 9 Q0 G00-02-3103535 1014 1.193772 test
# 9 Q0 G00-00-2040865 1015 1.187156 test
# 9 Q0 G00-55-0975670 1016 1.187156 test
# 9 Q0 G00-46-3411629 1017 1.187156 test
# 9 Q0 G00-08-3354269 1018 1.187156 test
# 9 Q0 G00-11-3773963 1019 1.187156 test
# 9 Q0 G00-45-1977767 1020 1.187156 test
# 9 Q0 G00-94-4046104 1021 1.187156 test
# 9 Q0 G00-94-4041492 1022 1.187156 test
# 9 Q0 G00-99-2536821 1023 1.187156 test
# 9 Q0 G00-87-0601767 1024 1.187156 test
# 9 Q0 G00-95-2095908 1025 1.187156 test
# 9 Q0 G00-92-2525720 1026 1.187156 test
# 9 Q0 G00-40-2206408 1027 1.187156 test
# 9 Q0 G00-40-2126286 1028 1.187156 test
# 9 Q0 G00-62-0234683 1029 1.187156 test
# 9 Q0 G00-28-3095840 1030 1.187156 test
# 9 Q0 G00-98-4068688 1031 1.176323 test
# 9 Q0 G00-70-3118212 1032 1.176221 test
# 9 Q0 G00-91-0134664 1033 1.175712 test
# 9 Q0 G00-50-0496728 1034 1.175712 test
# 9 Q0 G00-09-0071686 1035 1.175712 test
# 9 Q0 G00-03-1848726 1036 1.175712 test
# 9 Q0 G00-08-1473899 1037 1.175712 test
# 9 Q0 G00-08-3257336 1038 1.175712 test
# 9 Q0 G00-08-0417552 1039 1.175712 test
# 9 Q0 G00-11-1357603 1040 1.175712 test
# 9 Q0 G00-66-1584015 1041 1.175712 test
# 9 Q0 G00-66-0841001 1042 1.175712 test
# 9 Q0 G00-98-3853828 1043 1.175712 test
# 9 Q0 G00-04-1736888 1044 1.175712 test
# 9 Q0 G00-93-1371217 1045 1.175712 test
# 9 Q0 G00-05-1434764 1046 1.175712 test
# 9 Q0 G00-97-1443049 1047 1.175712 test
# 9 Q0 G00-82-1744219 1048 1.175712 test
# 9 Q0 G00-07-4190786 1049 1.175712 test
# 9 Q0 G00-31-1568234 1050 1.175712 test
# 9 Q0 G00-27-2319443 1051 1.175712 test
# 9 Q0 G00-03-3078273 1052 1.166077 test
# 9 Q0 G00-71-2435350 1053 1.166077 test
# 9 Q0 G00-21-4148394 1054 1.166077 test
# 9 Q0 G00-19-2784490 1055 1.166077 test
# 9 Q0 G00-36-1433110 1056 1.166077 test
# 9 Q0 G00-36-3734429 1057 1.166077 test
# 9 Q0 G00-08-0893800 1058 1.166077 test
# 9 Q0 G00-66-3193359 1059 1.166077 test
# 9 Q0 G00-04-4008583 1060 1.166077 test
# 9 Q0 G00-93-4160214 1061 1.166077 test
# 9 Q0 G00-23-4092941 1062 1.166077 test
# 9 Q0 G00-52-1354748 1063 1.166077 test
# 9 Q0 G00-64-3191505 1064 1.166077 test
# 9 Q0 G00-48-1527977 1065 1.166077 test
# 9 Q0 G00-06-1039005 1066 1.166077 test
# 9 Q0 G00-06-2032400 1067 1.166077 test
# 9 Q0 G00-40-1115652 1068 1.166077 test
# 9 Q0 G00-28-0052103 1069 1.166077 test
# 9 Q0 G00-74-1291250 1070 1.155034 test
# 9 Q0 G00-00-0799717 1071 1.155034 test
# 9 Q0 G00-00-2515121 1072 1.155034 test
# 9 Q0 G00-21-1973048 1073 1.155034 test
# 9 Q0 G00-55-3670302 1074 1.155034 test
# 9 Q0 G00-08-4001402 1075 1.155034 test
# 9 Q0 G00-08-3234501 1076 1.155034 test
# 9 Q0 G00-10-2794731 1077 1.155034 test
# 9 Q0 G00-88-2853984 1078 1.155034 test
# 9 Q0 G00-45-0006211 1079 1.155034 test
# 9 Q0 G00-04-0767639 1080 1.155034 test
# 9 Q0 G00-35-0886432 1081 1.155034 test
# 9 Q0 G00-97-3200260 1082 1.155034 test
# 9 Q0 G00-06-2028177 1083 1.155034 test
# 9 Q0 G00-72-0527645 1084 1.155034 test
# 9 Q0 G00-31-1216640 1085 1.155034 test
# 9 Q0 G00-24-1604470 1086 1.154231 test
# 9 Q0 G00-82-2554245 1087 1.154231 test
# 9 Q0 G00-47-0197492 1088 1.154231 test
# 9 Q0 G00-67-2278397 1089 1.154231 test
# 9 Q0 G00-70-0992046 1090 1.144198 test
# 9 Q0 G00-63-3049414 1091 1.144198 test
# 9 Q0 G00-91-2032916 1092 1.144198 test
# 9 Q0 G00-09-2549321 1093 1.144198 test
# 9 Q0 G00-03-1610340 1094 1.144198 test
# 9 Q0 G00-01-2064929 1095 1.144198 test
# 9 Q0 G00-21-2004003 1096 1.144198 test
# 9 Q0 G00-21-1858074 1097 1.144198 test
# 9 Q0 G00-08-3839955 1098 1.144198 test
# 9 Q0 G00-08-3950773 1099 1.144198 test
# 9 Q0 G00-10-0305437 1100 1.144198 test
# 9 Q0 G00-10-2861833 1101 1.144198 test
# 9 Q0 G00-15-3863880 1102 1.144198 test
# 9 Q0 G00-60-1487771 1103 1.144198 test
# 9 Q0 G00-24-2277582 1104 1.144198 test
# 9 Q0 G00-06-0239914 1105 1.144198 test
# 9 Q0 G00-38-1736026 1106 1.144198 test
# 9 Q0 G00-42-3198851 1107 1.144198 test
# 9 Q0 G00-07-2687847 1108 1.144198 test
# 9 Q0 G00-07-1161610 1109 1.144198 test
# 9 Q0 G00-67-0351803 1110 1.144198 test
# 9 Q0 G00-31-2428996 1111 1.144198 test
# 9 Q0 G00-28-1394199 1112 1.144198 test
# 9 Q0 G00-90-3801679 1113 1.134295 test
# 9 Q0 G00-52-0410632 1114 1.134295 test
# 9 Q0 G00-81-1053799 1115 1.134295 test
# 9 Q0 G00-69-2544761 1116 1.133564 test
# 9 Q0 G00-09-3749355 1117 1.133564 test
# 9 Q0 G00-03-1485396 1118 1.133564 test
# 9 Q0 G00-00-2164772 1119 1.133564 test
# 9 Q0 G00-00-3566921 1120 1.133564 test
# 9 Q0 G00-55-2655624 1121 1.133564 test
# 9 Q0 G00-58-0058694 1122 1.133564 test
# 9 Q0 G00-46-1883668 1123 1.133564 test
# 9 Q0 G00-08-0085414 1124 1.133564 test
# 9 Q0 G00-10-0606850 1125 1.133564 test
# 9 Q0 G00-10-3392667 1126 1.133564 test
# 9 Q0 G00-52-1091815 1127 1.133564 test
# 9 Q0 G00-48-1495892 1128 1.133564 test
# 9 Q0 G00-40-3007949 1129 1.133564 test
# 9 Q0 G00-20-0665105 1130 1.133564 test
# 9 Q0 G00-42-1179044 1131 1.133564 test
# 9 Q0 G00-07-0733299 1132 1.133564 test
# 9 Q0 G00-59-1181108 1133 1.133564 test
# 9 Q0 G00-59-2832535 1134 1.133564 test
# 9 Q0 G00-02-1818683 1135 1.133564 test
# 9 Q0 G00-02-3361139 1136 1.133564 test
# 9 Q0 G00-70-1221597 1137 1.123125 test
# 9 Q0 G00-50-1452188 1138 1.123125 test
# 9 Q0 G00-09-0245064 1139 1.123125 test
# 9 Q0 G00-09-3984077 1140 1.123125 test
# 9 Q0 G00-03-0968831 1141 1.123125 test
# 9 Q0 G00-32-0348108 1142 1.123125 test
# 9 Q0 G00-36-0882517 1143 1.123125 test
# 9 Q0 G00-36-1666289 1144 1.123125 test
# 9 Q0 G00-54-3434200 1145 1.123125 test
# 9 Q0 G00-18-2902056 1146 1.123125 test
# 9 Q0 G00-11-1703665 1147 1.123125 test
# 9 Q0 G00-66-3863804 1148 1.123125 test
# 9 Q0 G00-04-0730361 1149 1.123125 test
# 9 Q0 G00-04-2134942 1150 1.123125 test
# 9 Q0 G00-35-3432192 1151 1.123125 test
# 9 Q0 G00-05-1064100 1152 1.123125 test
# 9 Q0 G00-94-2611218 1153 1.123125 test
# 9 Q0 G00-77-2949998 1154 1.123125 test
# 9 Q0 G00-06-2853218 1155 1.123125 test
# 9 Q0 G00-40-3182751 1156 1.123125 test
# 9 Q0 G00-31-0298409 1157 1.123125 test
# 9 Q0 G00-43-0782190 1158 1.123125 test
# 9 Q0 G00-53-0783449 1159 1.114309 test
# 9 Q0 G00-29-2589930 1160 1.114309 test
# 9 Q0 G00-62-3289850 1161 1.114309 test
# 9 Q0 G00-03-3626113 1162 1.111428 test
# 9 Q0 G00-00-0503555 1163 1.111428 test
# 9 Q0 G00-00-1591495 1164 1.111428 test
# 9 Q0 G00-34-1044519 1165 1.111428 test
# 9 Q0 G00-01-3657801 1166 1.111428 test
# 9 Q0 G00-08-4015249 1167 1.111428 test
# 9 Q0 G00-08-0883392 1168 1.111428 test
# 9 Q0 G00-10-0300401 1169 1.111428 test
# 9 Q0 G00-11-1453588 1170 1.111428 test
# 9 Q0 G00-04-2417515 1171 1.111428 test
# 9 Q0 G00-99-1148872 1172 1.111428 test
# 9 Q0 G00-87-3904576 1173 1.111428 test
# 9 Q0 G00-53-4094998 1174 1.111428 test
# 9 Q0 G00-81-3230314 1175 1.111428 test
# 9 Q0 G00-07-3170301 1176 1.111428 test
# 9 Q0 G00-07-0926644 1177 1.111428 test
# 9 Q0 G00-00-2550100 1178 1.099973 test
# 9 Q0 G00-00-1829458 1179 1.099973 test
# 9 Q0 G00-00-2416713 1180 1.099973 test
# 9 Q0 G00-00-1246456 1181 1.099973 test
# 9 Q0 G00-01-0885829 1182 1.099973 test
# 9 Q0 G00-66-3554105 1183 1.099973 test
# 9 Q0 G00-79-3824822 1184 1.099973 test
# 9 Q0 G00-45-1444296 1185 1.099973 test
# 9 Q0 G00-45-2200333 1186 1.099973 test
# 9 Q0 G00-04-3372687 1187 1.099973 test
# 9 Q0 G00-53-1764251 1188 1.099973 test
# 9 Q0 G00-06-3205886 1189 1.099973 test
# 9 Q0 G00-06-0334457 1190 1.099973 test
# 9 Q0 G00-06-2996037 1191 1.099973 test
# 9 Q0 G00-84-2308958 1192 1.099973 test
# 9 Q0 G00-81-2418942 1193 1.099973 test
# 9 Q0 G00-59-1606146 1194 1.099973 test
# 9 Q0 G00-87-3746944 1195 1.097894 test
# 9 Q0 G00-36-2127662 1196 1.094313 test
# 9 Q0 G00-09-2736495 1197 1.088751 test
# 9 Q0 G00-01-3584374 1198 1.088751 test
# 9 Q0 G00-90-1438033 1199 1.088751 test
# 9 Q0 G00-08-0716288 1200 1.088751 test
# 9 Q0 G00-08-1048959 1201 1.088751 test
# 9 Q0 G00-10-2024294 1202 1.088751 test
# 9 Q0 G00-11-2000231 1203 1.088751 test
# 9 Q0 G00-11-3704445 1204 1.088751 test
# 9 Q0 G00-88-0128325 1205 1.088751 test
# 9 Q0 G00-45-2623195 1206 1.088751 test
# 9 Q0 G00-05-3680680 1207 1.088751 test
# 9 Q0 G00-97-3162638 1208 1.088751 test
# 9 Q0 G00-77-2698734 1209 1.088751 test
# 9 Q0 G00-48-2351509 1210 1.088751 test
# 9 Q0 G00-06-3431951 1211 1.088751 test
# 9 Q0 G00-06-2471691 1212 1.088751 test
# 9 Q0 G00-81-3117219 1213 1.088751 test
# 9 Q0 G00-07-0297207 1214 1.088751 test
# 9 Q0 G00-63-2410805 1215 1.077756 test
# 9 Q0 G00-89-0044196 1216 1.077756 test
# 9 Q0 G00-09-2033802 1217 1.077756 test
# 9 Q0 G00-09-3865948 1218 1.077756 test
# 9 Q0 G00-03-4012606 1219 1.077756 test
# 9 Q0 G00-03-0783642 1220 1.077756 test
# 9 Q0 G00-00-2430093 1221 1.077756 test
# 9 Q0 G00-00-2694952 1222 1.077756 test
# 9 Q0 G00-10-1754459 1223 1.077756 test
# 9 Q0 G00-15-1980890 1224 1.077756 test
# 9 Q0 G00-04-2858389 1225 1.077756 test
# 9 Q0 G00-05-3539237 1226 1.077756 test
# 9 Q0 G00-05-2303988 1227 1.077756 test
# 9 Q0 G00-05-3024540 1228 1.077756 test
# 9 Q0 G00-87-2843876 1229 1.077756 test
# 9 Q0 G00-24-0519991 1230 1.077756 test
# 9 Q0 G00-92-2053892 1231 1.077756 test
# 9 Q0 G00-42-4051351 1232 1.077756 test
# 9 Q0 G00-07-1984572 1233 1.077756 test
# 9 Q0 G00-07-3695881 1234 1.077756 test
# 9 Q0 G00-02-4012189 1235 1.077756 test
# 9 Q0 G00-02-0709635 1236 1.077756 test
# 9 Q0 G00-00-0945765 1237 1.065648 test
# 9 Q0 G00-73-0299639 1238 1.065648 test
# 9 Q0 G00-36-2943291 1239 1.065648 test
# 9 Q0 G00-46-3492739 1240 1.065648 test
# 9 Q0 G00-80-3757269 1241 1.065648 test
# 9 Q0 G00-10-4090850 1242 1.065648 test
# 9 Q0 G00-79-2923133 1243 1.065648 test
# 9 Q0 G00-04-3171772 1244 1.065648 test
# 9 Q0 G00-05-4049017 1245 1.065648 test
# 9 Q0 G00-24-0028328 1246 1.065648 test
# 9 Q0 G00-53-2230464 1247 1.065648 test
# 9 Q0 G00-82-3293970 1248 1.065648 test
# 9 Q0 G00-72-1340883 1249 1.065648 test
# 9 Q0 G00-47-0128679 1250 1.065648 test
# 9 Q0 G00-60-0199705 1251 1.054442 test
# 9 Q0 G00-25-1502844 1252 1.054442 test
# 9 Q0 G00-70-0775862 1253 1.053810 test
# ...
# 9 Q0 G00-67-3598246 1449 0.917858 test
# 9 Q0 G00-01-1619611 1450 0.905207 test
# 9 Q0 G00-01-0745853 1451 0.905207 test
# 9 Q0 G00-55-2853576 1452 0.905207 test
# 9 Q0 G00-52-3666949 1453 0.905207 test
# 9 Q0 G00-05-0013004 1454 0.905207 test
# 9 Q0 G00-87-2023843 1455 0.905207 test
# 9 Q0 G00-82-3018441 1456 0.905207 test
# 9 Q0 G00-40-0252660 1457 0.905207 test
# 9 Q0 G00-59-0515161 1458 0.905207 test
# 9 Q0 G00-22-2985512 1459 0.901370 test
# 9 Q0 G00-30-3863788 1460 0.901370 test
# 9 Q0 G00-55-3817584 1461 0.895925 test
# 9 Q0 G00-70-1933374 1462 0.892900 test
# 9 Q0 G00-69-2828869 1463 0.892900 test
# 9 Q0 G00-03-1496820 1464 0.892900 test
# 9 Q0 G00-01-1207426 1465 0.892900 test
# 9 Q0 G00-41-3243233 1466 0.892900 test
# 9 Q0 G00-12-3452859 1467 0.892900 test
# 9 Q0 G00-98-1706780 1468 0.892900 test
# 9 Q0 G00-35-2799823 1469 0.892900 test
# 9 Q0 G00-97-0293538 1470 0.892900 test
# 9 Q0 G00-26-2224339 1471 0.892900 test
# 9 Q0 G00-42-3697613 1472 0.892900 test
# 9 Q0 G00-07-3712517 1473 0.892900 test
# 9 Q0 G00-28-0007323 1474 0.892900 test
# 9 Q0 G00-86-3730053 1475 0.891018 test
# 9 Q0 G00-40-4123169 1476 0.891018 test
# 9 Q0 G00-00-3473051 1477 0.879108 test
# 9 Q0 G00-34-2047694 1478 0.879108 test
# 9 Q0 G00-17-0059415 1479 0.879108 test
# 9 Q0 G00-55-0789960 1480 0.879108 test
# 9 Q0 G00-18-3038584 1481 0.879108 test
# 9 Q0 G00-18-0401173 1482 0.879108 test
# 9 Q0 G00-11-1714751 1483 0.879108 test
# 9 Q0 G00-11-1277616 1484 0.879108 test
# 9 Q0 G00-30-3936140 1485 0.879108 test
# 9 Q0 G00-49-0535670 1486 0.879108 test
# 9 Q0 G00-23-3119665 1487 0.879108 test
# 9 Q0 G00-33-1942384 1488 0.879108 test
# 9 Q0 G00-72-3509260 1489 0.879108 test
# 9 Q0 G00-84-1325129 1490 0.879108 test
# 9 Q0 G00-07-2710935 1491 0.879108 test
# 9 Q0 G00-10-3758881 1492 0.869832 test
# 9 Q0 G00-44-0168977 1493 0.866615 test
# 9 Q0 G00-90-3161999 1494 0.866615 test
# 9 Q0 G00-36-3192459 1495 0.866615 test
# 9 Q0 G00-08-3809731 1496 0.866615 test
# 9 Q0 G00-79-2864917 1497 0.866615 test
# 9 Q0 G00-23-0479567 1498 0.866615 test
# 9 Q0 G00-05-3814025 1499 0.866615 test
# 9 Q0 G00-05-0230946 1500 0.866615 test
# 9 Q0 G00-82-3540073 1501 0.866615 test
# 9 Q0 G00-02-1862854 1502 0.866615 test
# 9 Q0 G00-63-1863069 1503 0.853618 test
# 9 Q0 G00-69-2578528 1504 0.853618 test
# 9 Q0 G00-30-0025674 1505 0.853618 test
# 9 Q0 G00-30-0826855 1506 0.853618 test
# 9 Q0 G00-04-3271001 1507 0.853618 test
# 9 Q0 G00-05-1267454 1508 0.853618 test
# 9 Q0 G00-97-3940310 1509 0.853618 test
# 9 Q0 G00-33-1897527 1510 0.853618 test
# 9 Q0 G00-81-3142599 1511 0.853618 test
# 9 Q0 G00-02-0460286 1512 0.853618 test
# 9 Q0 G00-65-0346398 1513 0.845994 test
# 9 Q0 G00-15-1144697 1514 0.845994 test
# 9 Q0 G00-44-2026102 1515 0.840178 test
# 9 Q0 G00-50-2059900 1516 0.840178 test
# 9 Q0 G00-69-1939272 1517 0.840178 test
# 9 Q0 G00-09-2693851 1518 0.840178 test
# 9 Q0 G00-09-0025460 1519 0.840178 test
# 9 Q0 G00-08-2045138 1520 0.840178 test
# 9 Q0 G00-98-2120171 1521 0.840178 test
# 9 Q0 G00-97-3618510 1522 0.840178 test
# 9 Q0 G00-24-2808188 1523 0.840178 test
# 9 Q0 G00-02-1551768 1524 0.840178 test
# 9 Q0 G00-15-3429810 1525 0.830895 test
# 9 Q0 G00-70-2787853 1526 0.828625 test
# 9 Q0 G00-65-3635077 1527 0.828346 test
# 9 Q0 G00-03-1944370 1528 0.827154 test
# 9 Q0 G00-73-1631747 1529 0.827154 test
# 9 Q0 G00-39-3954319 1530 0.827154 test
# 9 Q0 G00-05-2393778 1531 0.827154 test
# 9 Q0 G00-06-2496948 1532 0.827154 test
# 9 Q0 G00-28-3127444 1533 0.827154 test
# 9 Q0 G00-02-1497234 1534 0.827154 test
# 9 Q0 G00-89-1037295 1535 0.814527 test
# 9 Q0 G00-03-0467446 1536 0.814527 test
# 9 Q0 G00-39-0104519 1537 0.814527 test
# 9 Q0 G00-18-3212032 1538 0.814527 test
# 9 Q0 G00-45-0288610 1539 0.814527 test
# 9 Q0 G00-87-2091907 1540 0.814527 test
# 9 Q0 G00-26-0088644 1541 0.814527 test
# 9 Q0 G00-77-4073754 1542 0.814527 test
# 9 Q0 G00-38-2515094 1543 0.814527 test
# 9 Q0 G00-72-1085257 1544 0.814527 test
# 9 Q0 G00-41-0098543 1545 0.811673 test
# 9 Q0 G00-16-0165956 1546 0.810265 test
# 9 Q0 G00-65-0761364 1547 0.806050 test
# 9 Q0 G00-68-1081000 1548 0.801527 test
# 9 Q0 G00-03-2484932 1549 0.801527 test
# 9 Q0 G00-58-0435410 1550 0.801527 test
# 9 Q0 G00-88-2083848 1551 0.801527 test
# 9 Q0 G00-05-2034933 1552 0.801527 test
# 9 Q0 G00-91-0485812 1553 0.788208 test
# 9 Q0 G00-00-0088569 1554 0.788208 test
# 9 Q0 G00-16-2479016 1555 0.788208 test
# 9 Q0 G00-08-0601924 1556 0.788208 test
# 9 Q0 G00-67-2771108 1557 0.788208 test
# 9 Q0 G00-49-1872970 1558 0.775323 test
# 9 Q0 G00-35-1714937 1559 0.775323 test
# 9 Q0 G00-95-2005790 1560 0.775323 test
# 9 Q0 G00-07-3092558 1561 0.775323 test
# 9 Q0 G00-10-1806241 1562 0.762172 test
# 9 Q0 G00-45-1398664 1563 0.762172 test
# 9 Q0 G00-60-0338104 1564 0.762172 test
# 9 Q0 G00-95-0747101 1565 0.762172 test
# 9 Q0 G00-07-0121280 1566 0.762172 test
# 9 Q0 G00-02-1178594 1567 0.762172 test
# 9 Q0 G00-80-2792256 1568 0.748803 test
# 9 Q0 G00-93-1352793 1569 0.748803 test
# 9 Q0 G00-52-4071167 1570 0.748803 test
# 9 Q0 G00-92-2113170 1571 0.748803 test
# 9 Q0 G00-38-2869018 1572 0.748803 test
# 9 Q0 G00-42-1280190 1573 0.748803 test
# 9 Q0 G00-90-3593960 1574 0.735894 test
# 9 Q0 G00-98-1785584 1575 0.735894 test
# 9 Q0 G00-93-3702508 1576 0.735894 test
# 9 Q0 G00-82-3144058 1577 0.726928 test
# 9 Q0 G00-48-3798484 1578 0.724335 test
# 9 Q0 G00-00-0409603 1579 0.723423 test
# 9 Q0 G00-95-2542025 1580 0.723423 test
# 9 Q0 G00-40-1070064 1581 0.723423 test
# 9 Q0 G00-74-3490580 1582 0.710184 test
# 9 Q0 G00-41-3928454 1583 0.710184 test
# 9 Q0 G00-18-3177883 1584 0.710184 test
# 9 Q0 G00-08-0239407 1585 0.697421 test
# 9 Q0 G00-98-0827654 1586 0.697421 test
# 9 Q0 G00-92-2864043 1587 0.697421 test
# 9 Q0 G00-06-2519665 1588 0.697421 test
# 9 Q0 G00-81-2370175 1589 0.697421 test
# 9 Q0 G00-80-1342091 1590 0.684559 test
# 9 Q0 G00-43-2127379 1591 0.684559 test
# 9 Q0 G00-56-2140972 1592 0.675613 test
# 9 Q0 G00-21-1913322 1593 0.675613 test
# 9 Q0 G00-15-1718631 1594 0.675613 test
# 9 Q0 G00-50-1789161 1595 0.671634 test
# 9 Q0 G00-72-3535112 1596 0.671634 test
# 9 Q0 G00-42-1060597 1597 0.671634 test
# 9 Q0 G00-95-3428981 1598 0.659691 test
# 9 Q0 G00-96-1415966 1599 0.659189 test
# 9 Q0 G00-24-4085400 1600 0.659189 test
# 9 Q0 G00-70-2867841 1601 0.646706 test
# 9 Q0 G00-19-1969434 1602 0.646706 test
# 9 Q0 G00-30-2122407 1603 0.646706 test
# 9 Q0 G00-12-3511705 1604 0.646706 test
# 9 Q0 G00-43-1822848 1605 0.646706 test
# 9 Q0 G00-23-2420837 1606 0.634215 test
# 9 Q0 G00-15-3335359 1607 0.628836 test
# 9 Q0 G00-21-2194623 1608 0.621745 test
# 9 Q0 G00-27-0369252 1609 0.613694 test
# 9 Q0 G00-54-4103368 1610 0.609320 test
# 9 Q0 G00-89-1405587 1611 0.601866 test
# 9 Q0 G00-90-0833131 1612 0.598843 test
# 9 Q0 G00-01-1434889 1613 0.596965 test
# 9 Q0 G00-55-1156700 1614 0.596965 test
# 9 Q0 G00-88-0775356 1615 0.596965 test
# 9 Q0 G00-54-2576117 1616 0.584700 test
# 9 Q0 G00-31-3447261 1617 0.572928 test
# 9 Q0 G00-18-3303047 1618 0.555767 test
# 9 Q0 G00-89-0780322 1619 0.548982 test
# 9 Q0 G00-21-4119651 1620 0.548982 test
# 9 Q0 G00-22-2086631 1621 0.537237 test
# 9 Q0 G00-59-1196753 1622 0.528257 test
# 9 Q0 G00-27-2159399 1623 0.528257 test
# 9 Q0 G00-25-2361981 1624 0.525983 test
# 9 Q0 G00-40-4080000 1625 0.525983 test
# 9 Q0 G00-72-4059007 1626 0.525983 test
# 9 Q0 G00-52-3079304 1627 0.525329 test
# 9 Q0 G00-66-1204421 1628 0.514876 test
# 9 Q0 G00-94-1978508 1629 0.514261 test
# 9 Q0 G00-33-0504218 1630 0.503049 test
# 9 Q0 G00-15-3106058 1631 0.492032 test
# 9 Q0 G00-10-1509107 1632 0.480945 test
# 9 Q0 G00-79-0620805 1633 0.480945 test
# 9 Q0 G00-28-2535373 1634 0.480945 test
# 9 Q0 G00-03-2784515 1635 0.470088 test
# 9 Q0 G00-04-0561356 1636 0.463827 test
# 9 Q0 G00-30-0665654 1637 0.459215 test
# 9 Q0 G00-05-3391805 1638 0.459215 test
# 9 Q0 G00-50-1075346 1639 0.439927 test
# 9 Q0 G00-88-1482208 1640 0.438237 test
# 9 Q0 G00-62-3414482 1641 0.438237 test
# 9 Q0 G00-80-3548931 1642 0.427913 test
# 9 Q0 G00-98-2242918 1643 0.427913 test
# 9 Q0 G00-98-1047338 1644 0.427913 test
# 9 Q0 G00-23-3963973 1645 0.427913 test
# 9 Q0 G00-84-3705449 1646 0.417860 test
# 9 Q0 G00-74-1802348 1647 0.412075 test
# 9 Q0 G00-80-2865414 1648 0.407878 test
# 9 Q0 G00-63-3078014 1649 0.398177 test
# 9 Q0 G00-22-0206671 1650 0.398177 test
# 9 Q0 G00-26-3218156 1651 0.398177 test
# 9 Q0 G00-40-1089727 1652 0.388395 test
# 9 Q0 G00-47-2967546 1653 0.384162 test
# 9 Q0 G00-91-2643625 1654 0.378914 test
# 9 Q0 G00-69-1265256 1655 0.378914 test
# 9 Q0 G00-60-3914816 1656 0.373770 test
# 9 Q0 G00-20-0962516 1657 0.351461 test
# 9 Q0 G00-20-3716305 1658 0.333999 test
# 9 Q0 G00-70-3168895 1659 0.317126 test
# 9 Q0 G00-21-2773039 1660 0.300919 test
# 9 Q0 G00-83-3277638 1661 0.300670 test
# 9 Q0 G00-63-2233776 1662 0.293068 test
# 9 Q0 G00-25-1928405 1663 0.291964 test
# 9 Q0 G00-70-2163268 1664 0.270419 test
# 9 Q0 G00-26-1962814 1665 0.270419 test
# 9 Q0 G00-68-1600868 1666 0.256063 test
# 9 Q0 G00-24-3625720 1667 0.243848 test
# 9 Q0 G00-90-0342721 1668 0.242395 test
# 9 Q0 G00-40-0682400 1669 0.235833 test
# 9 Q0 G00-87-1292162 1670 0.216845 test
# 9 Q0 G00-68-0439463 1671 0.204975 test
# 9 Q0 G00-53-2539578 1672 0.204975 test
# 9 Q0 G00-80-1112147 1673 0.198240 test
# 9 Q0 G00-23-3770912 1674 0.193632 test
# 9 Q0 G00-43-1143881 1675 0.193632 test
# 9 Q0 G00-74-1394517 1676 0.192410 test
# 9 Q0 G00-90-4073444 1677 0.172575 test
# 9 Q0 G00-67-0152545 1678 0.170592 test
# 9 Q0 G00-69-2353421 1679 0.162832 test
# 9 Q0 G00-56-3884873 1680 0.149123 test
# 9 Q0 G00-51-3264753 1681 0.149123 test
# 9 Q0 G00-34-0444524 1682 0.124760 test
# 9 Q0 G00-79-2569923 1683 0.113999 test
# 9 Q0 G00-84-0274223 1684 0.089378 test
# 9 Q0 G00-28-0286112 1685 0.089378 test
# 9 Q0 G00-83-3561112 1686 0.084046 test
# 9 Q0 G00-01-0488061 1687 0.000000 test
# 9 Q0 G00-01-1078697 1688 0.000000 test
# 9 Q0 G00-76-1965909 1689 0.000000 test
# 9 Q0 G00-76-1093417 1690 0.000000 test
# 9 Q0 G00-76-0659802 1691 0.000000 test
# 9 Q0 G00-76-3461519 1692 0.000000 test
# 9 Q0 G00-76-1170213 1693 0.000000 test
# 9 Q0 G00-76-4172346 1694 0.000000 test
# 9 Q0 G00-76-1157350 1695 0.000000 test
# 9 Q0 G00-76-0232183 1696 0.000000 test
# 9 Q0 G00-76-1074169 1697 0.000000 test
# 9 Q0 G00-76-2156458 1698 0.000000 test
# 9 Q0 G00-76-2513112 1699 0.000000 test
# 9 Q0 G00-76-0415824 1700 0.000000 test
# 9 Q0 G00-76-2498376 1701 0.000000 test
# 9 Q0 G00-76-2841899 1702 0.000000 test
# 9 Q0 G00-76-3635292 1703 0.000000 test
# 9 Q0 G00-85-3944555 1704 0.000000 test
# 9 Q0 G00-85-3608680 1705 0.000000 test
# 9 Q0 G00-85-0776822 1706 0.000000 test
# 9 Q0 G00-85-4030813 1707 0.000000 test
# 9 Q0 G00-85-3490684 1708 0.000000 test
# 9 Q0 G00-85-2784544 1709 0.000000 test
# 9 Q0 G00-85-0189213 1710 0.000000 test
# 9 Q0 G00-85-3065292 1711 0.000000 test
# 9 Q0 G00-85-1525415 1712 0.000000 test
# 9 Q0 G00-85-3966586 1713 0.000000 test
# 9 Q0 G00-85-0221097 1714 0.000000 test
# 9 Q0 G00-85-3240813 1715 0.000000 test
# 9 Q0 G00-85-2970310 1716 0.000000 test
# 9 Q0 G00-85-0894040 1717 0.000000 test
# 9 Q0 G00-71-1781567 1718 0.000000 test
# 9 Q0 G00-71-0999126 1719 0.000000 test
# 9 Q0 G00-12-3438391 1720 0.000000 test
# 9 Q0 G00-12-3727083 1721 0.000000 test
# 9 Q0 G00-12-4053815 1722 0.000000 test
# 9 Q0 G00-12-1837057 1723 0.000000 test
# 9 Q0 G00-12-1043081 1724 0.000000 test
# 9 Q0 G00-12-3249880 1725 0.000000 test
# 9 Q0 G00-12-0024883 1726 0.000000 test
# 9 Q0 G00-12-0331334 1727 0.000000 test
# 9 Q0 G00-12-0015737 1728 0.000000 test
# 9 Q0 G00-12-1790785 1729 0.000000 test
# 9 Q0 G00-12-1139144 1730 0.000000 test
# 9 Q0 G00-12-1926166 1731 0.000000 test
# 9 Q0 G00-12-0399012 1732 0.000000 test
# 9 Q0 G00-12-1397051 1733 0.000000 test
# 9 Q0 G00-12-1831266 1734 0.000000 test
# 9 Q0 G00-12-2680588 1735 0.000000 test
# 9 Q0 G00-33-1434621 1736 0.000000 test
# 9 Q0 G00-33-0670497 1737 0.000000 test
# 9 Q0 G00-33-2347653 1738 0.000000 test
# 9 Q0 G00-33-0053624 1739 0.000000 test
# 9 Q0 G00-33-2327900 1740 0.000000 test
# 9 Q0 G00-33-2821056 1741 0.000000 test
# 9 Q0 G00-33-2002560 1742 0.000000 test
# 9 Q0 G00-33-0806248 1743 0.000000 test
# 9 Q0 G00-61-0655651 1744 0.000000 test
# 9 Q0 G00-61-1436475 1745 0.000000 test
# 9 Q0 G00-61-3907226 1746 0.000000 test
# 9 Q0 G00-61-4150601 1747 0.000000 test
# 9 Q0 G00-61-2800209 1748 0.000000 test
# 9 Q0 G00-61-1118212 1749 0.000000 test
# 9 Q0 G00-61-3120987 1750 0.000000 test
# 9 Q0 G00-61-0469713 1751 0.000000 test
# 9 Q0 G00-61-2451131 1752 0.000000 test
# 9 Q0 G00-61-3278363 1753 0.000000 test
# 9 Q0 G00-61-2756070 1754 0.000000 test
# 9 Q0 G00-61-0280746 1755 0.000000 test
# 9 Q0 G00-61-2231909 1756 0.000000 test
# 9 Q0 G00-61-3894960 1757 0.000000 test
# 9 Q0 G00-61-1109698 1758 0.000000 test
# 9 Q0 G00-61-2575433 1759 0.000000 test
# 9 Q0 G00-61-0113829 1760 0.000000 test
# 9 Q0 G00-37-1427392 1761 0.000000 test
# 9 Q0 G00-37-0534979 1762 0.000000 test
# 9 Q0 G00-37-0563843 1763 0.000000 test
# 9 Q0 G00-37-3695093 1764 0.000000 test
# 9 Q0 G00-37-3803525 1765 0.000000 test
# 9 Q0 G00-37-4086752 1766 0.000000 test
# 9 Q0 G00-37-3787077 1767 0.000000 test
# 9 Q0 G00-29-0371794 1768 0.000000 test
# 9 Q0 G00-29-1284645 1769 0.000000 test
# 9 Q0 G00-29-0924012 1770 0.000000 test
# 9 Q0 G00-29-1907477 1771 0.000000 test
# 9 Q0 G00-29-2678164 1772 0.000000 test
# 9 Q0 G00-29-0994948 1773 0.000000 test
# 9 Q0 G00-29-2159472 1774 0.000000 test
# 9 Q0 G00-29-3434101 1775 0.000000 test
# 9 Q0 G00-29-2643876 1776 0.000000 test
# 9 Q0 G00-29-3781694 1777 0.000000 test
# 9 Q0 G00-29-3538849 1778 0.000000 test
# 9 Q0 G00-29-4124951 1779 0.000000 test
# 9 Q0 G00-29-3005305 1780 0.000000 test
# 9 Q0 G00-29-0173341 1781 0.000000 test
# 9 Q0 G00-29-1977811 1782 0.000000 test
# 9 Q0 G00-29-3689678 1783 0.000000 test
# 9 Q0 G00-29-2689569 1784 0.000000 test
# 9 Q0 G00-29-3298118 1785 0.000000 test
# 9 Q0 G00-29-3287865 1786 0.000000 test
# 9 Q0 G00-29-2968932 1787 0.000000 test
# 9 Q0 G00-13-0969542 1788 0.000000 test
# 9 Q0 G00-13-1931082 1789 0.000000 test
# 9 Q0 G00-13-3394460 1790 0.000000 test
# 9 Q0 G00-13-1939935 1791 0.000000 test
# 9 Q0 G00-13-1139439 1792 0.000000 test
# 9 Q0 G00-13-0220876 1793 0.000000 test
# 9 Q0 G00-13-2475665 1794 0.000000 test
# 9 Q0 G00-78-1609511 1795 0.000000 test
# 9 Q0 G00-78-0686285 1796 0.000000 test
# 9 Q0 G00-78-3978118 1797 0.000000 test
# 9 Q0 G00-78-0419893 1798 0.000000 test
# 9 Q0 G00-78-1392606 1799 0.000000 test
# 9 Q0 G00-78-2116321 1800 0.000000 test
# 9 Q0 G00-78-0143635 1801 0.000000 test
# 9 Q0 G00-78-0412688 1802 0.000000 test
# 9 Q0 G00-78-3691063 1803 0.000000 test
# 9 Q0 G00-78-3963422 1804 0.000000 test
# 9 Q0 G00-78-0045864 1805 0.000000 test
# 9 Q0 G00-78-2551063 1806 0.000000 test
# 9 Q0 G00-78-2271043 1807 0.000000 test
# 9 Q0 G00-78-3557324 1808 0.000000 test
# 9 Q0 G00-78-0515193 1809 0.000000 test
# 9 Q0 G00-78-2978026 1810 0.000000 test
# 9 Q0 G00-78-4117174 1811 0.000000 test
# 9 Q0 G00-78-1144993 1812 0.000000 test
# 9 Q0 G00-78-3080721 1813 0.000000 test
# 9 Q0 G00-78-1531079 1814 0.000000 test
# 9 Q0 G00-78-3388040 1815 0.000000 test
# 9 Q0 G00-75-1062837 1816 0.000000 test
# 9 Q0 G00-75-2696512 1817 0.000000 test
# 9 Q0 G00-75-1809770 1818 0.000000 test
# 9 Q0 G00-75-3286457 1819 0.000000 test
# 9 Q0 G00-75-2944787 1820 0.000000 test
# 9 Q0 G00-75-3017232 1821 0.000000 test
# 9 Q0 G00-75-3337203 1822 0.000000 test
# 9 Q0 G00-75-2391076 1823 0.000000 test
# 9 Q0 G00-75-3524215 1824 0.000000 test
# 9 Q0 G00-75-3333385 1825 0.000000 test
# 9 Q0 G00-75-0353792 1826 0.000000 test
# 9 Q0 G00-75-2536079 1827 0.000000 test
# 9 Q0 G00-75-0360346 1828 0.000000 test
# 9 Q0 G00-14-1850196 1829 0.000000 test
# 9 Q0 G00-14-1818851 1830 0.000000 test
# 9 Q0 G00-14-1002771 1831 0.000000 test
# 9 Q0 G00-14-3787870 1832 0.000000 test
# 9 Q0 G00-14-0931254 1833 0.000000 test
# 9 Q0 G00-14-2266369 1834 0.000000 test
# 9 Q0 G00-14-2961673 1835 0.000000 test
# 9 Q0 G00-14-1375985 1836 0.000000 test
# 9 Q0 G00-14-3400567 1837 0.000000 test
# 9 Q0 G00-14-2329542 1838 0.000000 test
# 9 Q0 G00-14-1873492 1839 0.000000 test
# 9 Q0 G00-02-2594969 1840 0.000000 test
# 9 Q0 G00-02-0351712 1841 0.000000 test
# 9 Q0 G00-02-0533322 1842 0.000000 test
# 9 Q0 G00-02-0146077 1843 0.000000 test
# 9 Q0 G00-02-2454692 1844 0.000000 test
# 9 Q0 G00-02-3848847 1845 0.000000 test
# 9 Q0 G00-02-0135035 1846 0.000000 test
# 9 Q0 G00-02-3479535 1847 0.000000 test
# 9 Q0 G00-02-3474376 1848 0.000000 test
# 9 Q0 G00-02-0003148 1849 0.000000 test
# 9 Q0 G00-02-1720397 1850 0.000000 test
# 9 Q0 G00-02-2698369 1851 0.000000 test
# 9 Q0 G00-02-1479121 1852 0.000000 test
# 9 Q0 G00-02-2681918 1853 0.000000 test
# 9 Q0 G00-02-2153966 1854 0.000000 test
# 9 Q0 G00-02-2545922 1855 0.000000 test
# ---------------------------Relevant documents----------------------------------
# 9 0 G00-91-3181951 1

# %% [markdown]
# ### Q4 (b): Provide answer to Q4 (b) here [markdown cell]

# %% [markdown]
# A clear list of all final modifications made.
#
# Adding | StemFilter()| CustomFilter(LancasterStemmer().stem)| CustomFilter| CustomFilter(WordNetLemmatizer().lemmatize)
#
# Using the factory() class method of Orgroup: self.query_parser = QueryParser("file_content", schema=INDEX_Q4.schema, group=qparser.OrGroup.factory(0.8))
#
# Using whoosh scoring BM25F function: self.searcher = self.index_sys.searcher(weighting=scoring.BM25F(B=0.5,K1=5))
#
# By utilizing additional filters to enhance the performance, an 'OR' query was utilized to prioritize documents that contain a higher number of query terms. This resulted in the retrieval of more relevant documents, thereby increasing the map score. By conducting trial and error, the best factory number (0.8) was found to optimize results. Additionally, the Whoosh scoring function, BM25F, was utilized with the best combination of B and K found to be B = 0.5 and k =
# 5, resulting in a map score of 0.4105. While it may be difficult to determine the optimal values of B and K, it is believed that a better combination exists for further improvement.

# %% [markdown]
# ### Q4 (c): Provide answer to Q4 (c) here [markdown cell]

# %% [markdown]
# Yes, Q3 MAP is 0.3456, Q4 MAP is 0.4105.

# %% [markdown]
# ## Validation

# %% [markdown]
# #### Run the following cells to make sure your code returns the correct value types

# %%
from whoosh.index import FileIndex
from whoosh.qparser import QueryParser
from whoosh.searching import Searcher
import os.path

# %% [markdown]
# ### Q2 Validation

# %%
assert(isinstance(q2.index_sys, FileIndex)), "Index Type"
assert(isinstance(q2.query_parser, QueryParser)), "Query Parser Type"
assert(isinstance(q2.searcher, Searcher)), "Searcher Type"
print("Q2 Types Validated")
# Out:
# Q2 Types Validated

# %% [markdown]
# ### Q3 Validation

# %%
assert(isinstance(q3.index_sys, FileIndex)), "Index Type"
assert(isinstance(q3.query_parser, QueryParser)), "Query Parser Type"
assert(isinstance(q3.searcher, Searcher)), "Searcher Type"
print("Q3 Types Validated")
# Out:
# Q3 Types Validated

# %% [markdown]
# ### Q4 Validation

# %%
assert(isinstance(q4.index_sys, FileIndex)), "Index Type"
assert(isinstance(q4.query_parser, QueryParser)), "Query Parser Type"
assert(isinstance(q4.searcher, Searcher)), "Searcher Type"
print("Q4 Types Validated")
# Out:
# Q4 Types Validated
